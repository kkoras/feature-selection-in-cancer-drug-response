# %% [markdown]
# # Perform machine learning experiments with different settings
# Check out predictive performance using nominal targets. Relevant genes come directly from GDSC as well as DrugBank.

# %% [markdown]
# Imports and setup

# %%
# General imports
import pandas as pd
import numpy as np
import time
import random
import warnings
import sys
import collections
import dill
# Sklearn imports
from sklearn.base import clone
from scipy.stats import pearsonr
from sklearn.linear_model import ElasticNet
from sklearn import model_selection
from sklearn import metrics
from sklearn import preprocessing
from sklearn.dummy import DummyRegressor
from sklearn.pipeline import Pipeline
from sklearn import feature_selection
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor

warnings.filterwarnings('ignore')

# %% [markdown]
# Add directory to sys.path in order to import custom modules from there.

# %%
sys.path.insert(0, "/media/krzysztof/Nowy/Doktorat - Modelling drug efficacy in cancer/Projects/Created Modules")
# Import desired utilities
from gdsc_projects_module import DrugWithDrugBank, Experiment

# %% [markdown]
# ### Load data

# %%
# Initialize proper file pathways
drug_annotations = "/media/krzysztof/Nowy/Doktorat - Modelling drug efficacy in cancer/Data/Original Data/Genomics of Drug Sensitivity in Cancer/Original GDSC Data/Drug annotations/Screened_Compounds-March_27th_2018.xlsx"
cell_line_list = "/media/krzysztof/Nowy/Doktorat - Modelling drug efficacy in cancer/Data/Original Data/Genomics of Drug Sensitivity in Cancer/Original GDSC Data/Cell line list (directly from website)/Cell_listThu Aug 16 22_06_49 2018.csv"
gene_expr = "/media/krzysztof/Nowy/Doktorat - Modelling drug efficacy in cancer/Data/Original Data/Genomics of Drug Sensitivity in Cancer/Original GDSC Data/Gene expression/sanger1018_brainarray_ensemblgene_rma-March_2nd_2017.txt"
cnv1 = "/media/krzysztof/Nowy/Doktorat - Modelling drug efficacy in cancer/Data/Original Data/Genomics of Drug Sensitivity in Cancer/Original GDSC Data/Copy number variations/cnv_binary_1.csv"
cnv2 = "/media/krzysztof/Nowy/Doktorat - Modelling drug efficacy in cancer/Data/Original Data/Genomics of Drug Sensitivity in Cancer/Original GDSC Data/Copy number variations/PANCANCER_Genetic_feature_cna_Mon Aug  6 16_18_51 2018 (kopia).csv"
coding_variants = "/media/krzysztof/Nowy/Doktorat - Modelling drug efficacy in cancer/Data/Original Data/Genomics of Drug Sensitivity in Cancer/Original GDSC Data/Mutation calls/PANCANCER_Genetic_feature_variant_Mon Aug  6 15_45_44 2018.csv"
drug_response = "/media/krzysztof/Nowy/Doktorat - Modelling drug efficacy in cancer/Data/Original Data/Genomics of Drug Sensitivity in Cancer/Original GDSC Data/Sensitivity profiles/v17.3_fitted_dose_response-March_27th_2018.xlsx"

# Load dictionary with targets derived from DrugBank
drugbank_targets = "/media/krzysztof/Nowy/Doktorat - Modelling drug efficacy in cancer/Data/Original Data/DrugBank/Created data/drugbank_map_drug_to_targets.p"

# Filepath to gene expression signatures provided by Merck
signatures = "/media/krzysztof/Nowy/Doktorat - Modelling drug efficacy in cancer/Data/Created data/Merck Gene Expression Signatures/Data/SignatureScores_GDSC-cellLines_2018-09-27.tsv"

# Call loading function from DrugWithDrugBank class
(drug_annotations_df, cell_lines_list_df, gene_expression_df, cnv_binary_df, 
 coding_variants_df, drug_response_df, map_drugs_to_drugbank_targets) = DrugWithDrugBank.load_data(
    drug_annotations, cell_line_list, gene_expr, 
    cnv1, cnv2, coding_variants, drug_response, drugbank_targets)

# Load gene expression signatures
signatures_df = pd.read_table(signatures)

# Load helper dict for extraction of CNV data
filepath = "/media/krzysztof/Nowy/Doktorat - Modelling drug efficacy in cancer/Data/Original Data/Genomics of Drug Sensitivity in Cancer/Original GDSC Data/Copy number variations/Created data/"
with open(filepath + "map_cl_id_and_genetic_feature_to_mutation_status.pkl", "rb") as f:
    map_from_cl_id_and_genetic_feature_to_mutation_status = dill.load(f)

# Load gene mappings
filepath1 = "/media/krzysztof/Nowy/Doktorat - Modelling drug efficacy in cancer/Projects/GDSC - Prediction only with data related to nominal drug targets (minimal approach)/Created data/mapping_from_ensembl_id_to_hgnc_symbol.p"
filepath2 = "/media/krzysztof/Nowy/Doktorat - Modelling drug efficacy in cancer/Projects/GDSC - Prediction only with data related to nominal drug targets (minimal approach)/Created data/mapping_from_hgnc_symbol_to_ensembl_id.p"
DrugWithDrugBank.load_mappings(filepath2, filepath1)   # Initialize class variables

# Print shapes of created DataFrames
print("Loading summary:")
print("Drug annotations:", drug_annotations_df.shape)
print("Cell line list", cell_lines_list_df.shape)
print("Gene expression", gene_expression_df.shape)
print("CNV binary:", cnv_binary_df.shape)
print("Coding variants:", coding_variants_df.shape)
print("Drug response:", drug_response_df.shape)
print("DrugBank mapping (number of matched drugs):", len(map_drugs_to_drugbank_targets))
print("Gene expression signatures:", signatures_df.shape)
print("Number of entries in mapping from cell line and cnv genetic feature to mutation status:",
     len(map_from_cl_id_and_genetic_feature_to_mutation_status))
# Out:
# Loading summary:
# Drug annotations: (267, 5)
# Cell line list (1065, 6)
# Gene expression (17737, 1019)
# CNV binary: (419050, 9)
# Coding variants: (295740, 9)
# Drug response: (224202, 13)
# DrugBank mapping (number of matched drugs): 88
# Gene expression signatures: (128, 1018)
# Number of entries in mapping from cell line and cnv genetic feature to mutation status: 419050

# %% [markdown]
# # Machine learning section
# Check predictive performance with different experimental settings.

# %% [markdown]
# ### Elastic Net with Z-score normalization for all features and exhaustive grid search for hyperparameter tuning - all data classes (expression, mutation, CNV, tissue) but without Merck gene expression signatures

# %% [markdown]
# Initialize dictionary with DrugWithDrugBank objects and compute input data for all drugs.

# %%
# Create drug objects
drugs = DrugWithDrugBank.create_drugs(drug_annotations_df, map_drugs_to_drugbank_targets)
print(len(drugs))

# Set up data types we want to include in our input for each drug
data_types = ["CNV", "mutation", "expression", "tissue"]
# Create input data
Experiment.create_input_for_each_drug(drugs, drug_response_df, data_combination=data_types, 
                                     gene_expression_df=gene_expression_df, 
                                     cnv_binary_df=cnv_binary_df,
                                     map_cl_id_and_feature_to_status=map_from_cl_id_and_genetic_feature_to_mutation_status,
                                     cell_lines_list_df=cell_lines_list_df,
                                     coding_variants_df=coding_variants_df,
                                     feat_threshold=16,
                                     log=True)
# Out:
# 267
# 10 drugs done
# 20 drugs done
# 30 drugs done
# 40 drugs done
# 50 drugs done
# 60 drugs done
# 70 drugs done
# 80 drugs done
# 90 drugs done
# 100 drugs done
# 110 drugs done
# 120 drugs done
# 130 drugs done
# 140 drugs done
# 150 drugs done
# 160 drugs done
# 170 drugs done
# 180 drugs done
# 190 drugs done
# 200 drugs done
# 210 drugs done
# 220 drugs done
# 230 drugs done
# 240 drugs done
# 250 drugs done
# 260 drugs done
# Number of drugs with number of features bigger than 16: 184
# Mean number of features in 267 drugs: 3.7265917602996255

# %%
#############################################################################################################
# Set up constants, feature normalization, predictive algorithm and initialize experiment instance
#############################################################################################################

log = True
counter = 0
sensitivity_metric = "AUC"
record_weights = True   # Does the model has coefficients we want to record?
n_folds = 10   # Number of folds in parameter tuning cross-validation
n_combinations = 20   # Number of parameter combinations to try (when using randomized search)

scaler = preprocessing.StandardScaler()   # Setup transformer for feature scaling

estimator = ElasticNet(max_iter=2000)   # Setup algorithm to use

# Hyperparameter space to search on
param_grid = {"estimator__alpha": [0.001, 0.01, 0.1, 1., 5., 10., 30., 50., 100., 300.],
                 "estimator__l1_ratio": [0.0, 0.1, 0.25, 0.5, 0.75, 0.9, 1.]}

# Setup seeds for data split
split_seed = 37

# Function to be optimized during hyperparameter tuning
scoring = "neg_mean_squared_error"   # Function to be optimized by hyperparameters

# Initialize Experiment object for this assay
exp = Experiment(name="Only targets-Elastic Net with Z-score normalization",
                algorithm="ElasticNet",
                parameter_search_type="GridSearch",
                data_normalization_type="StandardScaler on all features",
                split_seed=split_seed,
                kfolds=n_folds)

#############################################################################################################
# Enter the loop over drugs
#############################################################################################################

for ide in drugs:
    drug = drugs[ide]   # Current Drug object
    data = drug.full_data  # Extract input data (should be previously computed)
    if data.shape[0] == 0:   # Check if data exists, if not, skip the drug
        continue
    if data.shape[1] < 16:    # That means that data has only features related to tissue
        continue           # so also skip this case
        
    # Add input data to corresponding Experiment objects's field (dictionary)
    exp.input_data[(drug.name, ide)] = data
    if log:
        print(drug.name, data.shape)
        
    # Add data shapes to corresponding field in Experiment (dictionary)
    exp.data_shapes[(drug.name, ide)] = data.shape
    
    y = data[sensitivity_metric]   # Extract response variable
    X = data.drop(["cell_line_id", sensitivity_metric], axis=1)     # Drop targets and cell line IDs
    assert X.shape[0] == y.shape[0]   # Sanity check
    assert X.shape[1] < data.shape[1]
    
    # Split data into training and test set
    test_size = 0.3    # Fraction of data spent on test set
    X_val, X_test, y_val, y_test = model_selection.train_test_split(X, y, test_size=test_size,
                                                                   random_state=split_seed)
    
    # Create collections.namedtuple for storing
    StandardDeviations = collections.namedtuple("StandardDeviations", ["validation", "test", "overall"])
    stds = StandardDeviations(y_val.std(), y_test.std(), y.std())
    # Record in corresponding field (dictionary)
    exp.data_stds[(drug.name, ide)] = stds    
    
    # Set up and fit Dummy Regressor
    dummy = DummyRegressor()
    dummy.fit(X_val, y_val)
    # Get dummy predictions on the test set
    dummy_preds = dummy.predict(X_test)
    # Baseline dummy performance
    baseline_scores = model_selection.cross_val_score(dummy, X_val, y_val, scoring=scoring, cv=n_folds)
    baseline_mean = np.mean([(-x)**0.5 for x in baseline_scores])
    baseline_std = np.std([(-x)**0.5 for x in baseline_scores])
    
    # Set elements of the pipeline, i.e. scaler and estimator
    transformer = clone(scaler)
    predictor = clone(estimator)
    
    # Create pipeline
    main_pipeline = Pipeline([
        ("scaler", transformer),
        ("estimator", predictor)
    ])    
    
    # Set up grid search with cross-validation
    grid = model_selection.GridSearchCV(main_pipeline, param_grid=param_grid, 
                                       scoring=scoring, cv=n_folds)
    
    # Fit the grid
    grid.fit(X_val, y_val)
    best = grid.best_estimator_   # Best model
    pred = grid.predict(X_test)   # Predict on test data with refitted best model
    training_preds = grid.predict(X_val)    # Predict on train data with refitted best model
    
    if log:   # Report the results
        # Summarize grid search
        print("Best CV score (RMSE):", (-grid.best_score_)**0.5)
        print("Best parameters:", grid.best_params_)
        print("")
        
        # Print out performance of the best model on training set
        print("RMSE on training data:", metrics.mean_squared_error(y_val, training_preds)**0.5)
        print("Correlation with the training set:", pearsonr(y_val, training_preds))
        print("")
        
        # Print out the performance of the best model on test set
        print("RMSE on test data:", metrics.mean_squared_error(y_test, pred) ** 0.5)
        print("Mean absolute error on test data:", metrics.mean_absolute_error(y_test, pred))
        print("Correlation with the test set:", pearsonr(y_test, pred))
        print("")
        
        # Print out performance of dummy regressor
        print("Dummy CV RMSE:", baseline_mean)
        print("Dummy test RMSE:", metrics.mean_squared_error(y_test, dummy_preds) ** 0.5)
        
    # Record results in corresponding Experiment fields, mostly as named tuples
    # Classification performance
    ModelTestScores = collections.namedtuple("ModelTestScores", ["cv_best_score", "test_RMSE",
                                                    "test_explained_variance", "test_correlation"])
    model_test_scores = ModelTestScores(grid.best_score_, metrics.mean_squared_error(y_test, pred) ** 0.5,
                                       metrics.explained_variance_score(y_test, pred), pearsonr(y_test, pred))
    # Record in appropriate field (dictionary)
    exp.best_scores[(drug.name, ide)] = model_test_scores
    
    # Full results of cross-validation tuning
    exp.cv_results[(drug.name, ide)] = grid.cv_results_
    
    # Parameters of best found model
    exp.best_parameters[(drug.name, ide)] = grid.best_params_
    
    # Coefficients (if model has them)
    if record_weights:
        BestModelWeights = collections.namedtuple("BestModelWeights", ["intercept", "weights_array"])
        best_model_weights = BestModelWeights(best.named_steps["estimator"].intercept_,
                                         best.named_steps["estimator"].coef_)
        # Record in appropriate field (dictionary)
        exp.coefficients[(drug.name, ide)] = best_model_weights
    
    # Performance on the training set
    ModelTrainingScores = collections.namedtuple("ModelTrainingScores", ["training_RMSE", "training_correlation"])
    model_training_scores = ModelTrainingScores(metrics.mean_squared_error(y_val, training_preds) ** 0.5,
                                               pearsonr(y_val, training_preds))
    # Record in appropriate field (dictionary)
    exp.training_scores[(drug.name, ide)] = model_training_scores
    
    # Performance of dummy model
    DummyScores = collections.namedtuple("DummyScores", ["cv_RMSE", "test_RMSE", "test_explained_variance",
                                            "test_correlation"])
    dummy_performance = DummyScores(baseline_mean, metrics.mean_squared_error(y_test, dummy_preds) ** 0.5,
                                   metrics.explained_variance_score(y_test, dummy_preds),
                                   pearsonr(y_test, dummy_preds))
    # Record in appropriate field (dictionary)
    exp.dummy_scores[(drug.name, ide)] = dummy_performance
    
    # Increment counter and display summary information
    counter += 1
    if log:
        print(counter, "drugs done")
        print("*" * 50)
        print("")
# Out:
# Erlotinib (347, 19)
# Best CV score (RMSE): 0.08331016504245249
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.0787708250192746
# Correlation with the training set: (0.47371132315354386, 6.112863286005931e-15)
#
# RMSE on test data: 0.06138808687115606
# Mean absolute error on test data: 0.038037574184868125
# Correlation with the test set: (0.5407944601565197, 2.5951217528987297e-09)
#
# Dummy CV RMSE: 0.07699414121333494
# Dummy test RMSE: 0.07096557172657372
# 1 drugs done
# **************************************************
#
# Rapamycin (362, 16)
# Best CV score (RMSE): 0.22729242064038202
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.21878975061719969
# Correlation with the training set: (0.3141587751006189, 3.3605672623170146e-07)
#
# RMSE on test data: 0.23751598294189738
# Mean absolute error on test data: 0.17220821311597512
# Correlation with the test set: (0.09262748416106704, 0.3380770172476105)
#
# Dummy CV RMSE: 0.2227736113351416
# Dummy test RMSE: 0.2381718975951265
# 2 drugs done
# **************************************************
#
# Sunitinib (372, 31)
# Best CV score (RMSE): 0.1322819108878335
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.11976064823972697
# Correlation with the training set: (0.6700880732604134, 2.980400671939976e-35)
#
# RMSE on test data: 0.13413589412679672
# Mean absolute error on test data: 0.08828914161044822
# Correlation with the test set: (0.37250518879925804, 5.242188158838037e-05)
#
# Dummy CV RMSE: 0.142935620706441
# Dummy test RMSE: 0.1443592045996043
# 3 drugs done
# **************************************************
#
# PHA-665752 (380, 18)
# Best CV score (RMSE): 0.060978000026651324
# Best parameters: {'estimator__alpha': 5.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.05975573537633223
# Correlation with the training set: (0.3264266978371391, 5.071974652821401e-08)
#
# RMSE on test data: 0.027164830293478548
# Mean absolute error on test data: 0.020152341363323535
# Correlation with the test set: (0.1289551402116394, 0.17149777874389602)
#
# Dummy CV RMSE: 0.05192732069612942
# Dummy test RMSE: 0.02745025502562561
# 4 drugs done
# **************************************************
#
# MG-132 (400, 16)
# Best CV score (RMSE): 0.12572194363469535
# Best parameters: {'estimator__alpha': 0.1, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.12082381190308453
# Correlation with the training set: (0.37988105919614096, 4.820988691119567e-11)
#
# RMSE on test data: 0.12675363690130423
# Mean absolute error on test data: 0.10013858277958049
# Correlation with the test set: (0.2941296681693983, 0.0011111961005775958)
#
# Dummy CV RMSE: 0.12967827067375035
# Dummy test RMSE: 0.13160617243829892
# 5 drugs done
# **************************************************
#
# Paclitaxel (388, 22)
# Best CV score (RMSE): 0.1885692789472333
# Best parameters: {'estimator__alpha': 0.1, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.1782486068139966
# Correlation with the training set: (0.42883658434286787, 1.5029710384077515e-13)
#
# RMSE on test data: 0.2003137543378173
# Mean absolute error on test data: 0.17156881424092313
# Correlation with the test set: (0.10302217194215256, 0.26901454719425055)
#
# Dummy CV RMSE: 0.1969821118965361
# Dummy test RMSE: 0.1979248929357995
# 6 drugs done
# **************************************************
#
# Cyclopamine (396, 16)
# Best CV score (RMSE): 0.03837038217015543
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.03761300275023566
# Correlation with the training set: (0.23361043462336997, 8.676047474797691e-05)
#
# RMSE on test data: 0.03158749013627671
# Mean absolute error on test data: 0.02284433151006368
# Correlation with the test set: (0.27009902110731593, 0.002970705199165317)
#
# Dummy CV RMSE: 0.03784510593795913
# Dummy test RMSE: 0.032466628919677956
# 7 drugs done
# **************************************************
#
# AZ628 (377, 17)
# Best CV score (RMSE): 0.1694982348656328
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.75}
#
# RMSE on training data: 0.15797102778645145
# Correlation with the training set: (0.5595000741607989, 4.5854154187555824e-23)
#
# RMSE on test data: 0.16746075231292104
# Mean absolute error on test data: 0.11747453365688804
# Correlation with the test set: (0.5126768224671663, 5.494808133158982e-09)
#
# Dummy CV RMSE: 0.188492861423681
# Dummy test RMSE: 0.19494662645869576
# 8 drugs done
# **************************************************
#
# Sorafenib (377, 34)
# Best CV score (RMSE): 0.11920049889189768
# Best parameters: {'estimator__alpha': 0.1, 'estimator__l1_ratio': 0.1}
#
# RMSE on training data: 0.11128922935773843
# Correlation with the training set: (0.4869297350323537, 4.597884790521455e-17)
#
# RMSE on test data: 0.0946915583589483
# Mean absolute error on test data: 0.05830805789840004
# Correlation with the test set: (0.34936742449988367, 0.00013902692885516357)
#
# Dummy CV RMSE: 0.11835127608696665
# Dummy test RMSE: 0.10104082382314131
# 9 drugs done
# **************************************************
#
# Tozasertib (382, 19)
# Best CV score (RMSE): 0.19424919704388144
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.18882855620295363
# Correlation with the training set: (0.2750456987585836, 5.079452317268893e-06)
#
# RMSE on test data: 0.20042871350335206
# Mean absolute error on test data: 0.1626036821474635
# Correlation with the test set: (0.08851424825706561, 0.34686470440808215)
#
# Dummy CV RMSE: 0.19321022673410207
# Dummy test RMSE: 0.20081457418511894
# 10 drugs done
# **************************************************
#
# Imatinib (380, 29)
# Best CV score (RMSE): 0.08544881088314821
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.5}
#
# RMSE on training data: 0.07792493053728858
# Correlation with the training set: (0.48567463620018375, 3.772082854627183e-17)
#
# RMSE on test data: 0.0658063095627882
# Mean absolute error on test data: 0.035920706108978614
# Correlation with the test set: (0.18527001360857434, 0.04844293501506699)
#
# Dummy CV RMSE: 0.07430120542713381
# Dummy test RMSE: 0.06290019799353104
# 11 drugs done
# **************************************************
#
# NVP-TAE684 (379, 17)
# Best CV score (RMSE): 0.13824691896765615
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.5}
#
# RMSE on training data: 0.131942931989492
# Correlation with the training set: (0.5516725585329061, 1.664156580818845e-22)
#
# RMSE on test data: 0.12573530299019545
# Mean absolute error on test data: 0.10078505271785539
# Correlation with the test set: (0.33783440251711816, 0.00023689821740592842)
#
# Dummy CV RMSE: 0.15328147967557829
# Dummy test RMSE: 0.13213707231188704
# 12 drugs done
# **************************************************
#
# Crizotinib (379, 21)
# Best CV score (RMSE): 0.0732852300843473
# Best parameters: {'estimator__alpha': 0.1, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.06594255884572797
# Correlation with the training set: (0.5235461230867949, 4.7164240992494275e-20)
#
# RMSE on test data: 0.04223389717258818
# Mean absolute error on test data: 0.029044556200122293
# Correlation with the test set: (0.5054895255771322, 9.68173536209803e-09)
#
# Dummy CV RMSE: 0.07148142510753884
# Dummy test RMSE: 0.048153759043624574
# 13 drugs done
# **************************************************
#
# Saracatinib (406, 17)
# Best CV score (RMSE): 0.08558497466831635
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.08344428063058924
# Correlation with the training set: (0.3567292610726498, 6.014977635293239e-10)
#
# RMSE on test data: 0.05436729045978748
# Mean absolute error on test data: 0.046508848788998594
# Correlation with the test set: (0.24517311973679068, 0.006492354945268419)
#
# Dummy CV RMSE: 0.08553010709128407
# Dummy test RMSE: 0.055068056919315
# 14 drugs done
# **************************************************
#
# S-Trityl-L-cysteine (397, 16)
# Best CV score (RMSE): 0.12832965579192368
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 1.0}
#
# RMSE on training data: 0.12606058133328202
# Correlation with the training set: (0.2583125679625675, 1.3376494650220805e-05)
#
# RMSE on test data: 0.12828809188137005
# Mean absolute error on test data: 0.10791524448710108
# Correlation with the test set: (0.33092944261155366, 0.00022268278290391136)
#
# Dummy CV RMSE: 0.1293992928141039
# Dummy test RMSE: 0.13304404481865914
# 15 drugs done
# **************************************************
#
# Dasatinib (369, 46)
# Best CV score (RMSE): 0.23255874215332678
# Best parameters: {'estimator__alpha': 0.1, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.20416508923251306
# Correlation with the training set: (0.6255486057886255, 2.0006320349836017e-29)
#
# RMSE on test data: 0.244766174899222
# Mean absolute error on test data: 0.1838633845773216
# Correlation with the test set: (0.40599436395149074, 9.826982220600028e-06)
#
# Dummy CV RMSE: 0.25989510330242505
# Dummy test RMSE: 0.26432504424334047
# 16 drugs done
# **************************************************
#
# GNF-2 (370, 16)
# Best CV score (RMSE): 0.03944734518947572
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.25}
#
# RMSE on training data: 0.035918321285195384
# Correlation with the training set: (0.584761675838488, 3.7410296900847344e-25)
#
# RMSE on test data: 0.05038448916361781
# Mean absolute error on test data: 0.022247017812979015
# Correlation with the test set: (0.6059096273996679, 1.841153051745101e-12)
#
# Dummy CV RMSE: 0.03673795070066288
# Dummy test RMSE: 0.06330078760008
# 17 drugs done
# **************************************************
#
# CGP-082996 (387, 17)
# Best CV score (RMSE): 0.06146738777752118
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.75}
#
# RMSE on training data: 0.06104236251160549
# Correlation with the training set: (0.18644067250969512, 0.002095604343969684)
#
# RMSE on test data: 0.04956784314789092
# Mean absolute error on test data: 0.042397969566114496
# Correlation with the test set: (0.11958003370391394, 0.19907837370008746)
#
# Dummy CV RMSE: 0.060666158250260206
# Dummy test RMSE: 0.04982136717579758
# 18 drugs done
# **************************************************
#
# A-770041 (399, 17)
# Best CV score (RMSE): 0.17954835423506835
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.17427476608156234
# Correlation with the training set: (0.32603222570693013, 2.4835809434449495e-08)
#
# RMSE on test data: 0.14644287502261924
# Mean absolute error on test data: 0.11002821000605863
# Correlation with the test set: (0.25504425953117965, 0.004934559756355901)
#
# Dummy CV RMSE: 0.1787519630676238
# Dummy test RMSE: 0.1508975767951093
# 19 drugs done
# **************************************************
#
# WH-4-023 (396, 17)
# Best CV score (RMSE): 0.21548186099349878
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 1.0}
#
# RMSE on training data: 0.21078190050427728
# Correlation with the training set: (0.3056638267078004, 2.1145612712474256e-07)
#
# RMSE on test data: 0.2032817580813319
# Mean absolute error on test data: 0.14440228077890474
# Correlation with the test set: (0.20979585409910592, 0.02202171500117573)
#
# Dummy CV RMSE: 0.21757828475391908
# Dummy test RMSE: 0.20792655578170258
# 20 drugs done
# **************************************************
#
# WZ-1-84 (398, 16)
# Best CV score (RMSE): 0.06245708957792629
# Best parameters: {'estimator__alpha': 5.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.061724438680672705
# Correlation with the training set: (0.26798764188856333, 5.863065876575682e-06)
#
# RMSE on test data: 0.05841074743450709
# Mean absolute error on test data: 0.04185873700530427
# Correlation with the test set: (0.25966015218549826, 0.004183858991288464)
#
# Dummy CV RMSE: 0.059499996599394325
# Dummy test RMSE: 0.05919907409607344
# 21 drugs done
# **************************************************
#
# BI-2536 (397, 18)
# Best CV score (RMSE): 0.14203634295689418
# Best parameters: {'estimator__alpha': 5.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.14029936855709146
# Correlation with the training set: (0.2562830427584834, 1.5712742135649278e-05)
#
# RMSE on test data: 0.17441658244011554
# Mean absolute error on test data: 0.150364671207167
# Correlation with the test set: (0.2439584425251504, 0.007249595475577954)
#
# Dummy CV RMSE: 0.14136156988331644
# Dummy test RMSE: 0.17623620404417156
# 22 drugs done
# **************************************************
#
# BMS-536924 (388, 17)
# Best CV score (RMSE): 0.16376920962757868
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.75}
#
# RMSE on training data: 0.15691942734149836
# Correlation with the training set: (0.4307842194948387, 1.1352696174599966e-13)
#
# RMSE on test data: 0.15047379046714313
# Mean absolute error on test data: 0.12046576991056573
# Correlation with the test set: (0.27298995288012, 0.002902184963607917)
#
# Dummy CV RMSE: 0.17202052033065027
# Dummy test RMSE: 0.15369042514929845
# 23 drugs done
# **************************************************
#
# BMS-509744 (399, 16)
# Best CV score (RMSE): 0.07481429796450888
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.07204167109312612
# Correlation with the training set: (0.3483893178028721, 2.210073173633231e-09)
#
# RMSE on test data: 0.07057779789604021
# Mean absolute error on test data: 0.054874564264401966
# Correlation with the test set: (0.20255080701169026, 0.026509914158226847)
#
# Dummy CV RMSE: 0.07483498680967486
# Dummy test RMSE: 0.07215883916366855
# 24 drugs done
# **************************************************
#
# Pyrimethamine (401, 16)
# Best CV score (RMSE): 0.11700978444702653
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.11440730716842004
# Correlation with the training set: (0.29594362368141636, 4.5744250225634756e-07)
#
# RMSE on test data: 0.11793858186488722
# Mean absolute error on test data: 0.08552928630399699
# Correlation with the test set: (0.24384249930569202, 0.00703388207825324)
#
# Dummy CV RMSE: 0.11661703911651625
# Dummy test RMSE: 0.12136745255786242
# 25 drugs done
# **************************************************
#
# JW-7-52-1 (358, 17)
# Best CV score (RMSE): 0.22655067539517018
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.21982587387875263
# Correlation with the training set: (0.3134744177353146, 4.1984523281022265e-07)
#
# RMSE on test data: 0.23282725079870617
# Mean absolute error on test data: 0.19736056464974897
# Correlation with the test set: (0.17472008115119125, 0.07052028465195627)
#
# Dummy CV RMSE: 0.22815215204432132
# Dummy test RMSE: 0.23624677701981267
# 26 drugs done
# **************************************************
#
# A-443654 (372, 25)
# Best CV score (RMSE): 0.13740694913165083
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.131654402300645
# Correlation with the training set: (0.3414967567029395, 1.5977486654647228e-08)
#
# RMSE on test data: 0.1449365758440348
# Mean absolute error on test data: 0.11704336537732149
# Correlation with the test set: (-0.06210366370134381, 0.5153702772943778)
#
# Dummy CV RMSE: 0.13819231163183748
# Dummy test RMSE: 0.1431336378144807
# 27 drugs done
# **************************************************
#
# GW843682X (399, 16)
# Best CV score (RMSE): 0.18705222348530365
# Best parameters: {'estimator__alpha': 5.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.18410032122021386
# Correlation with the training set: (0.2548433675576236, 1.6401723044493447e-05)
#
# RMSE on test data: 0.20536319069570658
# Mean absolute error on test data: 0.17751387220663528
# Correlation with the test set: (0.27776506023142916, 0.002129181866519508)
#
# Dummy CV RMSE: 0.18704532584274935
# Dummy test RMSE: 0.2078261407145027
# 28 drugs done
# **************************************************
#
# Entinostat (400, 17)
# Best CV score (RMSE): 0.1666273580969547
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 1.0}
#
# RMSE on training data: 0.1626739781354177
# Correlation with the training set: (0.27480053280798206, 3.0429829162629175e-06)
#
# RMSE on test data: 0.1416795277356965
# Mean absolute error on test data: 0.11528196231521116
# Correlation with the test set: (0.3259294437704798, 0.0002804432280003572)
#
# Dummy CV RMSE: 0.16878497437020812
# Dummy test RMSE: 0.14883350209915255
# 29 drugs done
# **************************************************
#
# Bortezomib (390, 18)
# Best CV score (RMSE): 0.186288291071687
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.17839860148700837
# Correlation with the training set: (0.4041913764021703, 3.748887157599903e-12)
#
# RMSE on test data: 0.18177494811806647
# Mean absolute error on test data: 0.15257928949002747
# Correlation with the test set: (0.35926672535943904, 6.949821175362282e-05)
#
# Dummy CV RMSE: 0.19142292482240836
# Dummy test RMSE: 0.19303431763373705
# 30 drugs done
# **************************************************
#
# Seliciclib (386, 24)
# Best CV score (RMSE): 0.04438216599524135
# Best parameters: {'estimator__alpha': 5.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.04373898630906445
# Correlation with the training set: (0.294864567163117, 8.108104682226973e-07)
#
# RMSE on test data: 0.04474615198392261
# Mean absolute error on test data: 0.03474905189144844
# Correlation with the test set: (0.13984012836357376, 0.13434633828580245)
#
# Dummy CV RMSE: 0.044147600662650645
# Dummy test RMSE: 0.045038342399505944
# 31 drugs done
# **************************************************
#
# Salubrinal (398, 16)
# Best CV score (RMSE): 0.06309324556312434
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.5}
#
# RMSE on training data: 0.06213746921355861
# Correlation with the training set: (0.29047215385221103, 8.308505911062668e-07)
#
# RMSE on test data: 0.052254250564227264
# Mean absolute error on test data: 0.04366206814143524
# Correlation with the test set: (0.167224472600486, 0.06791723497773737)
#
# Dummy CV RMSE: 0.06421525006702951
# Dummy test RMSE: 0.053365369674450366
# 32 drugs done
# **************************************************
#
# Lapatinib (371, 21)
# Best CV score (RMSE): 0.07153444549197605
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.5}
#
# RMSE on training data: 0.06622248550407539
# Correlation with the training set: (0.6524173011207963, 8.593094678972902e-33)
#
# RMSE on test data: 0.08718477133664107
# Mean absolute error on test data: 0.03956600416410759
# Correlation with the test set: (0.23679558858937194, 0.0119453536480039)
#
# Dummy CV RMSE: 0.07755898411046627
# Dummy test RMSE: 0.0819327543402351
# 33 drugs done
# **************************************************
#
# GSK269962A (391, 18)
# Best CV score (RMSE): 0.11530518645567868
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.11220128337663314
# Correlation with the training set: (0.3275003469118791, 3.026552405868588e-08)
#
# RMSE on test data: 0.14178371369730208
# Mean absolute error on test data: 0.08195688889085317
# Correlation with the test set: (0.20420056847864587, 0.02655492243823389)
#
# Dummy CV RMSE: 0.11452634435171163
# Dummy test RMSE: 0.1445337779025286
# 34 drugs done
# **************************************************
#
# Doxorubicin (871, 17)
# Best CV score (RMSE): 0.2071441452449536
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.2040573661798267
# Correlation with the training set: (0.2087183307346671, 2.0198351387583431e-07)
#
# RMSE on test data: 0.19766755314047685
# Mean absolute error on test data: 0.16490385102546326
# Correlation with the test set: (0.14976551235095587, 0.015254702965172002)
#
# Dummy CV RMSE: 0.2076112080301129
# Dummy test RMSE: 0.19981275469543863
# 35 drugs done
# **************************************************
#
# Etoposide (881, 17)
# Best CV score (RMSE): 0.22054807610752036
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.21689968495537937
# Correlation with the training set: (0.31129334352796456, 2.6214993983143646e-15)
#
# RMSE on test data: 0.21176209725291445
# Mean absolute error on test data: 0.18299150673351075
# Correlation with the test set: (0.21722640993789205, 0.00036789778717625924)
#
# Dummy CV RMSE: 0.22584447733705204
# Dummy test RMSE: 0.21678754691653096
# 36 drugs done
# **************************************************
#
# Gemcitabine (843, 20)
# Best CV score (RMSE): 0.30887004060114204
# Best parameters: {'estimator__alpha': 0.1, 'estimator__l1_ratio': 0.1}
#
# RMSE on training data: 0.3036874016560944
# Correlation with the training set: (0.275451325969351, 9.85199883092704e-12)
#
# RMSE on test data: 0.29649361301894145
# Mean absolute error on test data: 0.2596650335457084
# Correlation with the test set: (0.23567825285347882, 0.00015459943951248855)
#
# Dummy CV RMSE: 0.3148278857063786
# Dummy test RMSE: 0.30484467357967293
# 37 drugs done
# **************************************************
#
# Bicalutamide (870, 16)
# Best CV score (RMSE): 0.012135018596973182
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.01184648769810376
# Correlation with the training set: (0.29136262001976637, 2.214072495362225e-13)
#
# RMSE on test data: 0.010127657442010184
# Mean absolute error on test data: 0.005656841441271699
# Correlation with the test set: (0.17294126513015784, 0.0050836918793338804)
#
# Dummy CV RMSE: 0.010745214708657984
# Dummy test RMSE: 0.010278623982170958
# 38 drugs done
# **************************************************
#
# QS11 (848, 17)
# Best CV score (RMSE): 0.08804010204114729
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.08695091331736919
# Correlation with the training set: (0.18937734127966693, 3.4173244896923936e-06)
#
# RMSE on test data: 0.07763219776007778
# Mean absolute error on test data: 0.06326016954943886
# Correlation with the test set: (0.09879959134899194, 0.11553265670462803)
#
# Dummy CV RMSE: 0.0877468076738381
# Dummy test RMSE: 0.07808913297774242
# 39 drugs done
# **************************************************
#
# CP466722 (867, 17)
# Best CV score (RMSE): 0.10506997387066304
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.25}
#
# RMSE on training data: 0.10314306269403331
# Correlation with the training set: (0.522304368843874, 1.0246198524828436e-43)
#
# RMSE on test data: 0.10200361178678023
# Mean absolute error on test data: 0.08271318328331971
# Correlation with the test set: (0.5704916343984578, 6.18981730619006e-24)
#
# Dummy CV RMSE: 0.12045417643961169
# Dummy test RMSE: 0.12327543477670332
# 40 drugs done
# **************************************************
#
# Midostaurin (858, 17)
# Best CV score (RMSE): 0.08886010831155403
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.08724928694511071
# Correlation with the training set: (0.2647003617414034, 4.453203093794993e-11)
#
# RMSE on test data: 0.08215222392221595
# Mean absolute error on test data: 0.06651858227212586
# Correlation with the test set: (0.15562761685547674, 0.012318739729952885)
#
# Dummy CV RMSE: 0.08870925998179173
# Dummy test RMSE: 0.08310588482093066
# 41 drugs done
# **************************************************
#
# CHIR-99021 (855, 18)
# Best CV score (RMSE): 0.03919314352617273
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.038510760345475854
# Correlation with the training set: (0.2861304922542348, 9.888441842008752e-13)
#
# RMSE on test data: 0.04708872850640103
# Mean absolute error on test data: 0.025602003281038756
# Correlation with the test set: (0.28450265312131406, 3.572381167539248e-06)
#
# Dummy CV RMSE: 0.03876090314694976
# Dummy test RMSE: 0.04839584764010036
# 42 drugs done
# **************************************************
#
# Ponatinib (826, 44)
# Best CV score (RMSE): 0.11842636723206644
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.1137359822341606
# Correlation with the training set: (0.4891269009834926, 4.248617771282048e-36)
#
# RMSE on test data: 0.1586869388254976
# Mean absolute error on test data: 0.08529936171399609
# Correlation with the test set: (0.4816931579808445, 8.224442455910368e-16)
#
# Dummy CV RMSE: 0.123133423682808
# Dummy test RMSE: 0.17302210577957286
# 43 drugs done
# **************************************************
#
# HG6-64-1 (827, 17)
# Best CV score (RMSE): 0.16644470069182546
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.25}
#
# RMSE on training data: 0.16332337206603603
# Correlation with the training set: (0.3228136482969864, 1.7455393008656633e-15)
#
# RMSE on test data: 0.17309689296574182
# Mean absolute error on test data: 0.1332532151577261
# Correlation with the test set: (0.2674921764087709, 1.886410841849088e-05)
#
# Dummy CV RMSE: 0.17176437755173146
# Dummy test RMSE: 0.1792919927451297
# 44 drugs done
# **************************************************
#
# JQ1 (880, 19)
# Best CV score (RMSE): 0.15644946291341302
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.75}
#
# RMSE on training data: 0.1548706157462846
# Correlation with the training set: (0.2618146673024647, 4.102074040077392e-11)
#
# RMSE on test data: 0.1536418359119132
# Mean absolute error on test data: 0.12744278523507765
# Correlation with the test set: (0.21677333289571435, 0.0003885909482118728)
#
# Dummy CV RMSE: 0.1596049972214671
# Dummy test RMSE: 0.15741980210993448
# 45 drugs done
# **************************************************
#
# JQ12 (874, 17)
# Best CV score (RMSE): 0.16395859783432432
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.25}
#
# RMSE on training data: 0.16123198762931554
# Correlation with the training set: (0.27071610166516746, 1.0073347155399685e-11)
#
# RMSE on test data: 0.15827428429088608
# Mean absolute error on test data: 0.1277783889965341
# Correlation with the test set: (0.21314114139293033, 0.0005010791283024402)
#
# Dummy CV RMSE: 0.16698174502464552
# Dummy test RMSE: 0.1619104537464577
# 46 drugs done
# **************************************************
#
# AKT inhibitor VIII (823, 21)
# Best CV score (RMSE): 0.055443662083053194
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.25}
#
# RMSE on training data: 0.054273114897791755
# Correlation with the training set: (0.34921771890645703, 5.801301794639626e-18)
#
# RMSE on test data: 0.04897466626721131
# Mean absolute error on test data: 0.03627396476281454
# Correlation with the test set: (0.305907497363247, 9.519043397445755e-07)
#
# Dummy CV RMSE: 0.05656020274916548
# Dummy test RMSE: 0.05137066268944948
# 47 drugs done
# **************************************************
#
# Embelin (872, 16)
# Best CV score (RMSE): 0.09972834814488545
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.5}
#
# RMSE on training data: 0.09881478068951753
# Correlation with the training set: (0.21564192839396554, 7.51325781357454e-08)
#
# RMSE on test data: 0.09914180083460641
# Mean absolute error on test data: 0.0797680878615569
# Correlation with the test set: (0.1697093460814709, 0.005889781132126879)
#
# Dummy CV RMSE: 0.10091651174954239
# Dummy test RMSE: 0.10061578452658965
# 48 drugs done
# **************************************************
#
# IPA-3 (847, 17)
# Best CV score (RMSE): 0.10910345810554614
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.25}
#
# RMSE on training data: 0.10727811716647932
# Correlation with the training set: (0.3767933038956921, 2.0828272057401555e-21)
#
# RMSE on test data: 0.10109349795270281
# Mean absolute error on test data: 0.08503022684801867
# Correlation with the test set: (0.3536267096566076, 6.323700422011487e-09)
#
# Dummy CV RMSE: 0.11554733462424702
# Dummy test RMSE: 0.10826747234358583
# 49 drugs done
# **************************************************
#
# GSK650394 (840, 18)
# Best CV score (RMSE): 0.12322251888888554
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.12055355928670565
# Correlation with the training set: (0.24635141578714687, 1.4081226808594089e-09)
#
# RMSE on test data: 0.1329498870525426
# Mean absolute error on test data: 0.10431616956786285
# Correlation with the test set: (0.050336132937566586, 0.42626854677743187)
#
# Dummy CV RMSE: 0.12276933885999448
# Dummy test RMSE: 0.13278689007462469
# 50 drugs done
# **************************************************
#
# BAY-61-3606 (868, 16)
# Best CV score (RMSE): 0.12031823203543288
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.25}
#
# RMSE on training data: 0.11766309664340938
# Correlation with the training set: (0.33437763072019916, 2.5374734556424417e-17)
#
# RMSE on test data: 0.11945518618070794
# Mean absolute error on test data: 0.09485343276116401
# Correlation with the test set: (0.30441944256763875, 5.332470516825406e-07)
#
# Dummy CV RMSE: 0.12403865611892913
# Dummy test RMSE: 0.12531902985171142
# 51 drugs done
# **************************************************
#
# 5-Fluorouracil (888, 18)
# Best CV score (RMSE): 0.15613371254744082
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.5}
#
# RMSE on training data: 0.15331444597563842
# Correlation with the training set: (0.43716727083952056, 2.255705418443646e-30)
#
# RMSE on test data: 0.14196130625340053
# Mean absolute error on test data: 0.11204908945677244
# Correlation with the test set: (0.5472330971912304, 2.9345389651888957e-22)
#
# Dummy CV RMSE: 0.16943702739095318
# Dummy test RMSE: 0.16615080222722112
# 52 drugs done
# **************************************************
#
# Obatoclax Mesylate (841, 18)
# Best CV score (RMSE): 0.2213465693038503
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.75}
#
# RMSE on training data: 0.2168211684786223
# Correlation with the training set: (0.3272659063419741, 3.8172858039846587e-16)
#
# RMSE on test data: 0.20690007715989392
# Mean absolute error on test data: 0.17003138173953783
# Correlation with the test set: (0.3302753652025853, 7.488546885667577e-08)
#
# Dummy CV RMSE: 0.22793456850508434
# Dummy test RMSE: 0.2183557776391087
# 53 drugs done
# **************************************************
#
# BMS-754807 (844, 17)
# Best CV score (RMSE): 0.1627545852797875
# Best parameters: {'estimator__alpha': 0.1, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.15887651141088896
# Correlation with the training set: (0.4015888230755608, 2.8438866321086986e-24)
#
# RMSE on test data: 0.17812900422045172
# Mean absolute error on test data: 0.13011141028176185
# Correlation with the test set: (0.37919279763309305, 4.145702011380296e-10)
#
# Dummy CV RMSE: 0.1728082069857379
# Dummy test RMSE: 0.1926638198333312
# 54 drugs done
# **************************************************
#
# Linsitinib (844, 17)
# Best CV score (RMSE): 0.10270597669773356
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.25}
#
# RMSE on training data: 0.10066303285037045
# Correlation with the training set: (0.37121763608480274, 1.0264329912176457e-20)
#
# RMSE on test data: 0.11857912968895093
# Mean absolute error on test data: 0.07283737542958424
# Correlation with the test set: (0.372503366893451, 8.818003855972545e-10)
#
# Dummy CV RMSE: 0.10638652253161134
# Dummy test RMSE: 0.12708357300187606
# 55 drugs done
# **************************************************
#
# Bexarotene (860, 18)
# Best CV score (RMSE): 0.06978750990492201
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.5}
#
# RMSE on training data: 0.06962225646934332
# Correlation with the training set: (0.10570228724067167, 0.009449124447557853)
#
# RMSE on test data: 0.05790302682243126
# Mean absolute error on test data: 0.040924406103019305
# Correlation with the test set: (0.0858509635786531, 0.16918906155605312)
#
# Dummy CV RMSE: 0.06612105857674619
# Dummy test RMSE: 0.05806351077593512
# 56 drugs done
# **************************************************
#
# LFM-A13 (870, 16)
# Best CV score (RMSE): 0.0274821048275319
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.1}
#
# RMSE on training data: 0.027062641386814017
# Correlation with the training set: (0.2477271440394502, 5.729720694638836e-10)
#
# RMSE on test data: 0.025362919934245207
# Mean absolute error on test data: 0.01894604418182987
# Correlation with the test set: (0.3009580675788297, 7.265714202224206e-07)
#
# Dummy CV RMSE: 0.027478190748420388
# Dummy test RMSE: 0.026531110243537572
# 57 drugs done
# **************************************************
#
# GW-2580 (922, 16)
# Best CV score (RMSE): 0.03690243754836828
# Best parameters: {'estimator__alpha': 0.1, 'estimator__l1_ratio': 0.25}
#
# RMSE on training data: 0.03685703063758757
# Correlation with the training set: (4.763545779305672e-16, 1.0)
#
# RMSE on test data: 0.018098987412116553
# Mean absolute error on test data: 0.010813407673579035
# Correlation with the test set: (nan, 1.0)
#
# Dummy CV RMSE: 0.026696379894553403
# Dummy test RMSE: 0.018098987412116553
# 58 drugs done
# **************************************************
#
# Phenformin (887, 19)
# Best CV score (RMSE): 0.18689340020072936
# Best parameters: {'estimator__alpha': 0.1, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.1834954227631747
# Correlation with the training set: (0.4585768333833777, 1.443129150363376e-33)
#
# RMSE on test data: 0.18767739192234453
# Mean absolute error on test data: 0.14279472982001623
# Correlation with the test set: (0.39883239515009433, 1.2935099273724287e-11)
#
# Dummy CV RMSE: 0.20609000110223025
# Dummy test RMSE: 0.2046909852581266
# 59 drugs done
# **************************************************
#
# Pazopanib (814, 33)
# Best CV score (RMSE): 0.07757860676246352
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.25}
#
# RMSE on training data: 0.07513887725065724
# Correlation with the training set: (0.33016344602799774, 6.157941391460486e-16)
#
# RMSE on test data: 0.12126718865703387
# Mean absolute error on test data: 0.06728019867522766
# Correlation with the test set: (0.3413428018748805, 4.228301044683707e-08)
#
# Dummy CV RMSE: 0.07832874775550738
# Dummy test RMSE: 0.1268282281909517
# 60 drugs done
# **************************************************
#
# Dacinostat (872, 16)
# Best CV score (RMSE): 0.15689792006051462
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.5}
#
# RMSE on training data: 0.15532402026218553
# Correlation with the training set: (0.38079798623566474, 1.7442763848611542e-22)
#
# RMSE on test data: 0.1553439237159153
# Mean absolute error on test data: 0.11940924092127692
# Correlation with the test set: (0.3358561428039123, 2.5034421372713134e-08)
#
# Dummy CV RMSE: 0.16764569637815901
# Dummy test RMSE: 0.1650067198534384
# 61 drugs done
# **************************************************
#
# Epothilone B (848, 29)
# Best CV score (RMSE): 0.21324209923828247
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.2084487589525925
# Correlation with the training set: (0.29165961663642426, 4.308306775677904e-13)
#
# RMSE on test data: 0.21010067860486456
# Mean absolute error on test data: 0.17878608992766173
# Correlation with the test set: (0.19587130548393888, 0.0016725640706163128)
#
# Dummy CV RMSE: 0.21593392715682774
# Dummy test RMSE: 0.21388180712075974
# 62 drugs done
# **************************************************
#
# GSK1904529A (848, 17)
# Best CV score (RMSE): 0.023761995628162422
# Best parameters: {'estimator__alpha': 0.001, 'estimator__l1_ratio': 1.0}
#
# RMSE on training data: 0.02330296051182583
# Correlation with the training set: (0.2909708941120131, 4.915503991743069e-13)
#
# RMSE on test data: 0.021146173780356603
# Mean absolute error on test data: 0.013401873137647244
# Correlation with the test set: (0.14049229531011453, 0.024858222589649998)
#
# Dummy CV RMSE: 0.02346161748300864
# Dummy test RMSE: 0.021202418220412227
# 63 drugs done
# **************************************************
#
# Ruxolitinib (896, 19)
# Best CV score (RMSE): 0.05351966009437878
# Best parameters: {'estimator__alpha': 0.1, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.05257677202820182
# Correlation with the training set: (0.3155743070417014, 5.776967241383928e-16)
#
# RMSE on test data: 0.060916354182310596
# Mean absolute error on test data: 0.02000261036680029
# Correlation with the test set: (0.39613411674623655, 1.5327923854827167e-11)
#
# Dummy CV RMSE: 0.046279052961152686
# Dummy test RMSE: 0.06553323268696308
# 64 drugs done
# **************************************************
#
# AT-7519 (893, 22)
# Best CV score (RMSE): 0.1959353645421956
# Best parameters: {'estimator__alpha': 0.1, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.1900056995672912
# Correlation with the training set: (0.5549785824724687, 8.94348186623152e-52)
#
# RMSE on test data: 0.19250203038894073
# Mean absolute error on test data: 0.1622985957461543
# Correlation with the test set: (0.5342752987812556, 3.49695963071981e-21)
#
# Dummy CV RMSE: 0.22779982509785116
# Dummy test RMSE: 0.22772762941589075
# 65 drugs done
# **************************************************
#
# AS605240 (918, 16)
# Best CV score (RMSE): 0.16797682687969856
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.5}
#
# RMSE on training data: 0.1655844835051317
# Correlation with the training set: (0.3585994789530424, 6.4601423106220275e-21)
#
# RMSE on test data: 0.14809804590838982
# Mean absolute error on test data: 0.1106289350708579
# Correlation with the test set: (0.31220236914683724, 1.1828694882281112e-07)
#
# Dummy CV RMSE: 0.1743373242147541
# Dummy test RMSE: 0.15585832017835294
# 66 drugs done
# **************************************************
#
# Genentech Cpd 10 (897, 18)
# Best CV score (RMSE): 0.14475042945045433
# Best parameters: {'estimator__alpha': 0.1, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.14176608119346568
# Correlation with the training set: (0.5014839224244446, 3.0830913213870993e-41)
#
# RMSE on test data: 0.13468399716048474
# Mean absolute error on test data: 0.10181592764053163
# Correlation with the test set: (0.37587726891891415, 1.7337957831914246e-10)
#
# Dummy CV RMSE: 0.16307297781991936
# Dummy test RMSE: 0.14377718619600263
# 67 drugs done
# **************************************************
#
# GSK1070916 (869, 18)
# Best CV score (RMSE): 0.1957142986257846
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.25}
#
# RMSE on training data: 0.19228318439731779
# Correlation with the training set: (0.46732305562760557, 2.595665348122147e-34)
#
# RMSE on test data: 0.20292441254932955
# Mean absolute error on test data: 0.12299930951531457
# Correlation with the test set: (0.41915639690120216, 1.579773810770772e-12)
#
# Dummy CV RMSE: 0.2156021199597688
# Dummy test RMSE: 0.2229012951462211
# 68 drugs done
# **************************************************
#
# AKT inhibitor VIII (863, 21)
# Best CV score (RMSE): 0.11315475434747263
# Best parameters: {'estimator__alpha': 0.1, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.10972336776034632
# Correlation with the training set: (0.569175194681875, 3.7743333849389926e-53)
#
# RMSE on test data: 0.11942842457760701
# Mean absolute error on test data: 0.08788714459393156
# Correlation with the test set: (0.5444951409073977, 2.148266002255343e-21)
#
# Dummy CV RMSE: 0.13304914826916497
# Dummy test RMSE: 0.14194518450442792
# 69 drugs done
# **************************************************
#
# GSK429286A (897, 18)
# Best CV score (RMSE): 0.07151395028211913
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.1}
#
# RMSE on training data: 0.07065517846124016
# Correlation with the training set: (0.31105729847772334, 1.562198919372402e-15)
#
# RMSE on test data: 0.05397272567057383
# Mean absolute error on test data: 0.03238576220965604
# Correlation with the test set: (0.31824321475242906, 9.061436253009136e-08)
#
# Dummy CV RMSE: 0.07122161778456834
# Dummy test RMSE: 0.0572091068889053
# 70 drugs done
# **************************************************
#
# QL-XII-47 (920, 17)
# Best CV score (RMSE): 0.17920699448655195
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 1.0}
#
# RMSE on training data: 0.17791731976913056
# Correlation with the training set: (0.34823231210415373, 8.504592487022826e-20)
#
# RMSE on test data: 0.17618665785227106
# Mean absolute error on test data: 0.1489070138425629
# Correlation with the test set: (0.31934086259931654, 5.831632418483251e-08)
#
# Dummy CV RMSE: 0.18939399408843777
# Dummy test RMSE: 0.18598576178682436
# 71 drugs done
# **************************************************
#
# Cabozantinib (861, 29)
# Best CV score (RMSE): 0.0960487197232881
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.5}
#
# RMSE on training data: 0.09293610829860643
# Correlation with the training set: (0.5355622091031473, 5.502850369354655e-46)
#
# RMSE on test data: 0.09070874766624956
# Mean absolute error on test data: 0.059013731790774064
# Correlation with the test set: (0.15431024534736495, 0.012908425258194016)
#
# Dummy CV RMSE: 0.10739583602223746
# Dummy test RMSE: 0.08557861773830903
# 72 drugs done
# **************************************************
#
# WZ3105 (863, 26)
# Best CV score (RMSE): 0.14759652326546502
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.25}
#
# RMSE on training data: 0.14106912416499023
# Correlation with the training set: (0.5680973123686397, 6.523440257151027e-53)
#
# RMSE on test data: 0.15460517262554285
# Mean absolute error on test data: 0.11598662559288557
# Correlation with the test set: (0.4751438502275426, 5.426841156753729e-16)
#
# Dummy CV RMSE: 0.170161751013408
# Dummy test RMSE: 0.17569371607430592
# 73 drugs done
# **************************************************
#
# XMD14-99 (863, 20)
# Best CV score (RMSE): 0.03236165669099342
# Best parameters: {'estimator__alpha': 0.001, 'estimator__l1_ratio': 0.9}
#
# RMSE on training data: 0.031140330043534833
# Correlation with the training set: (0.492879603401586, 2.7346556239738936e-38)
#
# RMSE on test data: 0.02357134689514105
# Mean absolute error on test data: 0.016695701315940267
# Correlation with the test set: (0.5380473699346152, 7.72835457479878e-21)
#
# Dummy CV RMSE: 0.03504344826881377
# Dummy test RMSE: 0.0278696816721942
# 74 drugs done
# **************************************************
#
# Quizartinib (862, 18)
# Best CV score (RMSE): 0.06928761371299713
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.5}
#
# RMSE on training data: 0.06602187977623203
# Correlation with the training set: (0.5484418004404928, 1.1924036777144149e-48)
#
# RMSE on test data: 0.06162454293095513
# Mean absolute error on test data: 0.027256840157852905
# Correlation with the test set: (0.42669250555775656, 6.973729498829642e-13)
#
# Dummy CV RMSE: 0.06950554028064093
# Dummy test RMSE: 0.06685671494251601
# 75 drugs done
# **************************************************
#
# CP724714 (863, 18)
# Best CV score (RMSE): 0.04634746207239535
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.25}
#
# RMSE on training data: 0.04446048118924148
# Correlation with the training set: (0.5637565433204812, 5.789722889353137e-52)
#
# RMSE on test data: 0.04994821610422197
# Mean absolute error on test data: 0.023078554763091584
# Correlation with the test set: (0.3326551107059051, 4.142277520137907e-08)
#
# Dummy CV RMSE: 0.04788330134872616
# Dummy test RMSE: 0.05271661695848376
# 76 drugs done
# **************************************************
#
# JW-7-24-1 (922, 16)
# Best CV score (RMSE): 0.140481524169621
# Best parameters: {'estimator__alpha': 0.1, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.13692514679789963
# Correlation with the training set: (0.5466053556746762, 1.5888980860911983e-51)
#
# RMSE on test data: 0.1326888308733486
# Mean absolute error on test data: 0.10229961638830326
# Correlation with the test set: (0.5488368066530132, 3.431847727304178e-23)
#
# Dummy CV RMSE: 0.16317589558898093
# Dummy test RMSE: 0.1579922232905281
# 77 drugs done
# **************************************************
#
# NPK76-II-72-1 (920, 16)
# Best CV score (RMSE): 0.11894068796113079
# Best parameters: {'estimator__alpha': 0.001, 'estimator__l1_ratio': 1.0}
#
# RMSE on training data: 0.11731613612413154
# Correlation with the training set: (0.5776851501103962, 1.3451594110743646e-58)
#
# RMSE on test data: 0.12506766305221015
# Mean absolute error on test data: 0.0914816621983993
# Correlation with the test set: (0.5263783342095427, 4.499883606899695e-21)
#
# Dummy CV RMSE: 0.1426767002797506
# Dummy test RMSE: 0.1469115442441061
# 78 drugs done
# **************************************************
#
# NG-25 (920, 16)
# Best CV score (RMSE): 0.12902137983467182
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 1.0}
#
# RMSE on training data: 0.1281575097709449
# Correlation with the training set: (0.5362983272886722, 3.077563813677962e-49)
#
# RMSE on test data: 0.14401296530997018
# Mean absolute error on test data: 0.09802933062796665
# Correlation with the test set: (0.5250206027693753, 5.91107832450984e-21)
#
# Dummy CV RMSE: 0.14888523979781804
# Dummy test RMSE: 0.1698858447001442
# 79 drugs done
# **************************************************
#
# FR-180204 (894, 17)
# Best CV score (RMSE): 0.038105025951356404
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.1}
#
# RMSE on training data: 0.037682153050654726
# Correlation with the training set: (0.1836476443147215, 3.8122990926034267e-06)
#
# RMSE on test data: 0.028459172893595223
# Mean absolute error on test data: 0.021127318731527702
# Correlation with the test set: (0.19197288074748958, 0.001559371323682443)
#
# Dummy CV RMSE: 0.03587032622283391
# Dummy test RMSE: 0.029007109713656637
# 80 drugs done
# **************************************************
#
# Tubastatin A (917, 18)
# Best CV score (RMSE): 0.06723509278219755
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.25}
#
# RMSE on training data: 0.06618358512356934
# Correlation with the training set: (0.5451170259862215, 6.80848594029099e-51)
#
# RMSE on test data: 0.06235741590182193
# Mean absolute error on test data: 0.04432694385932077
# Correlation with the test set: (0.40075075800730237, 4.524699488804062e-12)
#
# Dummy CV RMSE: 0.07717418079351494
# Dummy test RMSE: 0.06689630506493317
# 81 drugs done
# **************************************************
#
# Sepantronium bromide (888, 16)
# Best CV score (RMSE): 0.2524845343328933
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 1.0}
#
# RMSE on training data: 0.248511113726019
# Correlation with the training set: (0.29491326349633284, 6.291114539120369e-14)
#
# RMSE on test data: 0.2576211266222394
# Mean absolute error on test data: 0.19538624133547272
# Correlation with the test set: (0.22625256577192498, 0.00019292085359920447)
#
# Dummy CV RMSE: 0.2566428672314717
# Dummy test RMSE: 0.2644383733127208
# 82 drugs done
# **************************************************
#
# NSC-207895 (889, 17)
# Best CV score (RMSE): 0.09329479593389664
# Best parameters: {'estimator__alpha': 0.1, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.09156850833493328
# Correlation with the training set: (0.2797828846096563, 1.1934391085438794e-12)
#
# RMSE on test data: 0.09455914278888776
# Mean absolute error on test data: 0.06971096636984421
# Correlation with the test set: (0.2732809826081907, 5.869345973705776e-06)
#
# Dummy CV RMSE: 0.09476259932354357
# Dummy test RMSE: 0.09826825567670788
# 83 drugs done
# **************************************************
#
# AR-42 (911, 16)
# Best CV score (RMSE): 0.18385791360354808
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 1.0}
#
# RMSE on training data: 0.18184582074923122
# Correlation with the training set: (0.4568367572669943, 3.642708367476378e-34)
#
# RMSE on test data: 0.18472992813652847
# Mean absolute error on test data: 0.1470460976123772
# Correlation with the test set: (0.48957349973342895, 6.3809875347310374e-18)
#
# Dummy CV RMSE: 0.2036208968439277
# Dummy test RMSE: 0.2116218537363952
# 84 drugs done
# **************************************************
#
# CUDC-101 (844, 21)
# Best CV score (RMSE): 0.1876645366251393
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 1.0}
#
# RMSE on training data: 0.1861385534142208
# Correlation with the training set: (0.47328650436732916, 2.8757818571705706e-34)
#
# RMSE on test data: 0.20409303124318084
# Mean absolute error on test data: 0.16794776302704417
# Correlation with the test set: (0.36505884603645883, 2.0019238189274906e-09)
#
# Dummy CV RMSE: 0.21046780694350714
# Dummy test RMSE: 0.2194496671441799
# 85 drugs done
# ...
#
# Dummy CV RMSE: 0.07374101808473636
# Dummy test RMSE: 0.07256863115542375
# 156 drugs done
# **************************************************
#
# HG-5-113-01 (484, 17)
# Best CV score (RMSE): 0.10208320799382874
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.09948150578350645
# Correlation with the training set: (0.31175271033049035, 4.716636302571963e-09)
#
# RMSE on test data: 0.09626667988186569
# Mean absolute error on test data: 0.07678308837451449
# Correlation with the test set: (0.2625857989536886, 0.0013650354389746278)
#
# Dummy CV RMSE: 0.10279531797147871
# Dummy test RMSE: 0.09915311198570526
# 157 drugs done
# **************************************************
#
# HG-5-88-01 (466, 18)
# Best CV score (RMSE): 0.0912233919870916
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.5}
#
# RMSE on training data: 0.09001295598330487
# Correlation with the training set: (0.23489553433778315, 1.8277131302930955e-05)
#
# RMSE on test data: 0.07789839102233835
# Mean absolute error on test data: 0.057222859467590204
# Correlation with the test set: (0.27955357017449567, 0.0008227774790557537)
#
# Dummy CV RMSE: 0.08921817095748207
# Dummy test RMSE: 0.08033068100786066
# 158 drugs done
# **************************************************
#
# TW 37 (897, 18)
# Best CV score (RMSE): 0.15007216669747372
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.25}
#
# RMSE on training data: 0.14643145720628528
# Correlation with the training set: (0.31217449183350887, 1.2233999022436937e-15)
#
# RMSE on test data: 0.15073416822331787
# Mean absolute error on test data: 0.12150320549194339
# Correlation with the test set: (0.29654169276600084, 6.972370447522843e-07)
#
# Dummy CV RMSE: 0.15373504653635958
# Dummy test RMSE: 0.15763401563181562
# 159 drugs done
# **************************************************
#
# XMD11-85h (484, 22)
# Best CV score (RMSE): 0.03589713596112236
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.25}
#
# RMSE on training data: 0.03543271901007396
# Correlation with the training set: (0.2369913443765178, 1.0637749180595372e-05)
#
# RMSE on test data: 0.04128504975041313
# Mean absolute error on test data: 0.03102906619057723
# Correlation with the test set: (0.12004525869869753, 0.14894468188034946)
#
# Dummy CV RMSE: 0.035802186547836685
# Dummy test RMSE: 0.04160704352960276
# 160 drugs done
# **************************************************
#
# XMD8-92 (496, 16)
# Best CV score (RMSE): 0.051005764388221915
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.050024224085545625
# Correlation with the training set: (0.2517506235925505, 2.040372007078946e-06)
#
# RMSE on test data: 0.06547382657159842
# Mean absolute error on test data: 0.0502589247911224
# Correlation with the test set: (0.19888285262723546, 0.015033495947549646)
#
# Dummy CV RMSE: 0.05113506449900489
# Dummy test RMSE: 0.06661462685456723
# 161 drugs done
# **************************************************
#
# QL-VIII-58 (469, 19)
# Best CV score (RMSE): 0.1835951649229674
# Best parameters: {'estimator__alpha': 0.1, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.1772590128660933
# Correlation with the training set: (0.3546042792164669, 3.7460069957657026e-11)
#
# RMSE on test data: 0.2027926431760528
# Mean absolute error on test data: 0.16134858518616157
# Correlation with the test set: (0.2561732701427106, 0.002168389398812609)
#
# Dummy CV RMSE: 0.18949098816844553
# Dummy test RMSE: 0.20967592185661676
# 162 drugs done
# **************************************************
#
# CCT-018159 (876, 19)
# Best CV score (RMSE): 0.06125836961090846
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.25}
#
# RMSE on training data: 0.06069164477193096
# Correlation with the training set: (0.20523022792053944, 2.9667405463647417e-07)
#
# RMSE on test data: 0.05489169701072197
# Mean absolute error on test data: 0.04547626445877538
# Correlation with the test set: (0.26182424048468594, 1.6993901291386465e-05)
#
# Dummy CV RMSE: 0.0606084679460822
# Dummy test RMSE: 0.05629309545239687
# 163 drugs done
# **************************************************
#
# Rucaparib (898, 19)
# Best CV score (RMSE): 0.038506860512437784
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.03778522376331036
# Correlation with the training set: (0.27524826234970806, 2.2186361290009176e-12)
#
# RMSE on test data: 0.041076205357745914
# Mean absolute error on test data: 0.026528665400148307
# Correlation with the test set: (0.3570896425256398, 1.5346285977944977e-09)
#
# Dummy CV RMSE: 0.03807637884400934
# Dummy test RMSE: 0.042824737883313466
# 164 drugs done
# **************************************************
#
# GSK269962A (906, 18)
# Best CV score (RMSE): 0.1259744312768609
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.1242558255325359
# Correlation with the training set: (0.24089445893664602, 8.031395717095136e-10)
#
# RMSE on test data: 0.11709738188003121
# Mean absolute error on test data: 0.08117692631269267
# Correlation with the test set: (0.17001121834227478, 0.004931417722068353)
#
# Dummy CV RMSE: 0.12605621511525153
# Dummy test RMSE: 0.11874190262382062
# 165 drugs done
# **************************************************
#
# Tamoxifen (906, 35)
# Best CV score (RMSE): 0.0270228618135337
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.1}
#
# RMSE on training data: 0.026489209272823517
# Correlation with the training set: (0.2487691165036067, 2.1308348814607544e-10)
#
# RMSE on test data: 0.034731419035383626
# Mean absolute error on test data: 0.017513460172375775
# Correlation with the test set: (0.04700138690826696, 0.4401004459296848)
#
# Dummy CV RMSE: 0.02594573458608332
# Dummy test RMSE: 0.0346393759598115
# 166 drugs done
# **************************************************
#
# QL-XII-61 (473, 17)
# Best CV score (RMSE): 0.07026310685237327
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.0679398642269802
# Correlation with the training set: (0.39267598458831937, 1.196903901806515e-13)
#
# RMSE on test data: 0.0629836844962041
# Mean absolute error on test data: 0.04863336707522938
# Correlation with the test set: (0.30628737775432097, 0.00020966516955333203)
#
# Dummy CV RMSE: 0.07145120571521582
# Dummy test RMSE: 0.06615286991974544
# 167 drugs done
# **************************************************
#
# JQ1 (917, 19)
# Best CV score (RMSE): 0.05934820538030496
# Best parameters: {'estimator__alpha': 0.1, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.058412775205483984
# Correlation with the training set: (0.38124278413584495, 1.321057762339937e-23)
#
# RMSE on test data: 0.07243000135344557
# Mean absolute error on test data: 0.04054757018526962
# Correlation with the test set: (0.2700007188014047, 5.364159414098639e-06)
#
# Dummy CV RMSE: 0.0609196686983598
# Dummy test RMSE: 0.0750874726359005
# 168 drugs done
# **************************************************
#
# PFI-1 (933, 16)
# Best CV score (RMSE): 0.07765571249363111
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.1}
#
# RMSE on training data: 0.0764195738847888
# Correlation with the training set: (0.3707197009452576, 1.0529595286602382e-22)
#
# RMSE on test data: 0.07658952854044404
# Mean absolute error on test data: 0.05917889607403275
# Correlation with the test set: (0.1944085067363655, 0.0010763269331256426)
#
# Dummy CV RMSE: 0.08203486385271641
# Dummy test RMSE: 0.07680926847141752
# 169 drugs done
# **************************************************
#
# IOX2 (907, 17)
# Best CV score (RMSE): 0.035266701722526
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.034970997402288956
# Correlation with the training set: (0.19467514645452227, 7.834104686401295e-07)
#
# RMSE on test data: 0.023723130765933992
# Mean absolute error on test data: 0.013042714448813044
# Correlation with the test set: (0.1580990704534911, 0.008878000730053228)
#
# Dummy CV RMSE: 0.02903474633596594
# Dummy test RMSE: 0.024034924100137713
# 170 drugs done
# **************************************************
#
# CHIR-99021 (893, 18)
# Best CV score (RMSE): 0.05394981367811582
# Best parameters: {'estimator__alpha': 0.1, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.05217646637157483
# Correlation with the training set: (0.3987093270894682, 3.014271206705586e-25)
#
# RMSE on test data: 0.05703220166458383
# Mean absolute error on test data: 0.04182636996385637
# Correlation with the test set: (0.2662534291135401, 9.943549301702114e-06)
#
# Dummy CV RMSE: 0.056011124265087364
# Dummy test RMSE: 0.05866612216471506
# 171 drugs done
# **************************************************
#
# Daporinad (879, 17)
# Best CV score (RMSE): 0.3128780701613941
# Best parameters: {'estimator__alpha': 0.1, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.30507244464761923
# Correlation with the training set: (0.5006390319156495, 2.5070416963098706e-40)
#
# RMSE on test data: 0.311345947359266
# Mean absolute error on test data: 0.2659807801762347
# Correlation with the test set: (0.4502443837503539, 1.3922061617648396e-14)
#
# Dummy CV RMSE: 0.3524317004988565
# Dummy test RMSE: 0.34970532259475623
# 172 drugs done
# **************************************************
#
# Talazoparib (893, 19)
# Best CV score (RMSE): 0.18532060655225438
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.18256443276149736
# Correlation with the training set: (0.27929198492651813, 1.1579724705474774e-12)
#
# RMSE on test data: 0.2044462622954332
# Mean absolute error on test data: 0.15215183169625468
# Correlation with the test set: (0.3527803466637468, 2.8441469642658557e-09)
#
# Dummy CV RMSE: 0.1877218292580048
# Dummy test RMSE: 0.21279913408575307
# 173 drugs done
# **************************************************
#
# UNC1215 (889, 17)
# Best CV score (RMSE): 0.009007768504091154
# Best parameters: {'estimator__alpha': 0.001, 'estimator__l1_ratio': 0.25}
#
# RMSE on training data: 0.008928398551360838
# Correlation with the training set: (0.19154409557718385, 1.4934312783147756e-06)
#
# RMSE on test data: 0.010485690802501169
# Mean absolute error on test data: 0.006591574563088989
# Correlation with the test set: (0.07684588504761292, 0.21070385266234629)
#
# Dummy CV RMSE: 0.0089190598534947
# Dummy test RMSE: 0.010511369029919155
# 174 drugs done
# **************************************************
#
# SGC0946 (888, 17)
# Best CV score (RMSE): 0.0135684252189221
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.013407397605881728
# Correlation with the training set: (0.22226151850402437, 2.1717113172988104e-08)
#
# RMSE on test data: 0.012971020859151363
# Mean absolute error on test data: 0.00753300112146652
# Correlation with the test set: (0.17268392966090979, 0.004658750498336787)
#
# Dummy CV RMSE: 0.01240508362453504
# Dummy test RMSE: 0.013151674779949636
# 175 drugs done
# **************************************************
#
# XAV939 (897, 17)
# Best CV score (RMSE): 0.041165894790903754
# Best parameters: {'estimator__alpha': 0.1, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.04018173675782093
# Correlation with the training set: (0.30718077691079265, 3.6194281285064284e-15)
#
# RMSE on test data: 0.053199886630219996
# Mean absolute error on test data: 0.033166205422861444
# Correlation with the test set: (0.18519938409301, 0.0022469092304364074)
#
# Dummy CV RMSE: 0.040374677605274516
# Dummy test RMSE: 0.054189988277318905
# 176 drugs done
# **************************************************
#
# PLX-4720 (870, 17)
# Best CV score (RMSE): 0.060382273504187275
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.1}
#
# RMSE on training data: 0.05881627884669048
# Correlation with the training set: (0.6695805688108089, 1.9108848571739038e-80)
#
# RMSE on test data: 0.06564911644025109
# Mean absolute error on test data: 0.03564354173555482
# Correlation with the test set: (0.6610647672399771, 3.653289332380535e-34)
#
# Dummy CV RMSE: 0.07604023043270192
# Dummy test RMSE: 0.08591011446770012
# 177 drugs done
# **************************************************
#
# Trametinib (850, 18)
# Best CV score (RMSE): 0.2638274487480144
# Best parameters: {'estimator__alpha': 0.1, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.25532055146298593
# Correlation with the training set: (0.4983552287712818, 1.1292585461438579e-38)
#
# RMSE on test data: 0.24053426615098053
# Mean absolute error on test data: 0.19679668799734176
# Correlation with the test set: (0.5139303711906852, 1.3651437933608725e-18)
#
# Dummy CV RMSE: 0.2943175344997806
# Dummy test RMSE: 0.28020135017140285
# 178 drugs done
# **************************************************
#
# Dabrafenib (823, 22)
# Best CV score (RMSE): 0.12659811018722064
# Best parameters: {'estimator__alpha': 0.1, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.12116412334168397
# Correlation with the training set: (0.7639043958731687, 2.839777565950319e-111)
#
# RMSE on test data: 0.1453356134353266
# Mean absolute error on test data: 0.0853462780143993
# Correlation with the test set: (0.7102940167275941, 3.124101513908695e-39)
#
# Dummy CV RMSE: 0.18470458862510783
# Dummy test RMSE: 0.20630954920273475
# 179 drugs done
# **************************************************
#
# Afatinib (862, 21)
# Best CV score (RMSE): 0.11948589819786107
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.5}
#
# RMSE on training data: 0.11713795834973954
# Correlation with the training set: (0.597185020610396, 1.504548248874512e-59)
#
# RMSE on test data: 0.14756388747803412
# Mean absolute error on test data: 0.08267779007886054
# Correlation with the test set: (0.6178196347787422, 1.1803689784781803e-28)
#
# Dummy CV RMSE: 0.14241186831264982
# Dummy test RMSE: 0.18171319894833393
# 180 drugs done
# **************************************************
#
# SN-38 (956, 16)
# Best CV score (RMSE): 0.18197496239143707
# Best parameters: {'estimator__alpha': 0.1, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.17848367659374753
# Correlation with the training set: (0.42300373863877, 2.022322905146593e-30)
#
# RMSE on test data: 0.19867794626756966
# Mean absolute error on test data: 0.16095712481949803
# Correlation with the test set: (0.27261982026576104, 2.766928503863535e-06)
#
# Dummy CV RMSE: 0.19648721909111883
# Dummy test RMSE: 0.2059482795580716
# 181 drugs done
# **************************************************
#
# Olaparib (884, 19)
# Best CV score (RMSE): 0.053407779755108103
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.1}
#
# RMSE on training data: 0.05228914731164847
# Correlation with the training set: (0.2732362627190461, 4.821865524630136e-12)
#
# RMSE on test data: 0.0631263247277073
# Mean absolute error on test data: 0.0398156460887064
# Correlation with the test set: (0.34063056590001495, 1.1928634717294151e-08)
#
# Dummy CV RMSE: 0.053134568035009544
# Dummy test RMSE: 0.06674051241538291
# 182 drugs done
# **************************************************
#
# Bicalutamide (880, 16)
# Best CV score (RMSE): 0.030090551251203697
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.25}
#
# RMSE on training data: 0.029936232737556478
# Correlation with the training set: (0.1587925715112143, 7.549632435448214e-05)
#
# RMSE on test data: 0.023103510850503974
# Mean absolute error on test data: 0.014005704166708063
# Correlation with the test set: (0.11370602935573386, 0.06507759503584512)
#
# Dummy CV RMSE: 0.026247146492701757
# Dummy test RMSE: 0.023211696033253387
# 183 drugs done
# **************************************************
#
# PFI-3 (800, 20)
# Best CV score (RMSE): 0.019206808357875072
# Best parameters: {'estimator__alpha': 5.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.019067647143827592
# Correlation with the training set: (0.20017375633147577, 1.798852922658472e-06)
#
# RMSE on test data: 0.019543243854041128
# Mean absolute error on test data: 0.010320482901433054
# Correlation with the test set: (0.10384983213676373, 0.10854284997807216)
#
# Dummy CV RMSE: 0.017743143385494237
# Dummy test RMSE: 0.019604059844441808
# 184 drugs done
# **************************************************

# %% [markdown]
# Save this Experiment instance

# %%
# Create a filename out of the Experiment's "name" field
filename = exp.name.lower().replace(" ", "_") + ".pkl"
# Save the instance
with open("../Created data/Results/" + filename, "wb") as f:
    dill.dump(exp, f)

# %% [markdown]
# ### RandomForestRegression with Z-score normalization for all features and randomized search for hyperparameter tuning - all data classes (expression, mutation, CNV, tissue) but without Merck gene expression signatures

# %% [markdown]
# Initialize dictionary with DrugWithDrugBank objects and compute input data for all drugs.

# %%
# Create drug objects
drugs = DrugWithDrugBank.create_drugs(drug_annotations_df, map_drugs_to_drugbank_targets)
print(len(drugs))

# Set up data types we want to include in our input for each drug
data_types = ["CNV", "mutation", "expression", "tissue"]
# Create input data
Experiment.create_input_for_each_drug(drugs, drug_response_df, data_combination=data_types, 
                                     gene_expression_df=gene_expression_df, 
                                     cnv_binary_df=cnv_binary_df,
                                     map_cl_id_and_feature_to_status=map_from_cl_id_and_genetic_feature_to_mutation_status,
                                     cell_lines_list_df=cell_lines_list_df,
                                     coding_variants_df=coding_variants_df,
                                     feat_threshold=16,
                                     log=True)
# Out:
# 267
# 10 drugs done
# 20 drugs done
# 30 drugs done
# 40 drugs done
# 50 drugs done
# 60 drugs done
# 70 drugs done
# 80 drugs done
# 90 drugs done
# 100 drugs done
# 110 drugs done
# 120 drugs done
# 130 drugs done
# 140 drugs done
# 150 drugs done
# 160 drugs done
# 170 drugs done
# 180 drugs done
# 190 drugs done
# 200 drugs done
# 210 drugs done
# 220 drugs done
# 230 drugs done
# 240 drugs done
# 250 drugs done
# 260 drugs done
# Number of drugs with number of features bigger than 16: 184
# Mean number of features in 267 drugs: 3.7265917602996255

# %%
#############################################################################################################
# Set up constants, feature normalization, predictive algorithm and initialize experiment instance
#############################################################################################################

log = True
counter = 0
sensitivity_metric = "AUC"
record_weights = False   # Does the model has coefficients we want to record?
n_folds = 5   # Number of folds in parameter tuning cross-validation
n_combinations = 20   # Number of parameter combinations to try (when using randomized search)

scaler = preprocessing.StandardScaler()   # Setup transformer for feature scaling

estimator = RandomForestRegressor()   # Setup algorithm to use

# Hyperparameter space to search on
# Number of trees in random forest
n_estimators = [10, 20, 50, 100, 200, 500]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [int(x) for x in np.linspace(2, 101, num = 10)]
# Minimum number of samples required at each leaf node
min_samples_leaf = [int(x) for x in np.linspace(2, 101, num = 10)]
# Method of selecting samples for training each tree
criterion = ["mse", "mae"]

# Create the param grid
param_grid = {'estimator__n_estimators': n_estimators,
               'estimator__max_features': max_features,
               'estimator__max_depth': max_depth,
               'estimator__min_samples_split': min_samples_split,
               'estimator__min_samples_leaf': min_samples_leaf,
               'estimator__criterion': criterion}

# Set up seeds for data split and randomized parameter tuning
split_seed = 37
tuning_seed = 53

# Function to be optimized during hyperparameter tuning
scoring = "neg_mean_squared_error"   # Function to be optimized by hyperparameters

# Initialize Experiment object for this assay
exp = Experiment(name="Only targets-Random Forest with Z-score normalization",
                algorithm="RandomForestRegressor",
                parameter_search_type="RandomizedSearch",
                data_normalization_type="StandardScaler on all features",
                kfolds=n_folds,
                split_seed=split_seed,
                tuning_seed=tuning_seed)

#############################################################################################################
# Enter the loop over drugs
#############################################################################################################

for ide in drugs:
    drug = drugs[ide]   # Current Drug object
    data = drug.full_data  # Extract input data (should be previously computed)
    if data.shape[0] == 0:   # Check if data exists, if not, skip the drug
        continue
    if data.shape[1] < 16:    # That means that data has only features related to tissue
        continue           # so also skip this case
        
    # Add input data to corresponding Experiment objects's field (dictionary)
    exp.input_data[(drug.name, ide)] = data
    if log:
        print(drug.name, data.shape)
        
    # Add data shapes to corresponding field in Experiment (dictionary)
    exp.data_shapes[(drug.name, ide)] = data.shape
    
    y = data[sensitivity_metric]   # Extract response variable
    X = data.drop(["cell_line_id", sensitivity_metric], axis=1)     # Drop targets and cell line IDs
    assert X.shape[0] == y.shape[0]   # Sanity check
    assert X.shape[1] < data.shape[1]
    
    # Split data into training and test set
    test_size = 0.3    # Fraction of data spent on test set
    X_val, X_test, y_val, y_test = model_selection.train_test_split(X, y, test_size=test_size,
                                                                   random_state=split_seed)
    
    # Record standard deviations of data
    # Create collections.collections.namedtuple for storing
    StandardDeviations = collections.namedtuple("StandardDeviations", ["validation", "test", "overall"])
    stds = StandardDeviations(y_val.std(), y_test.std(), y.std())
    # Record in corresponding field (dictionary)
    exp.data_stds[(drug.name, ide)] = stds    
    
    # Set up and fit Dummy Regressor
    dummy = DummyRegressor()
    dummy.fit(X_val, y_val)
    # Get dummy predictions on the test set
    dummy_preds = dummy.predict(X_test)
    # Baseline dummy performance
    baseline_scores = model_selection.cross_val_score(dummy, X_val, y_val, scoring=scoring, cv=n_folds)
    baseline_mean = np.mean([(-x)**0.5 for x in baseline_scores])
    baseline_std = np.std([(-x)**0.5 for x in baseline_scores])
    
    # Set elements of the pipeline, i.e. scaler and estimator
    transformer = clone(scaler)
    predictor = clone(estimator)   # Make a copy to ensure that for every drug we get "fresh" predictor
    
    # Create pipeline
    main_pipeline = Pipeline([
        ("scaler", transformer),
        ("estimator", predictor)
    ])    
    
#     # Set up grid search with cross-validation
#     grid = model_selection.GridSearchCV(main_pipeline, param_grid=param_grid, 
#                                        scoring=scoring, cv=n_folds)
    
    # Or use RandomizedSearch
    grid = model_selection.RandomizedSearchCV(main_pipeline, param_distributions=param_grid,
                                             n_iter=n_combinations, scoring=scoring, cv=n_folds,
                                             random_state=tuning_seed)
    
    # Fit the grid
    grid.fit(X_val, y_val)
    best = grid.best_estimator_   # Best model
    pred = grid.predict(X_test)   # Predict on test data with refitted best model
    training_preds = grid.predict(X_val)    # Predict on train data with refitted best model
    
    if log:   # Report the results
        # Summarize grid search
        print("Best CV score (RMSE):", (-grid.best_score_)**0.5)
        print("Best parameters:", grid.best_params_)
        print("")
        
        # Print out performance of the best model on training set
        print("RMSE on training data:", metrics.mean_squared_error(y_val, training_preds)**0.5)
        print("Correlation with the training set:", pearsonr(y_val, training_preds))
        print("")
        
        # Print out the performance of the best model on test set
        print("RMSE on test data:", metrics.mean_squared_error(y_test, pred) ** 0.5)
        print("Mean absolute error on test data:", metrics.mean_absolute_error(y_test, pred))
        print("Correlation with the test set:", pearsonr(y_test, pred))
        print("")
        
        # Print out performance of dummy regressor
        print("Dummy CV RMSE:", baseline_mean)
        print("Dummy test RMSE:", metrics.mean_squared_error(y_test, dummy_preds) ** 0.5)
        
    # Record results in corresponding Experiment fields, mostly as named tuples
    # Classification performance
    ModelTestScores = collections.namedtuple("ModelTestScores", ["cv_best_score", "test_RMSE",
                                                    "test_explained_variance", "test_correlation"])
    model_test_scores = ModelTestScores(grid.best_score_, metrics.mean_squared_error(y_test, pred) ** 0.5,
                                       metrics.explained_variance_score(y_test, pred), pearsonr(y_test, pred))
    # Record in appropriate field (dictionary)
    exp.best_scores[(drug.name, ide)] = model_test_scores
    
    # Full results of cross-validation tuning
    exp.cv_results[(drug.name, ide)] = grid.cv_results_
    
    # Parameters of best found model
    exp.best_parameters[(drug.name, ide)] = grid.best_params_
    
    # Coefficients (if model has them)
    if record_weights:
        BestModelWeights = collections.namedtuple("BestModelWeights", ["intercept", "weights_array"])
        best_model_weights = BestModelWeights(best.named_steps["estimator"].intercept_,
                                         best.named_steps["estimator"].coef_)
        # Record in appropriate field (dictionary)
        exp.coefficients[(drug.name, ide)] = best_model_weights
    
    # Performance on the training set
    ModelTrainingScores = collections.namedtuple("ModelTrainingScores", ["training_RMSE", "training_correlation"])
    model_training_scores = ModelTrainingScores(metrics.mean_squared_error(y_val, training_preds) ** 0.5,
                                               pearsonr(y_val, training_preds))
    # Record in appropriate field (dictionary)
    exp.training_scores[(drug.name, ide)] = model_training_scores
    
    # Performance of dummy model
    DummyScores = collections.namedtuple("DummyScores", ["cv_RMSE", "test_RMSE", "test_explained_variance",
                                            "test_correlation"])
    dummy_performance = DummyScores(baseline_mean, metrics.mean_squared_error(y_test, dummy_preds) ** 0.5,
                                   metrics.explained_variance_score(y_test, dummy_preds),
                                   pearsonr(y_test, dummy_preds))
    # Record in appropriate field (dictionary)
    exp.dummy_scores[(drug.name, ide)] = dummy_performance
    
    # Increment counter and display summary information
    counter += 1
    if log:
        print(counter, "drugs done")
        print("*" * 50)
        print("")
# Out:
# Erlotinib (347, 19)
# Best CV score (RMSE): 0.08192895188001664
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.07789852663734911
# Correlation with the training set: (0.4859686225513045, 9.529330929220756e-16)
#
# RMSE on test data: 0.06264247825828283
# Mean absolute error on test data: 0.03841156290849046
# Correlation with the test set: (0.48350898063643905, 1.7441774498702933e-07)
#
# Dummy CV RMSE: 0.08390702315605628
# Dummy test RMSE: 0.07096557172657372
# 1 drugs done
# **************************************************
#
# Rapamycin (362, 16)
# Best CV score (RMSE): 0.22786238423760885
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.21616871837848672
# Correlation with the training set: (0.3577516437999795, 4.707236948870702e-09)
#
# RMSE on test data: 0.23889369480916556
# Mean absolute error on test data: 0.17214156851123955
# Correlation with the test set: (0.06340026995490959, 0.5125022243311572)
#
# Dummy CV RMSE: 0.22557290892076653
# Dummy test RMSE: 0.2381718975951265
# 2 drugs done
# **************************************************
#
# Sunitinib (372, 31)
# Best CV score (RMSE): 0.11186814396975817
# Best parameters: {'estimator__n_estimators': 500, 'estimator__min_samples_split': 68, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'auto', 'estimator__max_depth': 30, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.096422788300989
# Correlation with the training set: (0.7816042444124417, 8.294988036158803e-55)
#
# RMSE on test data: 0.13783821587853246
# Mean absolute error on test data: 0.08593081913583252
# Correlation with the test set: (0.4067100641929428, 8.592958338328594e-06)
#
# Dummy CV RMSE: 0.14989000226971028
# Dummy test RMSE: 0.1443592045996043
# 3 drugs done
# **************************************************
#
# PHA-665752 (380, 18)
# Best CV score (RMSE): 0.06066006412848734
# Best parameters: {'estimator__n_estimators': 500, 'estimator__min_samples_split': 68, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'auto', 'estimator__max_depth': 30, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.05196459899413777
# Correlation with the training set: (0.5347392623003951, 4.478077178719962e-21)
#
# RMSE on test data: 0.028022921454282073
# Mean absolute error on test data: 0.019190398142135846
# Correlation with the test set: (0.09324691658870987, 0.32374832766308903)
#
# Dummy CV RMSE: 0.05541861281587431
# Dummy test RMSE: 0.02745025502562561
# 4 drugs done
# **************************************************
#
# MG-132 (400, 16)
# Best CV score (RMSE): 0.12506310003375956
# Best parameters: {'estimator__n_estimators': 500, 'estimator__min_samples_split': 68, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'auto', 'estimator__max_depth': 30, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.11476132714434978
# Correlation with the training set: (0.4932107092455869, 1.431003409149727e-18)
#
# RMSE on test data: 0.12744799086125555
# Mean absolute error on test data: 0.09961986103927624
# Correlation with the test set: (0.27051002590852735, 0.0028063309747928425)
#
# Dummy CV RMSE: 0.13039212969199462
# Dummy test RMSE: 0.13160617243829892
# 5 drugs done
# **************************************************
#
# Paclitaxel (388, 22)
# Best CV score (RMSE): 0.1932696829142721
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 79, 'estimator__min_samples_leaf': 13, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mae'}
#
# RMSE on training data: 0.1837596220802065
# Correlation with the training set: (0.42027501868039757, 5.051336655268424e-13)
#
# RMSE on test data: 0.19343844179051134
# Mean absolute error on test data: 0.168316327948718
# Correlation with the test set: (0.19568322946468317, 0.034481222640084026)
#
# Dummy CV RMSE: 0.19744735945789274
# Dummy test RMSE: 0.1979248929357995
# 6 drugs done
# **************************************************
#
# Cyclopamine (396, 16)
# Best CV score (RMSE): 0.0385370121686188
# Best parameters: {'estimator__n_estimators': 10, 'estimator__min_samples_split': 68, 'estimator__min_samples_leaf': 68, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 40, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.038357741786050704
# Correlation with the training set: (0.13370234205092552, 0.026068639043455258)
#
# RMSE on test data: 0.03254557813266768
# Mean absolute error on test data: 0.024009350717256742
# Correlation with the test set: (-0.054981793077016484, 0.5525795447872424)
#
# Dummy CV RMSE: 0.03805462133152069
# Dummy test RMSE: 0.032466628919677956
# 7 drugs done
# **************************************************
#
# AZ628 (377, 17)
# Best CV score (RMSE): 0.17068524388833736
# Best parameters: {'estimator__n_estimators': 500, 'estimator__min_samples_split': 68, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'auto', 'estimator__max_depth': 30, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.16250115073100035
# Correlation with the training set: (0.5263017320443203, 3.853153171679385e-20)
#
# RMSE on test data: 0.17251296613021047
# Mean absolute error on test data: 0.12239947756153224
# Correlation with the test set: (0.4909602513302602, 2.9257402270356116e-08)
#
# Dummy CV RMSE: 0.1894104682559174
# Dummy test RMSE: 0.19494662645869576
# 8 drugs done
# **************************************************
#
# Sorafenib (377, 34)
# Best CV score (RMSE): 0.11519430946660447
# Best parameters: {'estimator__n_estimators': 500, 'estimator__min_samples_split': 68, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'auto', 'estimator__max_depth': 30, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.08691451523909274
# Correlation with the training set: (0.732631543669469, 1.6441548180387395e-45)
#
# RMSE on test data: 0.08173651890744908
# Mean absolute error on test data: 0.05272660608719334
# Correlation with the test set: (0.5864510136592659, 7.088302007522324e-12)
#
# Dummy CV RMSE: 0.12423647078714964
# Dummy test RMSE: 0.10104082382314131
# 9 drugs done
# **************************************************
#
# Tozasertib (382, 19)
# Best CV score (RMSE): 0.19510956663384915
# Best parameters: {'estimator__n_estimators': 500, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 90, 'estimator__max_features': 'auto', 'estimator__max_depth': 30, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.19467381545321522
# Correlation with the training set: (0.05666704876560157, 0.3563490389125048)
#
# RMSE on test data: 0.20080456876740252
# Mean absolute error on test data: 0.16115702069488036
# Correlation with the test set: (0.022047052068042774, 0.815082876071299)
#
# Dummy CV RMSE: 0.19485132305992656
# Dummy test RMSE: 0.20081457418511894
# 10 drugs done
# **************************************************
#
# Imatinib (380, 29)
# Best CV score (RMSE): 0.07828133089053135
# Best parameters: {'estimator__n_estimators': 500, 'estimator__min_samples_split': 68, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'auto', 'estimator__max_depth': 30, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.06568985544943011
# Correlation with the training set: (0.6728092124787962, 2.0396223013055346e-36)
#
# RMSE on test data: 0.08275134403403102
# Mean absolute error on test data: 0.03576951617759054
# Correlation with the test set: (0.08607789195709693, 0.3624938397176811)
#
# Dummy CV RMSE: 0.07939521962220426
# Dummy test RMSE: 0.06290019799353104
# 11 drugs done
# **************************************************
#
# NVP-TAE684 (379, 17)
# Best CV score (RMSE): 0.13353134721390578
# Best parameters: {'estimator__n_estimators': 500, 'estimator__min_samples_split': 68, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'auto', 'estimator__max_depth': 30, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.11500944959155583
# Correlation with the training set: (0.6974725085433964, 6.108686278921486e-40)
#
# RMSE on test data: 0.12182679273676446
# Mean absolute error on test data: 0.09682221901727638
# Correlation with the test set: (0.4125861987347491, 5.077161036832862e-06)
#
# Dummy CV RMSE: 0.15486785485629123
# Dummy test RMSE: 0.13213707231188704
# 12 drugs done
# **************************************************
#
# Crizotinib (379, 21)
# Best CV score (RMSE): 0.07057537608962157
# Best parameters: {'estimator__n_estimators': 500, 'estimator__min_samples_split': 68, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'auto', 'estimator__max_depth': 30, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.05849640270416974
# Correlation with the training set: (0.6668825809569338, 1.851553867767928e-35)
#
# RMSE on test data: 0.037976412511410554
# Mean absolute error on test data: 0.02512683723582091
# Correlation with the test set: (0.6119394532680287, 4.714150147191803e-13)
#
# Dummy CV RMSE: 0.07362992936516966
# Dummy test RMSE: 0.048153759043624574
# 13 drugs done
# **************************************************
#
# Saracatinib (406, 17)
# Best CV score (RMSE): 0.08535481565273678
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.07787161210937618
# Correlation with the training set: (0.5113696257016761, 2.5176231464225576e-20)
#
# RMSE on test data: 0.051340880573679235
# Mean absolute error on test data: 0.042910996204797304
# Correlation with the test set: (0.3996732920295859, 5.099595764553796e-06)
#
# Dummy CV RMSE: 0.08628504569382792
# Dummy test RMSE: 0.055068056919315
# 14 drugs done
# **************************************************
#
# S-Trityl-L-cysteine (397, 16)
# Best CV score (RMSE): 0.12809107627534663
# Best parameters: {'estimator__n_estimators': 20, 'estimator__min_samples_split': 35, 'estimator__min_samples_leaf': 35, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 70, 'estimator__criterion': 'mae'}
#
# RMSE on training data: 0.12775808783009263
# Correlation with the training set: (0.2210630027338915, 0.00020843334978607627)
#
# RMSE on test data: 0.1303826183227967
# Mean absolute error on test data: 0.11000436749999999
# Correlation with the test set: (0.36823317665186894, 3.5044477824946736e-05)
#
# Dummy CV RMSE: 0.1297768737691382
# Dummy test RMSE: 0.13304404481865914
# 15 drugs done
# **************************************************
#
# Dasatinib (369, 46)
# Best CV score (RMSE): 0.23369621628918372
# Best parameters: {'estimator__n_estimators': 500, 'estimator__min_samples_split': 68, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'auto', 'estimator__max_depth': 30, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.1989382681358577
# Correlation with the training set: (0.667965712440641, 1.0518247911588285e-34)
#
# RMSE on test data: 0.2249576283717525
# Mean absolute error on test data: 0.1748032297337954
# Correlation with the test set: (0.5345707708324959, 1.5109377796879362e-09)
#
# Dummy CV RMSE: 0.2606453451787543
# Dummy test RMSE: 0.26432504424334047
# 16 drugs done
# **************************************************
#
# GNF-2 (370, 16)
# Best CV score (RMSE): 0.04426600074859042
# Best parameters: {'estimator__n_estimators': 10, 'estimator__min_samples_split': 46, 'estimator__min_samples_leaf': 101, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 10, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.04412583773488911
# Correlation with the training set: (nan, 1.0)
#
# RMSE on test data: 0.06334316447373917
# Mean absolute error on test data: 0.025451982201119955
# Correlation with the test set: (9.345606820490743e-16, 1.0)
#
# Dummy CV RMSE: 0.040860333210246215
# Dummy test RMSE: 0.06330078760008
# 17 drugs done
# **************************************************
#
# CGP-082996 (387, 17)
# Best CV score (RMSE): 0.06129554490202016
# Best parameters: {'estimator__n_estimators': 100, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 68, 'estimator__max_features': 'auto', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.06071351856940987
# Correlation with the training set: (0.17470950063422758, 0.003981410458911573)
#
# RMSE on test data: 0.04978349655430531
# Mean absolute error on test data: 0.04220174634451999
# Correlation with the test set: (0.10902927404058414, 0.2419358001047162)
#
# Dummy CV RMSE: 0.061437188339553105
# Dummy test RMSE: 0.04982136717579758
# 18 drugs done
# **************************************************
#
# A-770041 (399, 17)
# Best CV score (RMSE): 0.1803339448563689
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.1703392679298826
# Correlation with the training set: (0.41999037142047974, 2.384425390822485e-13)
#
# RMSE on test data: 0.14592233077758285
# Mean absolute error on test data: 0.11017211844904991
# Correlation with the test set: (0.2710815789540926, 0.0027466728674033604)
#
# Dummy CV RMSE: 0.18190763385361042
# Dummy test RMSE: 0.1508975767951093
# 19 drugs done
# **************************************************
#
# WH-4-023 (396, 17)
# Best CV score (RMSE): 0.21438193902465136
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.2019191312058954
# Correlation with the training set: (0.44520111141475094, 6.8545195395762295e-15)
#
# RMSE on test data: 0.20139639139925625
# Mean absolute error on test data: 0.14171528924643761
# Correlation with the test set: (0.2480487055424784, 0.0065286666006217535)
#
# Dummy CV RMSE: 0.2201217485506309
# Dummy test RMSE: 0.20792655578170258
# 20 drugs done
# **************************************************
#
# WZ-1-84 (398, 16)
# Best CV score (RMSE): 0.06257392096182278
# Best parameters: {'estimator__n_estimators': 500, 'estimator__min_samples_split': 46, 'estimator__min_samples_leaf': 46, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 30, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.062105862956692626
# Correlation with the training set: (0.1758279663753872, 0.003267557679158937)
#
# RMSE on test data: 0.05891576281613108
# Mean absolute error on test data: 0.042031820831207274
# Correlation with the test set: (0.1470117703860987, 0.10909025699426182)
#
# Dummy CV RMSE: 0.061766237817844995
# Dummy test RMSE: 0.05919907409607344
# 21 drugs done
# **************************************************
#
# BI-2536 (397, 18)
# Best CV score (RMSE): 0.13993165018976547
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.13323161007290393
# Correlation with the training set: (0.43304513247159854, 4.339575574388864e-14)
#
# RMSE on test data: 0.17763408796424876
# Mean absolute error on test data: 0.1525532542112752
# Correlation with the test set: (0.004659632003894626, 0.9597162115666812)
#
# Dummy CV RMSE: 0.14159749856385978
# Dummy test RMSE: 0.17623620404417156
# 22 drugs done
# **************************************************
#
# BMS-536924 (388, 17)
# Best CV score (RMSE): 0.1663332397969073
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.15740960263590367
# Correlation with the training set: (0.4592797188437373, 1.514390817529011e-15)
#
# RMSE on test data: 0.15306507050723264
# Mean absolute error on test data: 0.1219606159742588
# Correlation with the test set: (0.16922872909944545, 0.06814985453982307)
#
# Dummy CV RMSE: 0.1728576989574102
# Dummy test RMSE: 0.15369042514929845
# 23 drugs done
# **************************************************
#
# BMS-509744 (399, 16)
# Best CV score (RMSE): 0.07541072403246958
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.07152438110276209
# Correlation with the training set: (0.3528105287955793, 1.3384628819762337e-09)
#
# RMSE on test data: 0.07184098920304026
# Mean absolute error on test data: 0.05511473524545672
# Correlation with the test set: (0.13694080076347256, 0.13584458802700983)
#
# Dummy CV RMSE: 0.07593469801923682
# Dummy test RMSE: 0.07215883916366855
# 24 drugs done
# **************************************************
#
# Pyrimethamine (401, 16)
# Best CV score (RMSE): 0.1177621212387812
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.11293290581381815
# Correlation with the training set: (0.34351816067098573, 3.568428621523405e-09)
#
# RMSE on test data: 0.11841405991049077
# Mean absolute error on test data: 0.08490925315939536
# Correlation with the test set: (0.2247256920493405, 0.013208177301412171)
#
# Dummy CV RMSE: 0.11835498978154275
# Dummy test RMSE: 0.12136745255786242
# 25 drugs done
# **************************************************
#
# JW-7-52-1 (358, 17)
# Best CV score (RMSE): 0.22482735012519614
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.21650794625656727
# Correlation with the training set: (0.36747923985830716, 2.0701080909032953e-09)
#
# RMSE on test data: 0.23052128047740525
# Mean absolute error on test data: 0.19536810065559174
# Correlation with the test set: (0.22290861938568232, 0.020403976335493925)
#
# Dummy CV RMSE: 0.2288743242204559
# Dummy test RMSE: 0.23624677701981267
# 26 drugs done
# **************************************************
#
# A-443654 (372, 25)
# Best CV score (RMSE): 0.13829659905547503
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 79, 'estimator__min_samples_leaf': 35, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 70, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.13538894812252894
# Correlation with the training set: (0.3835415485234562, 1.542706000737157e-10)
#
# RMSE on test data: 0.1425721509051674
# Mean absolute error on test data: 0.11616901645335724
# Correlation with the test set: (0.126619853825306, 0.18340397893766086)
#
# Dummy CV RMSE: 0.13842327987735828
# Dummy test RMSE: 0.1431336378144807
# 27 drugs done
# **************************************************
#
# GW843682X (399, 16)
# Best CV score (RMSE): 0.187296287487703
# Best parameters: {'estimator__n_estimators': 10, 'estimator__min_samples_split': 46, 'estimator__min_samples_leaf': 101, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 10, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.18644115218922475
# Correlation with the training set: (-7.347493974115523e-16, 1.0)
#
# RMSE on test data: 0.20789832089110824
# Mean absolute error on test data: 0.1808772202688172
# Correlation with the test set: (nan, 1.0)
#
# Dummy CV RMSE: 0.18706853911725246
# Dummy test RMSE: 0.2078261407145027
# 28 drugs done
# **************************************************
#
# Entinostat (400, 17)
# Best CV score (RMSE): 0.16788426225708686
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.1597809970012922
# Correlation with the training set: (0.36432844551181903, 3.247255604551139e-10)
#
# RMSE on test data: 0.14250258586170114
# Mean absolute error on test data: 0.11642896094417456
# Correlation with the test set: (0.30330647667988087, 0.0007586141145024414)
#
# Dummy CV RMSE: 0.16873729942907328
# Dummy test RMSE: 0.14883350209915255
# 29 drugs done
# **************************************************
#
# Bortezomib (390, 18)
# Best CV score (RMSE): 0.18704093076491943
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 79, 'estimator__min_samples_leaf': 13, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mae'}
#
# RMSE on training data: 0.18311686789716058
# Correlation with the training set: (0.33899706289073794, 9.110934306164236e-09)
#
# RMSE on test data: 0.18851410134545066
# Mean absolute error on test data: 0.1585962181196581
# Correlation with the test set: (0.22497589143057287, 0.014739873437658807)
#
# Dummy CV RMSE: 0.19148156561925997
# Dummy test RMSE: 0.19303431763373705
# 30 drugs done
# **************************************************
#
# Seliciclib (386, 24)
# Best CV score (RMSE): 0.04440684297668982
# Best parameters: {'estimator__n_estimators': 100, 'estimator__min_samples_split': 35, 'estimator__min_samples_leaf': 35, 'estimator__max_features': 'auto', 'estimator__max_depth': None, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.04216865653779271
# Correlation with the training set: (0.3618781448094069, 8.921235142221384e-10)
#
# RMSE on test data: 0.04683105255125449
# Mean absolute error on test data: 0.036476525998030467
# Correlation with the test set: (-0.09389151965474131, 0.3160983684588934)
#
# Dummy CV RMSE: 0.044405589596861854
# Dummy test RMSE: 0.045038342399505944
# 31 drugs done
# **************************************************
#
# Salubrinal (398, 16)
# Best CV score (RMSE): 0.06333089109562887
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.0614411605634916
# Correlation with the training set: (0.32155528869874594, 4.168483594533048e-08)
#
# RMSE on test data: 0.052198528861788024
# Mean absolute error on test data: 0.0434118431036693
# Correlation with the test set: (0.1865024542191755, 0.041392236686296144)
#
# Dummy CV RMSE: 0.06447185039320864
# Dummy test RMSE: 0.053365369674450366
# 32 drugs done
# **************************************************
#
# Lapatinib (371, 21)
# Best CV score (RMSE): 0.06664869047007164
# Best parameters: {'estimator__n_estimators': 500, 'estimator__min_samples_split': 68, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'auto', 'estimator__max_depth': 30, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.06041120962338238
# Correlation with the training set: (0.7236898697313153, 2.754067563538403e-43)
#
# RMSE on test data: 0.08525390519536422
# Mean absolute error on test data: 0.036130176324191514
# Correlation with the test set: (0.22557509551029525, 0.016784739644722414)
#
# Dummy CV RMSE: 0.08281591806670072
# Dummy test RMSE: 0.0819327543402351
# 33 drugs done
# **************************************************
#
# GSK269962A (391, 18)
# Best CV score (RMSE): 0.11663317039714165
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.11045170367162456
# Correlation with the training set: (0.3808551364563383, 7.469604591414134e-11)
#
# RMSE on test data: 0.1404161127465732
# Mean absolute error on test data: 0.08167142110200534
# Correlation with the test set: (0.262033767663887, 0.0041520029794481755)
#
# Dummy CV RMSE: 0.11651887558584906
# Dummy test RMSE: 0.1445337779025286
# 34 drugs done
# **************************************************
#
# Doxorubicin (871, 17)
# Best CV score (RMSE): 0.20818208646681238
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.19736817678012417
# Correlation with the training set: (0.3574877337283395, 8.50216344936718e-20)
#
# RMSE on test data: 0.19824210724999033
# Mean absolute error on test data: 0.1660985637329111
# Correlation with the test set: (0.13452624615252545, 0.029481246100883287)
#
# Dummy CV RMSE: 0.20826480424313787
# Dummy test RMSE: 0.19981275469543863
# 35 drugs done
# **************************************************
#
# Etoposide (881, 17)
# Best CV score (RMSE): 0.218255948977179
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.2069906409889562
# Correlation with the training set: (0.42737887673971203, 9.607307023846319e-29)
#
# RMSE on test data: 0.2110132009049773
# Mean absolute error on test data: 0.18182636772225694
# Correlation with the test set: (0.24206927320813063, 6.85259790436094e-05)
#
# Dummy CV RMSE: 0.226005220411452
# Dummy test RMSE: 0.21678754691653096
# 36 drugs done
# **************************************************
#
# Gemcitabine (843, 20)
# Best CV score (RMSE): 0.3111181392798395
# Best parameters: {'estimator__n_estimators': 500, 'estimator__min_samples_split': 68, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'auto', 'estimator__max_depth': 30, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.27607914097060576
# Correlation with the training set: (0.5638975562713575, 7.953663926310995e-51)
#
# RMSE on test data: 0.29235811838935016
# Mean absolute error on test data: 0.25411334002644237
# Correlation with the test set: (0.28230951037373303, 5.083979936369114e-06)
#
# Dummy CV RMSE: 0.3150778122249769
# Dummy test RMSE: 0.30484467357967293
# 37 drugs done
# **************************************************
#
# Bicalutamide (870, 16)
# Best CV score (RMSE): 0.012155585408060558
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 79, 'estimator__min_samples_leaf': 35, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 70, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.012014322432250904
# Correlation with the training set: (0.23807108169358457, 2.7016487665363592e-09)
#
# RMSE on test data: 0.010074988150645316
# Mean absolute error on test data: 0.00568996741181129
# Correlation with the test set: (0.21702585065916571, 0.0004131875170077483)
#
# Dummy CV RMSE: 0.011540711573892842
# Dummy test RMSE: 0.010278623982170958
# 38 drugs done
# **************************************************
#
# QS11 (848, 17)
# Best CV score (RMSE): 0.08790951205060966
# Best parameters: {'estimator__n_estimators': 500, 'estimator__min_samples_split': 57, 'estimator__min_samples_leaf': 46, 'estimator__max_features': 'sqrt', 'estimator__max_depth': None, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.08747850542730515
# Correlation with the training set: (0.17919943426574766, 1.1326229311134022e-05)
#
# RMSE on test data: 0.07775722225574762
# Mean absolute error on test data: 0.06347520762208828
# Correlation with the test set: (0.10523902340465646, 0.09355507030184657)
#
# Dummy CV RMSE: 0.08805842472267486
# Dummy test RMSE: 0.07808913297774242
# 39 drugs done
# **************************************************
#
# CP466722 (867, 17)
# Best CV score (RMSE): 0.10667904769361927
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.10229292699446246
# Correlation with the training set: (0.541015975349125, 2.2747803662795323e-47)
#
# RMSE on test data: 0.10312345168010957
# Mean absolute error on test data: 0.08332792046209035
# Correlation with the test set: (0.5669327727449464, 1.3515437966469415e-23)
#
# Dummy CV RMSE: 0.1208574928084688
# Dummy test RMSE: 0.12327543477670332
# 40 drugs done
# **************************************************
#
# Midostaurin (858, 17)
# Best CV score (RMSE): 0.08892720702630055
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.0850406460114755
# Correlation with the training set: (0.33648212213667145, 2.3870920364543663e-17)
#
# RMSE on test data: 0.08291309123343324
# Mean absolute error on test data: 0.06667803846424375
# Correlation with the test set: (0.15933877219141615, 0.01036736401544573)
#
# Dummy CV RMSE: 0.08959369639441346
# Dummy test RMSE: 0.08310588482093066
# 41 drugs done
# **************************************************
#
# CHIR-99021 (855, 18)
# Best CV score (RMSE): 0.03908414057998446
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.037024584178188526
# Correlation with the training set: (0.40718484266562127, 2.750148681198125e-25)
#
# RMSE on test data: 0.046571471523759705
# Mean absolute error on test data: 0.025735275494457744
# Correlation with the test set: (0.29377824673552666, 1.6443418021015865e-06)
#
# Dummy CV RMSE: 0.03967297458536438
# Dummy test RMSE: 0.04839584764010036
# 42 drugs done
# **************************************************
#
# Ponatinib (826, 44)
# Best CV score (RMSE): 0.11782098248619363
# Best parameters: {'estimator__n_estimators': 500, 'estimator__min_samples_split': 68, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'auto', 'estimator__max_depth': 30, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.0981029681962465
# Correlation with the training set: (0.6696836335663915, 1.841895076643152e-76)
#
# RMSE on test data: 0.15430645641019577
# Mean absolute error on test data: 0.08165019543845828
# Correlation with the test set: (0.4844953299207935, 5.296811682443083e-16)
#
# Dummy CV RMSE: 0.12576768909733738
# Dummy test RMSE: 0.17302210577957286
# 43 drugs done
# **************************************************
#
# HG6-64-1 (827, 17)
# Best CV score (RMSE): 0.16672926376014865
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.16079197426137626
# Correlation with the training set: (0.37151144892312704, 2.3446407310079417e-20)
#
# RMSE on test data: 0.173462109809082
# Mean absolute error on test data: 0.13448755909670307
# Correlation with the test set: (0.2581558482154771, 3.7358043953795556e-05)
#
# Dummy CV RMSE: 0.1722818661684825
# Dummy test RMSE: 0.1792919927451297
# 44 drugs done
# **************************************************
#
# JQ1 (880, 19)
# Best CV score (RMSE): 0.15666976490162915
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.1467273592816634
# Correlation with the training set: (0.4664336410151735, 1.3359860191816767e-34)
#
# RMSE on test data: 0.15416034124284442
# Mean absolute error on test data: 0.12756661006954742
# Correlation with the test set: (0.194694893565381, 0.0014784479335268)
#
# Dummy CV RMSE: 0.1598030393894755
# Dummy test RMSE: 0.15741980210993448
# 45 drugs done
# **************************************************
#
# JQ12 (874, 17)
# Best CV score (RMSE): 0.1645689541305456
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.15748894765182647
# Correlation with the training set: (0.37230851635622836, 1.5923156820986464e-21)
#
# RMSE on test data: 0.15922045330413676
# Mean absolute error on test data: 0.128755527124741
# Correlation with the test set: (0.18926795918029587, 0.0020513152647554647)
#
# Dummy CV RMSE: 0.16739675197776824
# Dummy test RMSE: 0.1619104537464577
# 46 drugs done
# **************************************************
#
# AKT inhibitor VIII (823, 21)
# Best CV score (RMSE): 0.055964800517397696
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.052416801883437295
# Correlation with the training set: (0.4603664469011429, 1.4769932630614184e-31)
#
# RMSE on test data: 0.04789624752105371
# Mean absolute error on test data: 0.036115094610224364
# Correlation with the test set: (0.372953966993399, 1.435547650759353e-09)
#
# Dummy CV RMSE: 0.05739594000746153
# Dummy test RMSE: 0.05137066268944948
# 47 drugs done
# **************************************************
#
# Embelin (872, 16)
# Best CV score (RMSE): 0.10047594312698334
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.09666327036221313
# Correlation with the training set: (0.3029743060787589, 2.0405830081623076e-14)
#
# RMSE on test data: 0.09908912894999101
# Mean absolute error on test data: 0.08036163286287341
# Correlation with the test set: (0.17127711823646777, 0.005441313303716921)
#
# Dummy CV RMSE: 0.10105936371139049
# Dummy test RMSE: 0.10061578452658965
# 48 drugs done
# **************************************************
#
# IPA-3 (847, 17)
# Best CV score (RMSE): 0.10920284066488938
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.10594387090531052
# Correlation with the training set: (0.4056512539887519, 7.423605467115249e-25)
#
# RMSE on test data: 0.10140995836956096
# Mean absolute error on test data: 0.08567458873384531
# Correlation with the test set: (0.3556668563885619, 5.10122330901825e-09)
#
# Dummy CV RMSE: 0.11557968317749952
# Dummy test RMSE: 0.10826747234358583
# 49 drugs done
# **************************************************
#
# GSK650394 (840, 18)
# Best CV score (RMSE): 0.12339463008529648
# Best parameters: {'estimator__n_estimators': 500, 'estimator__min_samples_split': 46, 'estimator__min_samples_leaf': 46, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 30, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.12215508975026627
# Correlation with the training set: (0.22977965087613855, 1.744685617487393e-08)
#
# RMSE on test data: 0.13256958170628624
# Mean absolute error on test data: 0.10499775416543553
# Correlation with the test set: (0.05792031714056493, 0.3598482705868068)
#
# Dummy CV RMSE: 0.12337667620178427
# Dummy test RMSE: 0.13278689007462469
# 50 drugs done
# **************************************************
#
# BAY-61-3606 (868, 16)
# Best CV score (RMSE): 0.11875020330646432
# Best parameters: {'estimator__n_estimators': 500, 'estimator__min_samples_split': 68, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'auto', 'estimator__max_depth': 30, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.10931994783446444
# Correlation with the training set: (0.49842334720395004, 1.9616840408602893e-39)
#
# RMSE on test data: 0.12055383776685448
# Mean absolute error on test data: 0.09519200530925026
# Correlation with the test set: (0.28052846266331427, 4.162784547438281e-06)
#
# Dummy CV RMSE: 0.124136372484181
# Dummy test RMSE: 0.12531902985171142
# 51 drugs done
# **************************************************
#
# 5-Fluorouracil (888, 18)
# Best CV score (RMSE): 0.15764154461769925
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.15046511052698291
# Correlation with the training set: (0.4729200453699379, 6.323646509905437e-36)
#
# RMSE on test data: 0.14295130895911676
# Mean absolute error on test data: 0.11174101061934723
# Correlation with the test set: (0.5301659036861736, 9.374194732992321e-21)
#
# Dummy CV RMSE: 0.1700247277485852
# Dummy test RMSE: 0.16615080222722112
# 52 drugs done
# **************************************************
#
# Obatoclax Mesylate (841, 18)
# Best CV score (RMSE): 0.22146226412797052
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.21034906768479536
# Correlation with the training set: (0.41498412090541537, 7.024660516279988e-26)
#
# RMSE on test data: 0.2060852330197347
# Mean absolute error on test data: 0.16934409786884885
# Correlation with the test set: (0.3398422933595337, 2.9453374569593022e-08)
#
# Dummy CV RMSE: 0.2284090079659699
# Dummy test RMSE: 0.2183557776391087
# 53 drugs done
# **************************************************
#
# BMS-754807 (844, 17)
# Best CV score (RMSE): 0.1637725141666096
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.15697320706613768
# Correlation with the training set: (0.44627809801977547, 3.208797738167694e-30)
#
# RMSE on test data: 0.1808874806123594
# Mean absolute error on test data: 0.13061430162973292
# Correlation with the test set: (0.3433240885268035, 1.9505127706742473e-08)
#
# Dummy CV RMSE: 0.17337003367828815
# Dummy test RMSE: 0.1926638198333312
# 54 drugs done
# **************************************************
#
# Linsitinib (844, 17)
# Best CV score (RMSE): 0.10414110928157413
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.0994634974124736
# Correlation with the training set: (0.42119172377599606, 9.001902425807938e-27)
#
# RMSE on test data: 0.1201943685221532
# Mean absolute error on test data: 0.0745224153439895
# Correlation with the test set: (0.34180119045802576, 2.2732711436861216e-08)
#
# Dummy CV RMSE: 0.107082075736603
# Dummy test RMSE: 0.12708357300187606
# 55 drugs done
# **************************************************
#
# Bexarotene (860, 18)
# Best CV score (RMSE): 0.06978157796750026
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.06505309210838624
# Correlation with the training set: (0.46807001767997297, 4.170709169202577e-34)
#
# RMSE on test data: 0.05841593338151991
# Mean absolute error on test data: 0.04116990473352819
# Correlation with the test set: (0.04024689490533543, 0.5198461374353786)
#
# Dummy CV RMSE: 0.06759219775654929
# Dummy test RMSE: 0.05806351077593512
# 56 drugs done
# **************************************************
#
# LFM-A13 (870, 16)
# Best CV score (RMSE): 0.027420858373513688
# Best parameters: {'estimator__n_estimators': 200, 'estimator__min_samples_split': 57, 'estimator__min_samples_leaf': 79, 'estimator__max_features': 'auto', 'estimator__max_depth': 80, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.027209344437353032
# Correlation with the training set: (0.2184909685715311, 5.1292965061665686e-08)
#
# RMSE on test data: 0.027126260050663993
# Mean absolute error on test data: 0.020183389324243982
# Correlation with the test set: (0.014558917785075171, 0.8149151364134136)
#
# Dummy CV RMSE: 0.027719998456373775
# Dummy test RMSE: 0.026531110243537572
# 57 drugs done
# **************************************************
#
# GW-2580 (922, 16)
# Best CV score (RMSE): 0.03695074382896951
# Best parameters: {'estimator__n_estimators': 10, 'estimator__min_samples_split': 68, 'estimator__min_samples_leaf': 68, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 40, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.036786567091876915
# Correlation with the training set: (0.07724681514347682, 0.04988471809028766)
#
# RMSE on test data: 0.01809011407177425
# Mean absolute error on test data: 0.010870871181086804
# Correlation with the test set: (0.06117358359192434, 0.3103548474083257)
#
# Dummy CV RMSE: 0.029822547695022877
# Dummy test RMSE: 0.018098987412116553
# 58 drugs done
# **************************************************
#
# Phenformin (887, 19)
# Best CV score (RMSE): 0.18797500454470242
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.17913825137504158
# Correlation with the training set: (0.5014370094897714, 8.713309568211627e-41)
#
# RMSE on test data: 0.18870034655277018
# Mean absolute error on test data: 0.14371861834559388
# Correlation with the test set: (0.3876912215576442, 5.248751222203167e-11)
#
# Dummy CV RMSE: 0.20613451492241291
# Dummy test RMSE: 0.2046909852581266
# 59 drugs done
# **************************************************
#
# Pazopanib (814, 33)
# Best CV score (RMSE): 0.07810292825737415
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 79, 'estimator__min_samples_leaf': 35, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 70, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.07534920004782937
# Correlation with the training set: (0.42140380139498523, 6.693788150073562e-26)
#
# RMSE on test data: 0.12452381469689396
# Mean absolute error on test data: 0.06870976378472718
# Correlation with the test set: (0.25891295054847274, 4.094730895130691e-05)
#
# Dummy CV RMSE: 0.07904999609055055
# Dummy test RMSE: 0.1268282281909517
# 60 drugs done
# **************************************************
#
# Dacinostat (872, 16)
# Best CV score (RMSE): 0.15618064535672324
# Best parameters: {'estimator__n_estimators': 500, 'estimator__min_samples_split': 68, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'auto', 'estimator__max_depth': 30, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.14586578103438733
# Correlation with the training set: (0.5020043129831164, 2.9623031309165774e-40)
#
# RMSE on test data: 0.1571569659125318
# Mean absolute error on test data: 0.1225680373697816
# Correlation with the test set: (0.31297925481786126, 2.3120865810311252e-07)
#
# Dummy CV RMSE: 0.16796128826555917
# Dummy test RMSE: 0.1650067198534384
# 61 drugs done
# **************************************************
#
# Epothilone B (848, 29)
# Best CV score (RMSE): 0.21195011577137354
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.19574389283938398
# Correlation with the training set: (0.5365793475798436, 1.6116172461108092e-45)
#
# RMSE on test data: 0.21252263519573886
# Mean absolute error on test data: 0.18164702339943942
# Correlation with the test set: (0.14494484609914635, 0.020588173584735428)
#
# Dummy CV RMSE: 0.2161789267677115
# Dummy test RMSE: 0.21388180712075974
# 62 drugs done
# **************************************************
#
# GSK1904529A (848, 17)
# Best CV score (RMSE): 0.02381586222590667
# Best parameters: {'estimator__n_estimators': 100, 'estimator__min_samples_split': 35, 'estimator__min_samples_leaf': 35, 'estimator__max_features': 'auto', 'estimator__max_depth': None, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.02316480551323703
# Correlation with the training set: (0.3053092796977685, 2.931385145945808e-14)
#
# RMSE on test data: 0.021180275769005448
# Mean absolute error on test data: 0.013420968337897094
# Correlation with the test set: (0.1464396317877862, 0.019304876359992455)
#
# Dummy CV RMSE: 0.024161540141726043
# Dummy test RMSE: 0.021202418220412227
# 63 drugs done
# **************************************************
#
# Ruxolitinib (896, 19)
# Best CV score (RMSE): 0.0532818562324124
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.05040259903623912
# Correlation with the training set: (0.46202193112281786, 1.7728268503362842e-34)
#
# RMSE on test data: 0.05626688813457469
# Mean absolute error on test data: 0.01709605767878116
# Correlation with the test set: (0.6678394596759841, 4.1608071237170135e-36)
#
# Dummy CV RMSE: 0.05293313035649836
# Dummy test RMSE: 0.06553323268696308
# 64 drugs done
# **************************************************
#
# AT-7519 (893, 22)
# Best CV score (RMSE): 0.19639588139010966
# Best parameters: {'estimator__n_estimators': 100, 'estimator__min_samples_split': 35, 'estimator__min_samples_leaf': 35, 'estimator__max_features': 'auto', 'estimator__max_depth': None, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.18553560754709536
# Correlation with the training set: (0.5833213638563804, 2.9588782210240247e-58)
#
# RMSE on test data: 0.1924101244896047
# Mean absolute error on test data: 0.16091603447874472
# Correlation with the test set: (0.5369699403656225, 2.0311655426179893e-21)
#
# Dummy CV RMSE: 0.22798696026402032
# Dummy test RMSE: 0.22772762941589075
# 65 drugs done
# **************************************************
#
# AS605240 (918, 16)
# Best CV score (RMSE): 0.16880463548911098
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.1634941944764569
# Correlation with the training set: (0.38699601878904055, 2.2884305735224012e-24)
#
# RMSE on test data: 0.14773344019643914
# Mean absolute error on test data: 0.10995210025527173
# Correlation with the test set: (0.32402780861114144, 3.628484723900678e-08)
#
# Dummy CV RMSE: 0.1756936107198567
# Dummy test RMSE: 0.15585832017835294
# 66 drugs done
# **************************************************
#
# Genentech Cpd 10 (897, 18)
# Best CV score (RMSE): 0.14623363541377085
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.13906102276865218
# Correlation with the training set: (0.5413743384019452, 4.962463791470804e-49)
#
# RMSE on test data: 0.1343269777019581
# Mean absolute error on test data: 0.10172628038359657
# Correlation with the test set: (0.3689669352860726, 3.930511991551258e-10)
#
# Dummy CV RMSE: 0.16342319744253458
# Dummy test RMSE: 0.14377718619600263
# 67 drugs done
# **************************************************
#
# GSK1070916 (869, 18)
# Best CV score (RMSE): 0.1968110939147666
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.18960691222986414
# Correlation with the training set: (0.4965123338948424, 3.667637947589894e-39)
#
# RMSE on test data: 0.20492258720420245
# Mean absolute error on test data: 0.12360523269102221
# Correlation with the test set: (0.39834981811850023, 2.336116337042144e-11)
#
# Dummy CV RMSE: 0.217231769636364
# Dummy test RMSE: 0.2229012951462211
# 68 drugs done
# ...
# Correlation with the training set: (0.3967051300726198, 8.281489685955361e-14)
#
# RMSE on test data: 0.2032810822131455
# Mean absolute error on test data: 0.1638693472003683
# Correlation with the test set: (0.23278769867724897, 0.005471757729712661)
#
# Dummy CV RMSE: 0.19060614923191502
# Dummy test RMSE: 0.20967592185661676
# 162 drugs done
# **************************************************
#
# CCT-018159 (876, 19)
# Best CV score (RMSE): 0.06124080947619983
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.057773401215897094
# Correlation with the training set: (0.4237876542838102, 4.110573889745246e-28)
#
# RMSE on test data: 0.05473134890230049
# Mean absolute error on test data: 0.04487275475828212
# Correlation with the test set: (0.23816761295501826, 9.607209642867097e-05)
#
# Dummy CV RMSE: 0.06134434912086943
# Dummy test RMSE: 0.05629309545239687
# 163 drugs done
# **************************************************
#
# Rucaparib (898, 19)
# Best CV score (RMSE): 0.03873651855224537
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.03630343702762145
# Correlation with the training set: (0.4084055087050891, 1.2142944406191463e-26)
#
# RMSE on test data: 0.040893324367776776
# Mean absolute error on test data: 0.026078655883523465
# Correlation with the test set: (0.32065137866535304, 7.15181888482913e-08)
#
# Dummy CV RMSE: 0.038421769788458085
# Dummy test RMSE: 0.042824737883313466
# 164 drugs done
# **************************************************
#
# GSK269962A (906, 18)
# Best CV score (RMSE): 0.12608093462032127
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.11835896224110606
# Correlation with the training set: (0.41243244650322103, 1.9716586853476737e-27)
#
# RMSE on test data: 0.11866140903286537
# Mean absolute error on test data: 0.08270168653980645
# Correlation with the test set: (0.12436719289957869, 0.04040013642673092)
#
# Dummy CV RMSE: 0.1268598862231462
# Dummy test RMSE: 0.11874190262382062
# 165 drugs done
# **************************************************
#
# Tamoxifen (906, 35)
# Best CV score (RMSE): 0.02716452506225645
# Best parameters: {'estimator__n_estimators': 500, 'estimator__min_samples_split': 46, 'estimator__min_samples_leaf': 46, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 30, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.026280685707440132
# Correlation with the training set: (0.45682885103445386, 5.2022156565125595e-34)
#
# RMSE on test data: 0.03477294189860716
# Mean absolute error on test data: 0.0173984878082108
# Correlation with the test set: (-0.03962987214992733, 0.5151508640954217)
#
# Dummy CV RMSE: 0.026525282623171543
# Dummy test RMSE: 0.0346393759598115
# 166 drugs done
# **************************************************
#
# QL-XII-61 (473, 17)
# Best CV score (RMSE): 0.070825611397042
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.06673613195103131
# Correlation with the training set: (0.4293445316265404, 2.806247253766468e-16)
#
# RMSE on test data: 0.06442644598431535
# Mean absolute error on test data: 0.04936082098340492
# Correlation with the test set: (0.2424477089561448, 0.0036483829653658176)
#
# Dummy CV RMSE: 0.07224548853442893
# Dummy test RMSE: 0.06615286991974544
# 167 drugs done
# **************************************************
#
# JQ1 (917, 19)
# Best CV score (RMSE): 0.059811620959969544
# Best parameters: {'estimator__n_estimators': 100, 'estimator__min_samples_split': 35, 'estimator__min_samples_leaf': 35, 'estimator__max_features': 'auto', 'estimator__max_depth': None, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.05755022778025688
# Correlation with the training set: (0.4143281714153003, 5.5566292541701155e-28)
#
# RMSE on test data: 0.07189293797737006
# Mean absolute error on test data: 0.0404170425943107
# Correlation with the test set: (0.2897913222602373, 9.680281990595684e-07)
#
# Dummy CV RMSE: 0.062025486704552976
# Dummy test RMSE: 0.0750874726359005
# 168 drugs done
# **************************************************
#
# PFI-1 (933, 16)
# Best CV score (RMSE): 0.07801197009072289
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.07570669721269874
# Correlation with the training set: (0.40100594742168355, 1.2754631665264064e-26)
#
# RMSE on test data: 0.07639419227496619
# Mean absolute error on test data: 0.05869589413322247
# Correlation with the test set: (0.1848500721499844, 0.001895679598447278)
#
# Dummy CV RMSE: 0.08211008909685688
# Dummy test RMSE: 0.07680926847141752
# 169 drugs done
# **************************************************
#
# IOX2 (907, 17)
# Best CV score (RMSE): 0.035348267076731964
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.03446854456707753
# Correlation with the training set: (0.25364930065916863, 9.148165808413487e-11)
#
# RMSE on test data: 0.0240407651364833
# Mean absolute error on test data: 0.013382263702587837
# Correlation with the test set: (0.1258821815985155, 0.03764979902586098)
#
# Dummy CV RMSE: 0.03147704401965447
# Dummy test RMSE: 0.024034924100137713
# 170 drugs done
# **************************************************
#
# CHIR-99021 (893, 18)
# Best CV score (RMSE): 0.05421270955486219
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.05050526772410956
# Correlation with the training set: (0.4886298925887067, 8.081267214279264e-39)
#
# RMSE on test data: 0.05637766879591214
# Mean absolute error on test data: 0.04216341298389293
# Correlation with the test set: (0.28392457503123697, 2.313726430391717e-06)
#
# Dummy CV RMSE: 0.05670111064867617
# Dummy test RMSE: 0.05866612216471506
# 171 drugs done
# **************************************************
#
# Daporinad (879, 17)
# Best CV score (RMSE): 0.3157954666320075
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.3036230691342121
# Correlation with the training set: (0.5156243139113966, 4.502675875638064e-43)
#
# RMSE on test data: 0.3141973812452472
# Mean absolute error on test data: 0.2726170686016735
# Correlation with the test set: (0.4375920333518758, 8.9459930033981e-14)
#
# Dummy CV RMSE: 0.3523010190919204
# Dummy test RMSE: 0.34970532259475623
# 172 drugs done
# **************************************************
#
# Talazoparib (893, 19)
# Best CV score (RMSE): 0.1843101901742154
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.1740742737741441
# Correlation with the training set: (0.42135642707887316, 2.7212123687833233e-28)
#
# RMSE on test data: 0.20257660698005833
# Mean absolute error on test data: 0.14974109115295786
# Correlation with the test set: (0.3241804380730798, 5.6482949630274295e-08)
#
# Dummy CV RMSE: 0.18816248849742492
# Dummy test RMSE: 0.21279913408575307
# 173 drugs done
# **************************************************
#
# UNC1215 (889, 17)
# Best CV score (RMSE): 0.009042192837360885
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.00875266158162853
# Correlation with the training set: (0.28406235384240275, 5.21845112027259e-13)
#
# RMSE on test data: 0.010555951452255265
# Mean absolute error on test data: 0.006643739710746954
# Correlation with the test set: (0.04888358638994905, 0.4263270867013733)
#
# Dummy CV RMSE: 0.008985849178088506
# Dummy test RMSE: 0.010511369029919155
# 174 drugs done
# **************************************************
#
# SGC0946 (888, 17)
# Best CV score (RMSE): 0.013600160398197062
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 79, 'estimator__min_samples_leaf': 35, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 70, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.013463269604030983
# Correlation with the training set: (0.21797706493566207, 4.085137107042579e-08)
#
# RMSE on test data: 0.012954742269139894
# Mean absolute error on test data: 0.007475494513841004
# Correlation with the test set: (0.21043785839957577, 0.0005375950254443415)
#
# Dummy CV RMSE: 0.012737315475718472
# Dummy test RMSE: 0.013151674779949636
# 175 drugs done
# **************************************************
#
# XAV939 (897, 17)
# Best CV score (RMSE): 0.04126060766421653
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.03960832460623271
# Correlation with the training set: (0.3592676664855448, 1.5420979918297767e-20)
#
# RMSE on test data: 0.053129796873962354
# Mean absolute error on test data: 0.033217137607930956
# Correlation with the test set: (0.18711512676977823, 0.002017345927182777)
#
# Dummy CV RMSE: 0.04158271161650956
# Dummy test RMSE: 0.054189988277318905
# 176 drugs done
# **************************************************
#
# PLX-4720 (870, 17)
# Best CV score (RMSE): 0.06210859954510977
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.060058759574097995
# Correlation with the training set: (0.6737571183245987, 8.534370665416236e-82)
#
# RMSE on test data: 0.07031808006605039
# Mean absolute error on test data: 0.0376916813436422
# Correlation with the test set: (0.6243734276277473, 1.2930717752083097e-29)
#
# Dummy CV RMSE: 0.07808156607471356
# Dummy test RMSE: 0.08591011446770012
# 177 drugs done
# **************************************************
#
# Trametinib (850, 18)
# Best CV score (RMSE): 0.2665852126606343
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.247843820763026
# Correlation with the training set: (0.5513885167843896, 1.259899739770712e-48)
#
# RMSE on test data: 0.239947230037213
# Mean absolute error on test data: 0.19703392276147985
# Correlation with the test set: (0.5216404696635822, 3.3849023790110193e-19)
#
# Dummy CV RMSE: 0.2950853194169814
# Dummy test RMSE: 0.28020135017140285
# 178 drugs done
# **************************************************
#
# Dabrafenib (823, 22)
# Best CV score (RMSE): 0.13545868863966354
# Best parameters: {'estimator__n_estimators': 500, 'estimator__min_samples_split': 68, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'auto', 'estimator__max_depth': 30, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.12433576834248508
# Correlation with the training set: (0.7535608857739905, 1.176399953146715e-106)
#
# RMSE on test data: 0.140737762193865
# Mean absolute error on test data: 0.08526423491094301
# Correlation with the test set: (0.7514959254096051, 3.763712890141267e-46)
#
# Dummy CV RMSE: 0.18715578657062926
# Dummy test RMSE: 0.20630954920273475
# 179 drugs done
# **************************************************
#
# Afatinib (862, 21)
# Best CV score (RMSE): 0.11899304909859762
# Best parameters: {'estimator__n_estimators': 500, 'estimator__min_samples_split': 68, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'auto', 'estimator__max_depth': 30, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.10894479871762658
# Correlation with the training set: (0.6716120794320048, 2.575699525897459e-80)
#
# RMSE on test data: 0.14645003636152407
# Mean absolute error on test data: 0.08319477904773799
# Correlation with the test set: (0.6185289144085866, 9.824800109687786e-29)
#
# Dummy CV RMSE: 0.14458982511371482
# Dummy test RMSE: 0.18171319894833393
# 180 drugs done
# **************************************************
#
# SN-38 (956, 16)
# Best CV score (RMSE): 0.18348759612014667
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.17658354160752465
# Correlation with the training set: (0.4520692993986532, 5.245608075818352e-35)
#
# RMSE on test data: 0.19960827282508498
# Mean absolute error on test data: 0.1628368149439533
# Correlation with the test set: (0.2547262605121462, 1.2494123716895814e-05)
#
# Dummy CV RMSE: 0.19671011099603103
# Dummy test RMSE: 0.2059482795580716
# 181 drugs done
# **************************************************
#
# Olaparib (884, 19)
# Best CV score (RMSE): 0.05404665013595639
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.05074119864441218
# Correlation with the training set: (0.39512223645474936, 1.5875447002146618e-24)
#
# RMSE on test data: 0.06333176865856062
# Mean absolute error on test data: 0.03958910079338431
# Correlation with the test set: (0.336186432361319, 1.8910288272635697e-08)
#
# Dummy CV RMSE: 0.05366047838720021
# Dummy test RMSE: 0.06674051241538291
# 182 drugs done
# **************************************************
#
# Bicalutamide (880, 16)
# Best CV score (RMSE): 0.03006468645147929
# Best parameters: {'estimator__n_estimators': 100, 'estimator__min_samples_split': 35, 'estimator__min_samples_leaf': 35, 'estimator__max_features': 'auto', 'estimator__max_depth': None, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.029450876759441455
# Correlation with the training set: (0.2159593484661067, 6.194731487850408e-08)
#
# RMSE on test data: 0.02350624087086506
# Mean absolute error on test data: 0.014685959457824513
# Correlation with the test set: (0.08480449089781135, 0.16948902452797615)
#
# Dummy CV RMSE: 0.02640198284210386
# Dummy test RMSE: 0.023211696033253387
# 183 drugs done
# **************************************************
#
# PFI-3 (800, 20)
# Best CV score (RMSE): 0.019201268586210154
# Best parameters: {'estimator__n_estimators': 10, 'estimator__min_samples_split': 68, 'estimator__min_samples_leaf': 68, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 40, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.019093910749191253
# Correlation with the training set: (0.16421583447524038, 9.465264494218379e-05)
#
# RMSE on test data: 0.019573841235566204
# Mean absolute error on test data: 0.010211369194279474
# Correlation with the test set: (0.11077898519898713, 0.08680540813599616)
#
# Dummy CV RMSE: 0.018094919507903554
# Dummy test RMSE: 0.019604059844441808
# 184 drugs done
# **************************************************

# %% [markdown]
# Save this Experiment instance

# %%
# Create a filename out of the Experiment's "name" field
filename = exp.name.lower().replace(" ", "_") + ".pkl"
print(filename)
# Save the instance
with open("../Created data/Results/" + filename, "wb") as f:
    dill.dump(exp, f)
# Out:
# only_targets-random_forest_with_z-score_normalization.pkl

# %% [markdown]
# ### Elastic Net with Z-score normalization for all features and exhaustive grid search for hyperparameter tuning - all data classes (expression, mutation, CNV, tissue) + Merck gene expression signatures

# %% [markdown]
# Initialize dictionary with DrugWithDrugBank objects and compute input data for them

# %%
# Create drug objects
drugs = DrugWithDrugBank.create_drugs(drug_annotations_df, map_drugs_to_drugbank_targets)
print(len(drugs))

# Set up data types we want to include in our input for each drug
data_types = ["CNV", "mutation", "expression", "tissue", "merck signatures"]
# Create input data
Experiment.create_input_for_each_drug(drugs, drug_response_df, data_combination=data_types, 
                                     gene_expression_df=gene_expression_df, 
                                     cnv_binary_df=cnv_binary_df,
                                     map_cl_id_and_feature_to_status=map_from_cl_id_and_genetic_feature_to_mutation_status,
                                     cell_lines_list_df=cell_lines_list_df,
                                     coding_variants_df=coding_variants_df,
                                     merck_signatures_df=signatures_df,
                                     feat_threshold=144,
                                     log=True)
# Out:
# 267
# 10 drugs done
# 20 drugs done
# 30 drugs done
# 40 drugs done
# 50 drugs done
# 60 drugs done
# 70 drugs done
# 80 drugs done
# 90 drugs done
# 100 drugs done
# 110 drugs done
# 120 drugs done
# 130 drugs done
# 140 drugs done
# 150 drugs done
# 160 drugs done
# 170 drugs done
# 180 drugs done
# 190 drugs done
# 200 drugs done
# 210 drugs done
# 220 drugs done
# 230 drugs done
# 240 drugs done
# 250 drugs done
# 260 drugs done
# Number of drugs with number of features bigger than 144: 184
# Mean number of features in 267 drugs: 131.24719101123594

# %%
#############################################################################################################
# Set up constants, feature normalization, predictive algorithm and initialize experiment instance
#############################################################################################################

log = True
counter = 0
sensitivity_metric = "AUC"
record_weights = True   # Does the model has coefficients we want to record?
n_folds = 10   # Number of folds in parameter tuning cross-validation
n_combinations = 20   # Number of parameter combinations to try (when using randomized search)

scaler = preprocessing.StandardScaler()   # Setup transformer for feature scaling

estimator = ElasticNet(max_iter=2000)   # Setup algorithm to use

# Hyperparameter space to search on
param_grid = {"estimator__alpha": [0.001, 0.01, 0.1, 1., 5., 10., 30., 50., 100., 300.],
                 "estimator__l1_ratio": [0.0, 0.1, 0.25, 0.5, 0.75, 0.9, 1.]}

# Setup seeds for data split
split_seed = 37

# Function to be optimized during hyperparameter tuning
scoring = "neg_mean_squared_error"   # Function to be optimized by hyperparameters

# Initialize Experiment object for this assay
exp = Experiment(name="Only targets with merck signatures-Elastic Net with Z-score normalization",
                algorithm="ElasticNet",
                parameter_search_type="GridSearch",
                data_normalization_type="StandardScaler on all features",
                split_seed=split_seed,
                kfolds=n_folds)

#############################################################################################################
# Enter the loop over drugs
#############################################################################################################

for ide in drugs:
    drug = drugs[ide]   # Current Drug object
    data = drug.full_data  # Extract input data (should be previously computed)
    if data.shape[0] == 0:   # Check if data exists, if not, skip the drug
        continue
    if data.shape[1] < 144:    # That means that data has only features related to tissue
        continue           # so also skip this case
        
    # Add input data to corresponding Experiment objects's field (dictionary)
    exp.input_data[(drug.name, ide)] = data
    if log:
        print(drug.name, data.shape)
        
    # Add data shapes to corresponding field in Experiment (dictionary)
    exp.data_shapes[(drug.name, ide)] = data.shape
    
    y = data[sensitivity_metric]   # Extract response variable
    X = data.drop(["cell_line_id", sensitivity_metric], axis=1)     # Drop targets and cell line IDs
    assert X.shape[0] == y.shape[0]   # Sanity check
    assert X.shape[1] < data.shape[1]
    
    # Split data into training and test set
    test_size = 0.3    # Fraction of data spent on test set
    X_val, X_test, y_val, y_test = model_selection.train_test_split(X, y, test_size=test_size,
                                                                   random_state=split_seed)
    
    # Create collections.namedtuple for storing
    StandardDeviations = collections.namedtuple("StandardDeviations", ["validation", "test", "overall"])
    stds = StandardDeviations(y_val.std(), y_test.std(), y.std())
    # Record in corresponding field (dictionary)
    exp.data_stds[(drug.name, ide)] = stds    
    
    # Set up and fit Dummy Regressor
    dummy = DummyRegressor()
    dummy.fit(X_val, y_val)
    # Get dummy predictions on the test set
    dummy_preds = dummy.predict(X_test)
    # Baseline dummy performance
    baseline_scores = model_selection.cross_val_score(dummy, X_val, y_val, scoring=scoring, cv=n_folds)
    baseline_mean = np.mean([(-x)**0.5 for x in baseline_scores])
    baseline_std = np.std([(-x)**0.5 for x in baseline_scores])
    
    # Set elements of the pipeline, i.e. scaler and estimator
    transformer = scaler
    predictor = clone(estimator)
    
    # Create pipeline
    main_pipeline = Pipeline([
        ("scaler", transformer),
        ("estimator", predictor)
    ])    
    
    # Set up grid search with cross-validation
    grid = model_selection.GridSearchCV(main_pipeline, param_grid=param_grid, 
                                       scoring=scoring, cv=n_folds)
    
    # Fit the grid
    grid.fit(X_val, y_val)
    best = grid.best_estimator_   # Best model
    pred = grid.predict(X_test)   # Predict on test data with refitted best model
    training_preds = grid.predict(X_val)    # Predict on train data with refitted best model
    
    if log:   # Report the results
        # Summarize grid search
        print("Best CV score (RMSE):", (-grid.best_score_)**0.5)
        print("Best parameters:", grid.best_params_)
        print("")
        
        # Print out performance of the best model on training set
        print("RMSE on training data:", metrics.mean_squared_error(y_val, training_preds)**0.5)
        print("Correlation with the training set:", pearsonr(y_val, training_preds))
        print("")
        
        # Print out the performance of the best model on test set
        print("RMSE on test data:", metrics.mean_squared_error(y_test, pred) ** 0.5)
        print("Mean absolute error on test data:", metrics.mean_absolute_error(y_test, pred))
        print("Correlation with the test set:", pearsonr(y_test, pred))
        print("")
        
        # Print out performance of dummy regressor
        print("Dummy CV RMSE:", baseline_mean)
        print("Dummy test RMSE:", metrics.mean_squared_error(y_test, dummy_preds) ** 0.5)
        
    # Record results in corresponding Experiment fields, mostly as named tuples
    # Classification performance
    ModelTestScores = collections.namedtuple("ModelTestScores", ["cv_best_score", "test_RMSE",
                                                    "test_explained_variance", "test_correlation"])
    model_test_scores = ModelTestScores(grid.best_score_, metrics.mean_squared_error(y_test, pred) ** 0.5,
                                       metrics.explained_variance_score(y_test, pred), pearsonr(y_test, pred))
    # Record in appropriate field (dictionary)
    exp.best_scores[(drug.name, ide)] = model_test_scores
    
    # Full results of cross-validation tuning
    exp.cv_results[(drug.name, ide)] = grid.cv_results_
    
    # Parameters of best found model
    exp.best_parameters[(drug.name, ide)] = grid.best_params_
    
    # Coefficients (if model has them)
    if record_weights:
        BestModelWeights = collections.namedtuple("BestModelWeights", ["intercept", "weights_array"])
        best_model_weights = BestModelWeights(best.named_steps["estimator"].intercept_,
                                         best.named_steps["estimator"].coef_)
        # Record in appropriate field (dictionary)
        exp.coefficients[(drug.name, ide)] = best_model_weights
    
    # Performance on the training set
    ModelTrainingScores = collections.namedtuple("ModelTrainingScores", ["training_RMSE", "training_correlation"])
    model_training_scores = ModelTrainingScores(metrics.mean_squared_error(y_val, training_preds) ** 0.5,
                                               pearsonr(y_val, training_preds))
    # Record in appropriate field (dictionary)
    exp.training_scores[(drug.name, ide)] = model_training_scores
    
    # Performance of dummy model
    DummyScores = collections.namedtuple("DummyScores", ["cv_RMSE", "test_RMSE", "test_explained_variance",
                                            "test_correlation"])
    dummy_performance = DummyScores(baseline_mean, metrics.mean_squared_error(y_test, dummy_preds) ** 0.5,
                                   metrics.explained_variance_score(y_test, dummy_preds),
                                   pearsonr(y_test, dummy_preds))
    # Record in appropriate field (dictionary)
    exp.dummy_scores[(drug.name, ide)] = dummy_performance
    
    # Increment counter and display summary information
    counter += 1
    if log:
        print(counter, "drugs done")
        print("*" * 50)
        print("")
# Out:
# Erlotinib (347, 147)
# Best CV score (RMSE): 0.08120291865173236
# Best parameters: {'estimator__alpha': 5.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.07630734986277565
# Correlation with the training set: (0.5172220123741602, 5.868314066133642e-18)
#
# RMSE on test data: 0.06413236771815596
# Mean absolute error on test data: 0.039198860332930116
# Correlation with the test set: (0.4299575143069548, 4.707016052079047e-06)
#
# Dummy CV RMSE: 0.07699414121333494
# Dummy test RMSE: 0.07096557172657372
# 1 drugs done
# **************************************************
#
# Rapamycin (362, 144)
# Best CV score (RMSE): 0.22324135566945788
# Best parameters: {'estimator__alpha': 5.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.21198581990200463
# Correlation with the training set: (0.4520300228075026, 3.819159533435406e-14)
#
# RMSE on test data: 0.23318365513907446
# Mean absolute error on test data: 0.16696642351703633
# Correlation with the test set: (0.21540178735473808, 0.0244865229934914)
#
# Dummy CV RMSE: 0.2227736113351416
# Dummy test RMSE: 0.2381718975951265
# 2 drugs done
# **************************************************
#
# Sunitinib (372, 159)
# Best CV score (RMSE): 0.13163998641253338
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.1109343953267823
# Correlation with the training set: (0.720830068747957, 5.802300280073268e-43)
#
# RMSE on test data: 0.13832273045491306
# Mean absolute error on test data: 0.08913475037848385
# Correlation with the test set: (0.3201242361634404, 0.0005798182261095048)
#
# Dummy CV RMSE: 0.142935620706441
# Dummy test RMSE: 0.1443592045996043
# 3 drugs done
# **************************************************
#
# PHA-665752 (380, 146)
# Best CV score (RMSE): 0.06076374232927697
# Best parameters: {'estimator__alpha': 30.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.05974189618370502
# Correlation with the training set: (0.25986481724361327, 1.768511768045696e-05)
#
# RMSE on test data: 0.027499737371117626
# Mean absolute error on test data: 0.020385917005398685
# Correlation with the test set: (0.11549212405051124, 0.22109260874557463)
#
# Dummy CV RMSE: 0.05192732069612942
# Dummy test RMSE: 0.02745025502562561
# 4 drugs done
# **************************************************
#
# MG-132 (400, 144)
# Best CV score (RMSE): 0.12475342557780275
# Best parameters: {'estimator__alpha': 5.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.11927920119190329
# Correlation with the training set: (0.4409195858622806, 9.523795688308875e-15)
#
# RMSE on test data: 0.1271214339898637
# Mean absolute error on test data: 0.10318604507980846
# Correlation with the test set: (0.2599798327968796, 0.004135870397458138)
#
# Dummy CV RMSE: 0.12967827067375035
# Dummy test RMSE: 0.13160617243829892
# 5 drugs done
# **************************************************
#
# Paclitaxel (388, 150)
# Best CV score (RMSE): 0.18998420364818921
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.75}
#
# RMSE on training data: 0.17083142287635433
# Correlation with the training set: (0.5305956721659036, 4.4128221423272265e-21)
#
# RMSE on test data: 0.19749401670326647
# Mean absolute error on test data: 0.16768936634858478
# Correlation with the test set: (0.12432375825346585, 0.18170737617328575)
#
# Dummy CV RMSE: 0.1969821118965361
# Dummy test RMSE: 0.1979248929357995
# 6 drugs done
# **************************************************
#
# Cyclopamine (396, 144)
# Best CV score (RMSE): 0.03796502601714018
# Best parameters: {'estimator__alpha': 5.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.036526185634673906
# Correlation with the training set: (0.34538082696140626, 3.526587844252994e-09)
#
# RMSE on test data: 0.03169644884456928
# Mean absolute error on test data: 0.022848841419931768
# Correlation with the test set: (0.21888868505738365, 0.016771970716587734)
#
# Dummy CV RMSE: 0.03784510593795913
# Dummy test RMSE: 0.032466628919677956
# 7 drugs done
# **************************************************
#
# AZ628 (377, 145)
# Best CV score (RMSE): 0.15329335997427967
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.5}
#
# RMSE on training data: 0.12750706221667554
# Correlation with the training set: (0.7471898028581452, 3.225157408063489e-48)
#
# RMSE on test data: 0.1484852183967267
# Mean absolute error on test data: 0.10917604445329877
# Correlation with the test set: (0.6497017183928192, 5.269988689990347e-15)
#
# Dummy CV RMSE: 0.188492861423681
# Dummy test RMSE: 0.19494662645869576
# 8 drugs done
# **************************************************
#
# Sorafenib (377, 162)
# Best CV score (RMSE): 0.11856430366303156
# Best parameters: {'estimator__alpha': 0.1, 'estimator__l1_ratio': 0.1}
#
# RMSE on training data: 0.10961648382715954
# Correlation with the training set: (0.5155987789359361, 2.897151659195202e-19)
#
# RMSE on test data: 0.095529840398507
# Mean absolute error on test data: 0.05972378344875198
# Correlation with the test set: (0.3335557023621381, 0.00028719356510819644)
#
# Dummy CV RMSE: 0.11835127608696665
# Dummy test RMSE: 0.10104082382314131
# 9 drugs done
# **************************************************
#
# Tozasertib (382, 147)
# Best CV score (RMSE): 0.19324706039047795
# Best parameters: {'estimator__alpha': 5.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.18471150905234643
# Correlation with the training set: (0.3745394110691698, 2.5661104408814593e-10)
#
# RMSE on test data: 0.1960840782591237
# Mean absolute error on test data: 0.15817152479802526
# Correlation with the test set: (0.22873124231902636, 0.01394171448789948)
#
# Dummy CV RMSE: 0.19321022673410207
# Dummy test RMSE: 0.20081457418511894
# 10 drugs done
# **************************************************
#
# Imatinib (380, 157)
# Best CV score (RMSE): 0.08554391903549853
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 1.0}
#
# RMSE on training data: 0.07926019014681235
# Correlation with the training set: (0.49416887887199823, 8.738302053119963e-18)
#
# RMSE on test data: 0.06450757205333303
# Mean absolute error on test data: 0.0329480501842621
# Correlation with the test set: (0.16343981474324906, 0.08229334441189233)
#
# Dummy CV RMSE: 0.07430120542713381
# Dummy test RMSE: 0.06290019799353104
# 11 drugs done
# **************************************************
#
# NVP-TAE684 (379, 145)
# Best CV score (RMSE): 0.1338933542108844
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.75}
#
# RMSE on training data: 0.12068400835930126
# Correlation with the training set: (0.6549877124409399, 7.411723536376463e-34)
#
# RMSE on test data: 0.12314032003820398
# Mean absolute error on test data: 0.0969262021845199
# Correlation with the test set: (0.4093409932583145, 6.1207680924834565e-06)
#
# Dummy CV RMSE: 0.15328147967557829
# Dummy test RMSE: 0.13213707231188704
# 12 drugs done
# **************************************************
#
# Crizotinib (379, 149)
# Best CV score (RMSE): 0.07215532434255076
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.06198436685576606
# Correlation with the training set: (0.6596954460145671, 1.7556973457116188e-34)
#
# RMSE on test data: 0.043042574762099294
# Mean absolute error on test data: 0.030123767852417334
# Correlation with the test set: (0.4641537957935576, 1.9764186254565557e-07)
#
# Dummy CV RMSE: 0.07148142510753884
# Dummy test RMSE: 0.048153759043624574
# 13 drugs done
# **************************************************
#
# Saracatinib (406, 145)
# Best CV score (RMSE): 0.08448913573490568
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.5}
#
# RMSE on training data: 0.07869846574616349
# Correlation with the training set: (0.472260099502555, 3.500303683435841e-17)
#
# RMSE on test data: 0.053623223789254
# Mean absolute error on test data: 0.04275213628111793
# Correlation with the test set: (0.35427387042480557, 6.2427133212086e-05)
#
# Dummy CV RMSE: 0.08553010709128407
# Dummy test RMSE: 0.055068056919315
# 14 drugs done
# **************************************************
#
# S-Trityl-L-cysteine (397, 144)
# Best CV score (RMSE): 0.12886246583534652
# Best parameters: {'estimator__alpha': 30.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.1267766989386144
# Correlation with the training set: (0.2613497018882935, 1.0486647306205437e-05)
#
# RMSE on test data: 0.12974359499198496
# Mean absolute error on test data: 0.10938165719936249
# Correlation with the test set: (0.3181544318251146, 0.00039830510691741936)
#
# Dummy CV RMSE: 0.1293992928141039
# Dummy test RMSE: 0.13304404481865914
# 15 drugs done
# **************************************************
#
# Dasatinib (369, 174)
# Best CV score (RMSE): 0.216915204250626
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.5}
#
# RMSE on training data: 0.17104227403243022
# Correlation with the training set: (0.7647448838846853, 8.810114130927631e-51)
#
# RMSE on test data: 0.26030889548307556
# Mean absolute error on test data: 0.190134177833353
# Correlation with the test set: (0.33840032510305956, 0.00028047639950015506)
#
# Dummy CV RMSE: 0.25989510330242505
# Dummy test RMSE: 0.26432504424334047
# 16 drugs done
# **************************************************
#
# GNF-2 (370, 144)
# Best CV score (RMSE): 0.03923335884767753
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.03440223963735584
# Correlation with the training set: (0.7104785034993525, 4.2166655068500107e-41)
#
# RMSE on test data: 0.05302462296235967
# Mean absolute error on test data: 0.024628300775499302
# Correlation with the test set: (0.5615365179225754, 1.4411001186648766e-10)
#
# Dummy CV RMSE: 0.03673795070066288
# Dummy test RMSE: 0.06330078760008
# 17 drugs done
# **************************************************
#
# CGP-082996 (387, 145)
# Best CV score (RMSE): 0.06037355629119562
# Best parameters: {'estimator__alpha': 5.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.05733177931665996
# Correlation with the training set: (0.41686305646251415, 8.939734704075175e-13)
#
# RMSE on test data: 0.04803123236569982
# Mean absolute error on test data: 0.04052488247831637
# Correlation with the test set: (0.2694806500965758, 0.003301879250227221)
#
# Dummy CV RMSE: 0.060666158250260206
# Dummy test RMSE: 0.04982136717579758
# 18 drugs done
# **************************************************
#
# A-770041 (399, 145)
# Best CV score (RMSE): 0.17168913473736908
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.9}
#
# RMSE on training data: 0.15849660981307245
# Correlation with the training set: (0.5083172402002827, 9.759382144389714e-20)
#
# RMSE on test data: 0.13308041175129207
# Mean absolute error on test data: 0.09861008732774185
# Correlation with the test set: (0.48094071464520216, 2.699036629925871e-08)
#
# Dummy CV RMSE: 0.1787519630676238
# Dummy test RMSE: 0.1508975767951093
# 19 drugs done
# **************************************************
#
# WH-4-023 (396, 145)
# Best CV score (RMSE): 0.20603712802874766
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.18537519477365874
# Correlation with the training set: (0.5704356879358445, 2.6099250073668056e-25)
#
# RMSE on test data: 0.19436684234734825
# Mean absolute error on test data: 0.13138101183318554
# Correlation with the test set: (0.35562480896692544, 7.217088617671928e-05)
#
# Dummy CV RMSE: 0.21757828475391908
# Dummy test RMSE: 0.20792655578170258
# 20 drugs done
# **************************************************
#
# WZ-1-84 (398, 144)
# Best CV score (RMSE): 0.05921213607204846
# Best parameters: {'estimator__alpha': 5.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.05653637606318296
# Correlation with the training set: (0.46043448811147303, 5.40658242889329e-16)
#
# RMSE on test data: 0.05483656409932714
# Mean absolute error on test data: 0.0395615159215135
# Correlation with the test set: (0.38357019502867884, 1.52934888192486e-05)
#
# Dummy CV RMSE: 0.059499996599394325
# Dummy test RMSE: 0.05919907409607344
# 21 drugs done
# **************************************************
#
# BI-2536 (397, 146)
# Best CV score (RMSE): 0.140157734080194
# Best parameters: {'estimator__alpha': 5.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.13396527965074753
# Correlation with the training set: (0.39326972993415354, 1.1110828138536722e-11)
#
# RMSE on test data: 0.17070070414583174
# Mean absolute error on test data: 0.14710535740181688
# Correlation with the test set: (0.2624917148811988, 0.003775633117165569)
#
# Dummy CV RMSE: 0.14136156988331644
# Dummy test RMSE: 0.17623620404417156
# 22 drugs done
# **************************************************
#
# BMS-536924 (388, 145)
# Best CV score (RMSE): 0.15820862649778025
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 1.0}
#
# RMSE on training data: 0.1468149365231147
# Correlation with the training set: (0.5531181508400519, 4.0569919055845454e-23)
#
# RMSE on test data: 0.1484188586281531
# Mean absolute error on test data: 0.1165168672317961
# Correlation with the test set: (0.3078536252396519, 0.0007339107294854199)
#
# Dummy CV RMSE: 0.17202052033065027
# Dummy test RMSE: 0.15369042514929845
# 23 drugs done
# **************************************************
#
# BMS-509744 (399, 144)
# Best CV score (RMSE): 0.07287569078058853
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.5}
#
# RMSE on training data: 0.06823065381520106
# Correlation with the training set: (0.4707560664439385, 8.56892268091101e-17)
#
# RMSE on test data: 0.07012187731803389
# Mean absolute error on test data: 0.054385162536849024
# Correlation with the test set: (0.2418046832156653, 0.007797429066358864)
#
# Dummy CV RMSE: 0.07483498680967486
# Dummy test RMSE: 0.07215883916366855
# 24 drugs done
# **************************************************
#
# Pyrimethamine (401, 144)
# Best CV score (RMSE): 0.11678433730799044
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.10582745101741242
# Correlation with the training set: (0.5129093967739824, 3.4434667115658487e-20)
#
# RMSE on test data: 0.11829533814777383
# Mean absolute error on test data: 0.08646036173588648
# Correlation with the test set: (0.21511815024743283, 0.01780977491539438)
#
# Dummy CV RMSE: 0.11661703911651625
# Dummy test RMSE: 0.12136745255786242
# 25 drugs done
# **************************************************
#
# JW-7-52-1 (358, 145)
# Best CV score (RMSE): 0.22245957562475835
# Best parameters: {'estimator__alpha': 5.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.21295677299632954
# Correlation with the training set: (0.40218547706000185, 3.8849703114954534e-11)
#
# RMSE on test data: 0.23183122212249554
# Mean absolute error on test data: 0.19302014764496125
# Correlation with the test set: (0.20058455807722567, 0.037389614245227486)
#
# Dummy CV RMSE: 0.22815215204432132
# Dummy test RMSE: 0.23624677701981267
# 26 drugs done
# **************************************************
#
# A-443654 (372, 153)
# Best CV score (RMSE): 0.13646418630573842
# Best parameters: {'estimator__alpha': 5.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.1301511398754372
# Correlation with the training set: (0.43202093267366926, 3.016785409778601e-13)
#
# RMSE on test data: 0.14446433182242743
# Mean absolute error on test data: 0.11670328928317676
# Correlation with the test set: (-0.01206955515629017, 0.8994914485348399)
#
# Dummy CV RMSE: 0.13819231163183748
# Dummy test RMSE: 0.1431336378144807
# 27 drugs done
# **************************************************
#
# GW843682X (399, 144)
# Best CV score (RMSE): 0.18530134368905954
# Best parameters: {'estimator__alpha': 5.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.17545710421328886
# Correlation with the training set: (0.3839803840779727, 3.109995745023584e-11)
#
# RMSE on test data: 0.2014454757179797
# Mean absolute error on test data: 0.17452832624150835
# Correlation with the test set: (0.25943140858121777, 0.004218502080665831)
#
# Dummy CV RMSE: 0.18704532584274935
# Dummy test RMSE: 0.2078261407145027
# 28 drugs done
# **************************************************
#
# Entinostat (400, 145)
# Best CV score (RMSE): 0.16759194929410295
# Best parameters: {'estimator__alpha': 5.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.15944145967558315
# Correlation with the training set: (0.36431161661856554, 3.253786721316729e-10)
#
# RMSE on test data: 0.14000437019306172
# Mean absolute error on test data: 0.11426720241066655
# Correlation with the test set: (0.33920401083755175, 0.0001507088280402714)
#
# Dummy CV RMSE: 0.16878497437020812
# Dummy test RMSE: 0.14883350209915255
# 29 drugs done
# **************************************************
#
# Bortezomib (390, 146)
# Best CV score (RMSE): 0.18120466171627844
# Best parameters: {'estimator__alpha': 5.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.1714192976342724
# Correlation with the training set: (0.4760799034194932, 7.531960134491884e-17)
#
# RMSE on test data: 0.17923683316873018
# Mean absolute error on test data: 0.14945530510304256
# Correlation with the test set: (0.38534841334736625, 1.7841067460604473e-05)
#
# Dummy CV RMSE: 0.19142292482240836
# Dummy test RMSE: 0.19303431763373705
# 30 drugs done
# **************************************************
#
# Seliciclib (386, 152)
# Best CV score (RMSE): 0.044477062223604924
# Best parameters: {'estimator__alpha': 50.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.04394532776196716
# Correlation with the training set: (0.2292614077814403, 0.00014445489981028447)
#
# RMSE on test data: 0.044647422889630445
# Mean absolute error on test data: 0.034852862708624775
# Correlation with the test set: (0.19906848135556773, 0.03216901539974498)
#
# Dummy CV RMSE: 0.044147600662650645
# Dummy test RMSE: 0.045038342399505944
# 31 drugs done
# **************************************************
#
# Salubrinal (398, 144)
# Best CV score (RMSE): 0.06314587292981573
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.5}
#
# RMSE on training data: 0.06107163367079944
# Correlation with the training set: (0.3508589640536589, 1.7882787829968335e-09)
#
# RMSE on test data: 0.052362151654206414
# Mean absolute error on test data: 0.04331658284938267
# Correlation with the test set: (0.18146593355067267, 0.04730562149096253)
#
# Dummy CV RMSE: 0.06421525006702951
# Dummy test RMSE: 0.053365369674450366
# 32 drugs done
# **************************************************
#
# Lapatinib (371, 149)
# Best CV score (RMSE): 0.07010141691680143
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.05931821525974304
# Correlation with the training set: (0.7434739101907498, 8.302858692337301e-47)
#
# RMSE on test data: 0.08274002514024867
# Mean absolute error on test data: 0.04300536409185324
# Correlation with the test set: (0.34676890087795087, 0.000179962021092151)
#
# Dummy CV RMSE: 0.07755898411046627
# Dummy test RMSE: 0.0819327543402351
# 33 drugs done
# **************************************************
#
# GSK269962A (391, 146)
# Best CV score (RMSE): 0.11198080782654805
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.09943224770505472
# Correlation with the training set: (0.5515579220639428, 3.937061505339032e-23)
#
# RMSE on test data: 0.13834090039417068
# Mean absolute error on test data: 0.08167643287277343
# Correlation with the test set: (0.2923966913065025, 0.001313797505265724)
#
# Dummy CV RMSE: 0.11452634435171163
# Dummy test RMSE: 0.1445337779025286
# 34 drugs done
# **************************************************
#
# Doxorubicin (871, 145)
# Best CV score (RMSE): 0.2036971942183946
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.1924343729885846
# Correlation with the training set: (0.4143546672972165, 1.1507988685429479e-26)
#
# RMSE on test data: 0.1937623841340362
# Mean absolute error on test data: 0.15991480798163366
# Correlation with the test set: (0.24420628765348482, 6.48119997787849e-05)
#
# Dummy CV RMSE: 0.2076112080301129
# Dummy test RMSE: 0.19981275469543863
# 35 drugs done
# **************************************************
#
# Etoposide (881, 145)
# Best CV score (RMSE): 0.21523213745264913
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.20352078375708763
# Correlation with the training set: (0.4645921469648236, 2.6261765613164105e-34)
#
# RMSE on test data: 0.2075344409131722
# Mean absolute error on test data: 0.17716637357338355
# Correlation with the test set: (0.2933188801268422, 1.1760891419258288e-06)
#
# Dummy CV RMSE: 0.22584447733705204
# Dummy test RMSE: 0.21678754691653096
# 36 drugs done
# **************************************************
#
# Gemcitabine (843, 148)
# Best CV score (RMSE): 0.29693485640279416
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.75}
#
# RMSE on training data: 0.2791581124245224
# Correlation with the training set: (0.475428574941406, 1.3243581678713515e-34)
#
# RMSE on test data: 0.30021125017468664
# Mean absolute error on test data: 0.25971373728340497
# Correlation with the test set: (0.22051109019119858, 0.0004098305863054015)
#
# Dummy CV RMSE: 0.3148278857063786
# Dummy test RMSE: 0.30484467357967293
# 37 drugs done
# **************************************************
#
# Bicalutamide (870, 144)
# Best CV score (RMSE): 0.01197948737320554
# Best parameters: {'estimator__alpha': 10.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.011792238532233709
# Correlation with the training set: (0.28835784566764894, 3.9828474447643463e-13)
#
# RMSE on test data: 0.010028049549972658
# Mean absolute error on test data: 0.005596645448346389
# Correlation with the test set: (0.2204233419834769, 0.0003329837445981429)
#
# Dummy CV RMSE: 0.010745214708657984
# Dummy test RMSE: 0.010278623982170958
# 38 drugs done
# **************************************************
#
# QS11 (848, 145)
# Best CV score (RMSE): 0.08714514583039462
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.08250930081358397
# Correlation with the training set: (0.4004731402192125, 2.9942576219522722e-24)
#
# RMSE on test data: 0.07714129556015202
# Mean absolute error on test data: 0.06254766600245372
# Correlation with the test set: (0.1735495197392783, 0.005454902508009168)
#
# Dummy CV RMSE: 0.0877468076738381
# Dummy test RMSE: 0.07808913297774242
# 39 drugs done
# **************************************************
#
# CP466722 (867, 145)
# Best CV score (RMSE): 0.1034285766002596
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.5}
#
# RMSE on training data: 0.0991738187603735
# Correlation with the training set: (0.5778004593268568, 2.92506544366053e-55)
#
# RMSE on test data: 0.10098451134528946
# Mean absolute error on test data: 0.080565685885783
# Correlation with the test set: (0.5817386002724817, 4.924727123662548e-25)
#
# Dummy CV RMSE: 0.12045417643961169
# Dummy test RMSE: 0.12327543477670332
# 40 drugs done
# **************************************************
#
# Midostaurin (858, 145)
# Best CV score (RMSE): 0.08366908616964595
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.07855372046603215
# Correlation with the training set: (0.4959160420848257, 1.4501959626775344e-38)
#
# RMSE on test data: 0.07700018296378133
# Mean absolute error on test data: 0.0608784696007202
# Correlation with the test set: (0.3777924635094366, 3.546495282137194e-10)
#
# Dummy CV RMSE: 0.08870925998179173
# Dummy test RMSE: 0.08310588482093066
# 41 drugs done
# **************************************************
#
# CHIR-99021 (855, 146)
# Best CV score (RMSE): 0.038180964217902
# Best parameters: {'estimator__alpha': 5.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.0373277414990984
# Correlation with the training set: (0.35887175809842753, 1.2917587984410127e-19)
#
# RMSE on test data: 0.046283830193211514
# Mean absolute error on test data: 0.025243306773476977
# Correlation with the test set: (0.30384246254455627, 6.866496990109681e-07)
#
# Dummy CV RMSE: 0.03876090314694976
# Dummy test RMSE: 0.04839584764010036
# 42 drugs done
# **************************************************
#
# Ponatinib (826, 172)
# Best CV score (RMSE): 0.11652997735502695
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.1072956907070708
# Correlation with the training set: (0.5597253938753717, 5.7837076370772545e-49)
#
# RMSE on test data: 0.15459715214265488
# Mean absolute error on test data: 0.08280714719704801
# Correlation with the test set: (0.48878927698604896, 2.677812643745007e-16)
#
# Dummy CV RMSE: 0.123133423682808
# Dummy test RMSE: 0.17302210577957286
# 43 drugs done
# **************************************************
#
# HG6-64-1 (827, 145)
# Best CV score (RMSE): 0.16032849357294598
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.15189936666172438
# Correlation with the training set: (0.49124029300537086, 1.9288242624084304e-36)
#
# RMSE on test data: 0.1654741424673422
# Mean absolute error on test data: 0.12355652563910229
# Correlation with the test set: (0.3976555554332769, 7.32102249728416e-11)
#
# Dummy CV RMSE: 0.17176437755173146
# Dummy test RMSE: 0.1792919927451297
# 44 drugs done
# **************************************************
#
# JQ1 (880, 147)
# Best CV score (RMSE): 0.1568270415733212
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.5}
#
# RMSE on training data: 0.15077828878694796
# Correlation with the training set: (0.3508769955454247, 2.761094196862698e-19)
#
# RMSE on test data: 0.15125477507277352
# Mean absolute error on test data: 0.1241776724550635
# Correlation with the test set: (0.2740108855886871, 6.248904558104302e-06)
#
# Dummy CV RMSE: 0.1596049972214671
# Dummy test RMSE: 0.15741980210993448
# 45 drugs done
# **************************************************
#
# JQ12 (874, 145)
# Best CV score (RMSE): 0.16170434532134062
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.5}
#
# RMSE on training data: 0.15505648704937844
# Correlation with the training set: (0.3951605925901983, 2.860176095129387e-24)
#
# RMSE on test data: 0.15789359544121953
# Mean absolute error on test data: 0.12581927178636318
# Correlation with the test set: (0.2201119953914306, 0.00032212409442966273)
#
# Dummy CV RMSE: 0.16698174502464552
# Dummy test RMSE: 0.1619104537464577
# 46 drugs done
# **************************************************
#
# AKT inhibitor VIII (823, 149)
# Best CV score (RMSE): 0.05510713996030728
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.25}
#
# RMSE on training data: 0.05289689269705973
# Correlation with the training set: (0.41010995118064575, 8.966931304478017e-25)
#
# RMSE on test data: 0.04912325937872402
# Mean absolute error on test data: 0.03651584154933531
# Correlation with the test set: (0.2975462763506324, 1.927746102156921e-06)
#
# Dummy CV RMSE: 0.05656020274916548
# Dummy test RMSE: 0.05137066268944948
# 47 drugs done
# **************************************************
#
# Embelin (872, 144)
# Best CV score (RMSE): 0.09755335334602203
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.25}
#
# RMSE on training data: 0.09302071549756089
# Correlation with the training set: (0.4045459269298097, 2.0140851890231665e-25)
#
# RMSE on test data: 0.09859222457271968
# Mean absolute error on test data: 0.07943419982358144
# Correlation with the test set: (0.20869617623582068, 0.0006753423020796123)
#
# Dummy CV RMSE: 0.10091651174954239
# Dummy test RMSE: 0.10061578452658965
# 48 drugs done
# **************************************************
#
# IPA-3 (847, 145)
# Best CV score (RMSE): 0.1048192889267339
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.0992201910040546
# Correlation with the training set: (0.5261619946139227, 1.846375437363306e-43)
#
# RMSE on test data: 0.09602947675217731
# Mean absolute error on test data: 0.07945585115822965
# Correlation with the test set: (0.4674550840072909, 3.0118432372711766e-15)
#
# Dummy CV RMSE: 0.11554733462424702
# Dummy test RMSE: 0.10826747234358583
# 49 drugs done
# **************************************************
#
# GSK650394 (840, 146)
# Best CV score (RMSE): 0.12107951808734384
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.11394629251060327
# Correlation with the training set: (0.42671646577891975, 2.0304965752649236e-27)
#
# RMSE on test data: 0.13117656170253947
# Mean absolute error on test data: 0.10349348617117826
# Correlation with the test set: (0.16723360522695002, 0.0078068019531614755)
#
# Dummy CV RMSE: 0.12276933885999448
# Dummy test RMSE: 0.13278689007462469
# 50 drugs done
# **************************************************
#
# BAY-61-3606 (868, 144)
# Best CV score (RMSE): 0.1180296048297052
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.11191930762088129
# Correlation with the training set: (0.45710867924586773, 1.135431120744292e-32)
#
# RMSE on test data: 0.11585140187946696
# Mean absolute error on test data: 0.09264479802135525
# Correlation with the test set: (0.3906144033306598, 6.069221068421759e-11)
#
# Dummy CV RMSE: 0.12403865611892913
# Dummy test RMSE: 0.12531902985171142
# 51 drugs done
# **************************************************
#
# 5-Fluorouracil (888, 146)
# Best CV score (RMSE): 0.1484179217382459
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.14073167128448255
# Correlation with the training set: (0.5734631958207665, 1.3952511632317395e-55)
#
# RMSE on test data: 0.1348357067615304
# Mean absolute error on test data: 0.10531987596139336
# Correlation with the test set: (0.5957559258316246, 4.8447684190442615e-27)
#
# Dummy CV RMSE: 0.16943702739095318
# Dummy test RMSE: 0.16615080222722112
# 52 drugs done
# **************************************************
#
# Obatoclax Mesylate (841, 146)
# Best CV score (RMSE): 0.21303321222980082
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.2002089446909703
# Correlation with the training set: (0.513144507974618, 8.292859395197863e-41)
#
# RMSE on test data: 0.20143240081655905
# Mean absolute error on test data: 0.16528029674984349
# Correlation with the test set: (0.39470054368474766, 7.348214981819055e-11)
#
# Dummy CV RMSE: 0.22793456850508434
# Dummy test RMSE: 0.2183557776391087
# 53 drugs done
# **************************************************
#
# BMS-754807 (844, 145)
# Best CV score (RMSE): 0.1607707864526243
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.1524140510595661
# Correlation with the training set: (0.5144820277266856, 3.5130870726535804e-41)
#
# RMSE on test data: 0.1799149733085897
# Mean absolute error on test data: 0.1310965274086227
# Correlation with the test set: (0.3657858952158075, 1.8495720600871817e-09)
#
# Dummy CV RMSE: 0.1728082069857379
# Dummy test RMSE: 0.1926638198333312
# 54 drugs done
# **************************************************
#
# Linsitinib (844, 145)
# Best CV score (RMSE): 0.10307223656514031
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.5}
#
# RMSE on training data: 0.0990523183966598
# Correlation with the training set: (0.421868159038843, 7.329967305905192e-27)
#
# RMSE on test data: 0.11793798839111354
# Mean absolute error on test data: 0.07254152512084204
# Correlation with the test set: (0.39698377814469615, 5.1155879140489254e-11)
#
# Dummy CV RMSE: 0.10638652253161134
# Dummy test RMSE: 0.12708357300187606
# 55 drugs done
# **************************************************
#
# Bexarotene (860, 146)
# Best CV score (RMSE): 0.06907510593227788
# Best parameters: {'estimator__alpha': 5.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.06735891777567679
# Correlation with the training set: (0.31194887337478727, 4.714478275290163e-15)
#
# RMSE on test data: 0.05715178760532357
# Mean absolute error on test data: 0.04007914967450827
# Correlation with the test set: (0.179029458369349, 0.003913885324118403)
#
# Dummy CV RMSE: 0.06612105857674619
# Dummy test RMSE: 0.05806351077593512
# 56 drugs done
# **************************************************
#
# LFM-A13 (870, 144)
# Best CV score (RMSE): 0.02716640606411587
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.25}
#
# RMSE on training data: 0.026841732292894774
# Correlation with the training set: (0.2975335024193096, 6.485424623765958e-14)
#
# RMSE on test data: 0.02584580591393653
# Mean absolute error on test data: 0.01901159300873667
# Correlation with the test set: (0.23070412003611107, 0.00016984709673316265)
#
# Dummy CV RMSE: 0.027478190748420388
# Dummy test RMSE: 0.026531110243537572
# 57 drugs done
# **************************************************
#
# GW-2580 (922, 144)
# Best CV score (RMSE): 0.03690243754836828
# Best parameters: {'estimator__alpha': 0.1, 'estimator__l1_ratio': 0.25}
#
# RMSE on training data: 0.03685703063758757
# Correlation with the training set: (4.763545779305672e-16, 1.0)
#
# RMSE on test data: 0.018098987412116553
# Mean absolute error on test data: 0.010813407673579035
# Correlation with the test set: (nan, 1.0)
#
# Dummy CV RMSE: 0.026696379894553403
# Dummy test RMSE: 0.018098987412116553
# 58 drugs done
# **************************************************
#
# Phenformin (887, 147)
# Best CV score (RMSE): 0.1851655649123658
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.1759337727670418
# Correlation with the training set: (0.5334786750366053, 6.809657863854825e-47)
#
# RMSE on test data: 0.18435090221052425
# Mean absolute error on test data: 0.1413379931851781
# Correlation with the test set: (0.4380528379744646, 6.047811876243746e-14)
#
# Dummy CV RMSE: 0.20609000110223025
# Dummy test RMSE: 0.2046909852581266
# 59 drugs done
# **************************************************
#
# Pazopanib (814, 161)
# Best CV score (RMSE): 0.077228523192112
# Best parameters: {'estimator__alpha': 5.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.07500871310313476
# Correlation with the training set: (0.34689523003268136, 1.5599960379891757e-17)
#
# RMSE on test data: 0.12244064200201575
# Mean absolute error on test data: 0.06647089500584986
# Correlation with the test set: (0.30606994931473713, 1.0397301791845626e-06)
#
# Dummy CV RMSE: 0.07832874775550738
# Dummy test RMSE: 0.1268282281909517
# 60 drugs done
# **************************************************
#
# Dacinostat (872, 144)
# Best CV score (RMSE): 0.1542092807483076
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.75}
#
# RMSE on training data: 0.1498250891942239
# Correlation with the training set: (0.4572333835113499, 7.625345919780927e-33)
#
# RMSE on test data: 0.15584991028751163
# Mean absolute error on test data: 0.11899020002875164
# Correlation with the test set: (0.3347451891704232, 2.800790103437064e-08)
#
# Dummy CV RMSE: 0.16764569637815901
# Dummy test RMSE: 0.1650067198534384
# 61 drugs done
# **************************************************
#
# Epothilone B (848, 157)
# Best CV score (RMSE): 0.2087168311972843
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.19677205539447862
# Correlation with the training set: (0.44570182335098746, 2.776298214717006e-30)
#
# RMSE on test data: 0.20400128673280088
# Mean absolute error on test data: 0.17537130608690146
# Correlation with the test set: (0.3145336951920127, 2.916200883897301e-07)
#
# Dummy CV RMSE: 0.21593392715682774
# Dummy test RMSE: 0.21388180712075974
# 62 drugs done
# **************************************************
#
# GSK1904529A (848, 145)
# Best CV score (RMSE): 0.023618475105940024
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.25}
#
# RMSE on training data: 0.023434821400756412
# Correlation with the training set: (0.2874589901039049, 9.575035427747582e-13)
#
# RMSE on test data: 0.02095009311857142
# Mean absolute error on test data: 0.013330117315496085
# Correlation with the test set: (0.15948710370515995, 0.010752557690824381)
#
# Dummy CV RMSE: 0.02346161748300864
# Dummy test RMSE: 0.021202418220412227
# 63 drugs done
# **************************************************
#
# Ruxolitinib (896, 147)
# Best CV score (RMSE): 0.053295201649335176
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.25}
#
# RMSE on training data: 0.051486980284283744
# Correlation with the training set: (0.38453845177543433, 1.5779411564829236e-23)
#
# RMSE on test data: 0.06040521154281704
# Mean absolute error on test data: 0.01769011267497083
# Correlation with the test set: (0.44439823620637187, 1.8981242630479896e-14)
#
# Dummy CV RMSE: 0.046279052961152686
# Dummy test RMSE: 0.06553323268696308
# 64 drugs done
# **************************************************
#
# AT-7519 (893, 150)
# Best CV score (RMSE): 0.1894286952492
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.1793495127573048
# Correlation with the training set: (0.6240506271619077, 9.178683313953007e-69)
#
# RMSE on test data: 0.19084193237792793
# Mean absolute error on test data: 0.1610450213107951
# Correlation with the test set: (0.5455217974483323, 3.5056126012322577e-22)
#
# Dummy CV RMSE: 0.22779982509785116
# Dummy test RMSE: 0.22772762941589075
# 65 drugs done
# **************************************************
#
# AS605240 (918, 144)
# Best CV score (RMSE): 0.1609598529488277
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.15252931916861054
# Correlation with the training set: (0.5319974071366341, 3.412607633730408e-48)
#
# RMSE on test data: 0.1438378446138713
# Mean absolute error on test data: 0.10575906930409054
# Correlation with the test set: (0.3847317060431157, 3.6125475553176014e-11)
#
# Dummy CV RMSE: 0.1743373242147541
# Dummy test RMSE: 0.15585832017835294
# 66 drugs done
# **************************************************
#
# Genentech Cpd 10 (897, 146)
# Best CV score (RMSE): 0.1402933620504031
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.13319383440030638
# Correlation with the training set: (0.5900251622031646, 4.5398683829699026e-60)
#
# RMSE on test data: 0.13273547037524555
# Mean absolute error on test data: 0.10143957369982559
# Correlation with the test set: (0.40278780378719214, 5.92398042263914e-12)
#
# Dummy CV RMSE: 0.16307297781991936
# Dummy test RMSE: 0.14377718619600263
# 67 drugs done
# **************************************************
#
# GSK1070916 (869, 146)
# Best CV score (RMSE): 0.17563142410973337
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.25}
#
# RMSE on training data: 0.1567580286540083
# Correlation with the training set: (0.6963130343636844, 2.4121609415724478e-89)
#
# RMSE on test data: 0.1855486170494027
# Mean absolute error on test data: 0.11457110046015537
# Correlation with the test set: (0.5581760369757638, 8.873943632656008e-23)
#
# Dummy CV RMSE: 0.2156021199597688
# Dummy test RMSE: 0.2229012951462211
# 68 drugs done
# **************************************************
#
# AKT inhibitor VIII (863, 149)
# Best CV score (RMSE): 0.10839366392094826
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.25}
#
# RMSE on training data: 0.10008190313022143
# Correlation with the training set: (0.6633629325164613, 7.623163678336491e-78)
#
# RMSE on test data: 0.11246584270088865
# Mean absolute error on test data: 0.0827267514592465
# Correlation with the test set: (0.6164650585445637, 1.6736130230663453e-28)
#
# Dummy CV RMSE: 0.13304914826916497
# Dummy test RMSE: 0.14194518450442792
# 69 drugs done
# **************************************************
#
# GSK429286A (897, 146)
# Best CV score (RMSE): 0.06935680177517639
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.06578068807776484
# Correlation with the training set: (0.48132157899797406, 1.1290841195602082e-37)
#
# RMSE on test data: 0.05339176038693546
# Mean absolute error on test data: 0.03209602036824363
# Correlation with the test set: (0.3492019402936884, 3.677898334899908e-09)
#
# Dummy CV RMSE: 0.07122161778456834
# Dummy test RMSE: 0.0572091068889053
# 70 drugs done
# **************************************************
#
# QL-XII-47 (920, 145)
# Best CV score (RMSE): 0.17662973582831445
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.9}
#
# RMSE on training data: 0.17273475309902153
# Correlation with the training set: (0.4194201247412894, 7.935289924367487e-29)
#
# RMSE on test data: 0.1750574078933401
# Mean absolute error on test data: 0.14579109958851974
# Correlation with the test set: (0.3368202720246612, 9.532816058247318e-09)
#
# Dummy CV RMSE: 0.18939399408843777
# Dummy test RMSE: 0.18598576178682436
# 71 drugs done
# **************************************************
#
# Cabozantinib (861, 157)
# Best CV score (RMSE): 0.09533254970637906
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.5}
#
# RMSE on training data: 0.09129678213883662
# Correlation with the training set: (0.5602769073805309, 4.7534002982254916e-51)
#
# RMSE on test data: 0.09124615013309105
# Mean absolute error on test data: 0.0588069363756401
# Correlation with the test set: (0.16152774267303102, 0.009211813020269442)
#
# Dummy CV RMSE: 0.10739583602223746
# Dummy test RMSE: 0.08557861773830903
# 72 drugs done
# **************************************************
#
# WZ3105 (863, 154)
# Best CV score (RMSE): 0.14050530645997164
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.5}
#
# RMSE on training data: 0.13076330916822357
# Correlation with the training set: (0.6497034942148925, 1.0294824281242015e-73)
#
# RMSE on test data: 0.14992681048748158
# Mean absolute error on test data: 0.11387849212482332
# Correlation with the test set: (0.5215362459914443, 1.8145379638660093e-19)
#
# Dummy CV RMSE: 0.170161751013408
# Dummy test RMSE: 0.17569371607430592
# 73 drugs done
# **************************************************
#
# XMD14-99 (863, 148)
# Best CV score (RMSE): 0.03176355644528099
# Best parameters: {'estimator__alpha': 0.001, 'estimator__l1_ratio': 0.9}
#
# RMSE on training data: 0.029096252064303964
# Correlation with the training set: (0.586536012060135, 4.2216387121479975e-57)
#
# RMSE on test data: 0.024615163759834465
# Mean absolute error on test data: 0.01700797538290549
# Correlation with the test set: (0.4886154458452787, 6.011912392344707e-17)
#
# Dummy CV RMSE: 0.03504344826881377
# Dummy test RMSE: 0.0278696816721942
# 74 drugs done
# **************************************************
#
# Quizartinib (862, 146)
# Best CV score (RMSE): 0.06893094556428236
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.25}
#
# RMSE on training data: 0.06340191926389857
# Correlation with the training set: (0.5956630630054691, 3.517600324971129e-59)
#
# RMSE on test data: 0.062005705295780006
# Mean absolute error on test data: 0.027967140403710428
# Correlation with the test set: (0.45140181221890385, 2.0872034070561185e-14)
#
# Dummy CV RMSE: 0.06950554028064093
# Dummy test RMSE: 0.06685671494251601
# 75 drugs done
# **************************************************
#
# CP724714 (863, 146)
# Best CV score (RMSE): 0.0467162363570052
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.25}
#
# RMSE on training data: 0.043861229900651645
# Correlation with the training set: (0.580520907897873, 1.050558603615748e-55)
#
# RMSE on test data: 0.05071639664332255
# Mean absolute error on test data: 0.0226755078151363
# Correlation with the test set: (0.2941522605517265, 1.4496822811998677e-06)
#
# Dummy CV RMSE: 0.04788330134872616
# Dummy test RMSE: 0.05271661695848376
# 76 drugs done
# **************************************************
#
# JW-7-24-1 (922, 144)
# Best CV score (RMSE): 0.14006007135552478
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.75}
#
# RMSE on training data: 0.1350725977807164
# Correlation with the training set: (0.5673229625327876, 3.255079342983682e-56)
#
# RMSE on test data: 0.12962377989999702
# Mean absolute error on test data: 0.0999199583281538
# Correlation with the test set: (0.5812369761406293, 1.9825857247257782e-26)
#
# Dummy CV RMSE: 0.16317589558898093
# Dummy test RMSE: 0.1579922232905281
# 77 drugs done
# **************************************************
#
# NPK76-II-72-1 (920, 144)
# Best CV score (RMSE): 0.11055392141998398
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.25}
#
# RMSE on training data: 0.10309514280330546
# Correlation with the training set: (0.6984158139513511, 2.4404248089836044e-95)
#
# RMSE on test data: 0.11789130947330782
# Mean absolute error on test data: 0.0854727522681483
# Correlation with the test set: (0.5951324974838105, 7.767076886648776e-28)
#
# Dummy CV RMSE: 0.1426767002797506
# Dummy test RMSE: 0.1469115442441061
# 78 drugs done
# **************************************************
#
# NG-25 (920, 144)
# Best CV score (RMSE): 0.12839720086030776
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.25}
#
# RMSE on training data: 0.11790727312492576
# Correlation with the training set: (0.6308996735539169, 8.700352538776541e-73)
#
# RMSE on test data: 0.1412636857555196
# Mean absolute error on test data: 0.09778366439612088
# Correlation with the test set: (0.5474604731548707, 5.540343457751647e-23)
#
# Dummy CV RMSE: 0.14888523979781804
# Dummy test RMSE: 0.1698858447001442
# 79 drugs done
# **************************************************
#
# FR-180204 (894, 145)
# Best CV score (RMSE): 0.03649575246377641
# Best parameters: {'estimator__alpha': 0.001, 'estimator__l1_ratio': 1.0}
#
# RMSE on training data: 0.0347772896664635
# Correlation with the training set: (0.42995025821574284, 1.6496204182408965e-29)
#
# RMSE on test data: 0.027419364186988027
# Mean absolute error on test data: 0.020203563432131595
# Correlation with the test set: (0.32908024492037785, 3.2596727761309646e-08)
#
# Dummy CV RMSE: 0.03587032622283391
# Dummy test RMSE: 0.029007109713656637
# 80 drugs done
# **************************************************
#
# Tubastatin A (917, 146)
# Best CV score (RMSE): 0.06529100826662534
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.061760639102846196
# Correlation with the training set: (0.6266973881666136, 3.0685409009923026e-71)
#
# RMSE on test data: 0.059473283936840295
# Mean absolute error on test data: 0.043473702771471535
# Correlation with the test set: (0.47756471143519236, 3.9517404597661166e-17)
#
# Dummy CV RMSE: 0.07717418079351494
# Dummy test RMSE: 0.06689630506493317
# 81 drugs done
# **************************************************
#
# Sepantronium bromide (888, 144)
# Best CV score (RMSE): 0.24870061742441277
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.23581229791624206
# Correlation with the training set: (0.44205185914632145, 4.295230891692955e-31)
#
# RMSE on test data: 0.25012415948399175
# Mean absolute error on test data: 0.18682531434445576
# Correlation with the test set: (0.327538420773034, 4.282580025053404e-08)
#
# Dummy CV RMSE: 0.2566428672314717
# Dummy test RMSE: 0.2644383733127208
# 82 drugs done
# **************************************************
#
# NSC-207895 (889, 145)
# Best CV score (RMSE): 0.09097364710610917
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.25}
#
# RMSE on training data: 0.08645521927130774
# Correlation with the training set: (0.43592638760245256, 3.0781993657971382e-30)
#
# RMSE on test data: 0.09473372655094356
# Mean absolute error on test data: 0.06855206321566235
# Correlation with the test set: (0.2715370880670062, 6.7638480367452676e-06)
#
# Dummy CV RMSE: 0.09476259932354357
# Dummy test RMSE: 0.09826825567670788
# 83 drugs done
# **************************************************
#
# AR-42 (911, 144)
# Best CV score (RMSE): 0.17422444793600692
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 1.0}
#
# RMSE on training data: 0.1707051168256611
# Correlation with the training set: (0.5513158354588323, 6.250884859213853e-52)
#
# RMSE on test data: 0.18307632781612548
# Mean absolute error on test data: 0.14569174602506138
# Correlation with the test set: (0.4960266091843893, 2.0100370969355787e-18)
#
# Dummy CV RMSE: 0.2036208968439277
# Dummy test RMSE: 0.2116218537363952
# 84 drugs done
# **************************************************
#
# CUDC-101 (844, 149)
# Best CV score (RMSE): 0.1814534127482047
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.9}
#
# RMSE on training data: 0.1775212369359782
# Correlation with the training set: (0.5433363643441506, 1.2853507098828489e-46)
#
# RMSE on test data: 0.19845085071504348
# Mean absolute error on test data: 0.16321307793732623
# Correlation with the test set: (0.42409108826481623, 1.6451675958956023e-12)
#
# Dummy CV RMSE: 0.21046780694350714
# ...
# Dummy test RMSE: 0.07256863115542375
# 156 drugs done
# **************************************************
#
# HG-5-113-01 (484, 145)
# Best CV score (RMSE): 0.09735792365552103
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.08733419277601959
# Correlation with the training set: (0.5821871448482347, 4.6900205251805134e-32)
#
# RMSE on test data: 0.09340305737152356
# Mean absolute error on test data: 0.0732719878038248
# Correlation with the test set: (0.35314120655449305, 1.2308368755626259e-05)
#
# Dummy CV RMSE: 0.10279531797147871
# Dummy test RMSE: 0.09915311198570526
# 157 drugs done
# **************************************************
#
# HG-5-88-01 (466, 146)
# Best CV score (RMSE): 0.0917425551449775
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 1.0}
#
# RMSE on training data: 0.09103095993414229
# Correlation with the training set: (0.24658436872109663, 6.6420864058798225e-06)
#
# RMSE on test data: 0.0796530069240163
# Mean absolute error on test data: 0.05797138410259306
# Correlation with the test set: (0.1571388737638565, 0.06371637952781956)
#
# Dummy CV RMSE: 0.08921817095748207
# Dummy test RMSE: 0.08033068100786066
# 158 drugs done
# **************************************************
#
# TW 37 (897, 146)
# Best CV score (RMSE): 0.14328129860613306
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.13602900574928123
# Correlation with the training set: (0.4903234504907191, 3.096906241653405e-39)
#
# RMSE on test data: 0.14127268064453938
# Mean absolute error on test data: 0.11312521282750404
# Correlation with the test set: (0.46878128793526574, 3.7140512935303663e-16)
#
# Dummy CV RMSE: 0.15373504653635958
# Dummy test RMSE: 0.15763401563181562
# 159 drugs done
# **************************************************
#
# XMD11-85h (484, 150)
# Best CV score (RMSE): 0.03564240510872355
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.25}
#
# RMSE on training data: 0.034250412718821635
# Correlation with the training set: (0.35311920737761776, 2.3166641620119445e-11)
#
# RMSE on test data: 0.04200419219535904
# Mean absolute error on test data: 0.031337391678259524
# Correlation with the test set: (0.03761564438025891, 0.6521593843550701)
#
# Dummy CV RMSE: 0.035802186547836685
# Dummy test RMSE: 0.04160704352960276
# 160 drugs done
# **************************************************
#
# XMD8-92 (496, 144)
# Best CV score (RMSE): 0.050646627024303524
# Best parameters: {'estimator__alpha': 5.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.04876899899200122
# Correlation with the training set: (0.37117887168555247, 8.918396368193298e-13)
#
# RMSE on test data: 0.06539078527182966
# Mean absolute error on test data: 0.05011672087559852
# Correlation with the test set: (0.20914229798691486, 0.010473838464965751)
#
# Dummy CV RMSE: 0.05113506449900489
# Dummy test RMSE: 0.06661462685456723
# 161 drugs done
# **************************************************
#
# QL-VIII-58 (469, 147)
# Best CV score (RMSE): 0.1765872729259805
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.16029162389729656
# Correlation with the training set: (0.5787946946285161, 9.987590991374077e-31)
#
# RMSE on test data: 0.18950846513271705
# Mean absolute error on test data: 0.15513135688349156
# Correlation with the test set: (0.4159496474775587, 2.904491421514079e-07)
#
# Dummy CV RMSE: 0.18949098816844553
# Dummy test RMSE: 0.20967592185661676
# 162 drugs done
# **************************************************
#
# CCT-018159 (876, 147)
# Best CV score (RMSE): 0.06033699472318518
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.05693087931040433
# Correlation with the training set: (0.4234630396591869, 4.557222318220419e-28)
#
# RMSE on test data: 0.05184359942168326
# Mean absolute error on test data: 0.042545137723784904
# Correlation with the test set: (0.3989740534286217, 1.8099199034656096e-11)
#
# Dummy CV RMSE: 0.0606084679460822
# Dummy test RMSE: 0.05629309545239687
# 163 drugs done
# **************************************************
#
# Rucaparib (898, 147)
# Best CV score (RMSE): 0.037946464100819734
# Best parameters: {'estimator__alpha': 5.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.03713945215167949
# Correlation with the training set: (0.3186712577277653, 2.7390933005062127e-16)
#
# RMSE on test data: 0.04118865160058026
# Mean absolute error on test data: 0.026556510857221896
# Correlation with the test set: (0.286586787660768, 1.6839906135398222e-06)
#
# Dummy CV RMSE: 0.03807637884400934
# Dummy test RMSE: 0.042824737883313466
# 164 drugs done
# **************************************************
#
# GSK269962A (906, 146)
# Best CV score (RMSE): 0.12254891460616217
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.11629752043016911
# Correlation with the training set: (0.4199386748684015, 1.7783888083591497e-28)
#
# RMSE on test data: 0.11436671212529591
# Mean absolute error on test data: 0.07831291009446045
# Correlation with the test set: (0.2720471877708327, 5.308745339029846e-06)
#
# Dummy CV RMSE: 0.12605621511525153
# Dummy test RMSE: 0.11874190262382062
# 165 drugs done
# **************************************************
#
# Tamoxifen (906, 163)
# Best CV score (RMSE): 0.027112639962949946
# Best parameters: {'estimator__alpha': 10.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.026647678667852524
# Correlation with the training set: (0.23862012308559852, 1.1681680075891727e-09)
#
# RMSE on test data: 0.03486521201868462
# Mean absolute error on test data: 0.017512787180956856
# Correlation with the test set: (-0.025761269174569994, 0.6723103666068708)
#
# Dummy CV RMSE: 0.02594573458608332
# Dummy test RMSE: 0.0346393759598115
# 166 drugs done
# **************************************************
#
# QL-XII-61 (473, 145)
# Best CV score (RMSE): 0.06991364349417295
# Best parameters: {'estimator__alpha': 5.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.06632311352697733
# Correlation with the training set: (0.44302660431051005, 2.408580053786858e-17)
#
# RMSE on test data: 0.06099176840623788
# Mean absolute error on test data: 0.04725700898798855
# Correlation with the test set: (0.4000034324684948, 8.141084850961643e-07)
#
# Dummy CV RMSE: 0.07145120571521582
# Dummy test RMSE: 0.06615286991974544
# 167 drugs done
# **************************************************
#
# JQ1 (917, 147)
# Best CV score (RMSE): 0.05992600716896404
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.05711778705501713
# Correlation with the training set: (0.4356496682537871, 4.506723580052664e-31)
#
# RMSE on test data: 0.07223939379016789
# Mean absolute error on test data: 0.04073490801198633
# Correlation with the test set: (0.2729018729790828, 4.207949853410606e-06)
#
# Dummy CV RMSE: 0.0609196686983598
# Dummy test RMSE: 0.0750874726359005
# 168 drugs done
# **************************************************
#
# PFI-1 (933, 144)
# Best CV score (RMSE): 0.07663563284499969
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.25}
#
# RMSE on training data: 0.0738327149190393
# Correlation with the training set: (0.4508668650512877, 5.1666893112906756e-34)
#
# RMSE on test data: 0.0771813171273339
# Mean absolute error on test data: 0.05937770192641734
# Correlation with the test set: (0.1800440267832839, 0.002494688384617638)
#
# Dummy CV RMSE: 0.08203486385271641
# Dummy test RMSE: 0.07680926847141752
# 169 drugs done
# **************************************************
#
# IOX2 (907, 145)
# Best CV score (RMSE): 0.035366849612785016
# Best parameters: {'estimator__alpha': 5.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.034739110655363274
# Correlation with the training set: (0.23525653104168778, 2.0189253736758716e-09)
#
# RMSE on test data: 0.023419219775776663
# Mean absolute error on test data: 0.01242458747488908
# Correlation with the test set: (0.2281901606437787, 0.00014276980461957363)
#
# Dummy CV RMSE: 0.02903474633596594
# Dummy test RMSE: 0.024034924100137713
# 170 drugs done
# **************************************************
#
# CHIR-99021 (893, 146)
# Best CV score (RMSE): 0.05233942333632504
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.04955394879925196
# Correlation with the training set: (0.5072089732881945, 3.654659410079189e-42)
#
# RMSE on test data: 0.0529906212431721
# Mean absolute error on test data: 0.03832434781283516
# Correlation with the test set: (0.4343447275438764, 9.308090086903275e-14)
#
# Dummy CV RMSE: 0.056011124265087364
# Dummy test RMSE: 0.05866612216471506
# 171 drugs done
# **************************************************
#
# Daporinad (879, 145)
# Best CV score (RMSE): 0.30164783682283736
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.75}
#
# RMSE on training data: 0.2807573187412268
# Correlation with the training set: (0.6073627515911133, 2.8555448828000877e-63)
#
# RMSE on test data: 0.2732228892105772
# Mean absolute error on test data: 0.22467790412981248
# Correlation with the test set: (0.6248578194382349, 5.376970720559272e-30)
#
# Dummy CV RMSE: 0.3524317004988565
# Dummy test RMSE: 0.34970532259475623
# 172 drugs done
# **************************************************
#
# Talazoparib (893, 147)
# Best CV score (RMSE): 0.17999877987605323
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.1708172050734645
# Correlation with the training set: (0.44728383376535796, 4.498929800513978e-32)
#
# RMSE on test data: 0.19718236250338447
# Mean absolute error on test data: 0.14468515522359307
# Correlation with the test set: (0.39255466410898593, 2.6314485336126327e-11)
#
# Dummy CV RMSE: 0.1877218292580048
# Dummy test RMSE: 0.21279913408575307
# 173 drugs done
# **************************************************
#
# UNC1215 (889, 145)
# Best CV score (RMSE): 0.008952237466594494
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.008536514392820715
# Correlation with the training set: (0.3693763972335712, 1.529804341408043e-21)
#
# RMSE on test data: 0.01046850304846659
# Mean absolute error on test data: 0.006518213279631283
# Correlation with the test set: (0.12280410608654728, 0.04498278081870425)
#
# Dummy CV RMSE: 0.0089190598534947
# Dummy test RMSE: 0.010511369029919155
# 174 drugs done
# **************************************************
#
# SGC0946 (888, 145)
# Best CV score (RMSE): 0.013521669538264924
# Best parameters: {'estimator__alpha': 5.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.013271686123023714
# Correlation with the training set: (0.2623940484050616, 3.086466777810935e-11)
#
# RMSE on test data: 0.012910988948181556
# Mean absolute error on test data: 0.007459982142424025
# Correlation with the test set: (0.19595591271816346, 0.001290069089623461)
#
# Dummy CV RMSE: 0.01240508362453504
# Dummy test RMSE: 0.013151674779949636
# 175 drugs done
# **************************************************
#
# XAV939 (897, 145)
# Best CV score (RMSE): 0.03955298158992014
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.0376416187652345
# Correlation with the training set: (0.46746383115045026, 2.3337083904613204e-35)
#
# RMSE on test data: 0.05011206834093044
# Mean absolute error on test data: 0.030180503006491655
# Correlation with the test set: (0.408146659724151, 2.9137409325241647e-12)
#
# Dummy CV RMSE: 0.040374677605274516
# Dummy test RMSE: 0.054189988277318905
# 176 drugs done
# **************************************************
#
# PLX-4720 (870, 145)
# Best CV score (RMSE): 0.060272168122333165
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.25}
#
# RMSE on training data: 0.058290181827679415
# Correlation with the training set: (0.6781624569803992, 3.039895246099866e-83)
#
# RMSE on test data: 0.06554365475299455
# Mean absolute error on test data: 0.03599828309002766
# Correlation with the test set: (0.6723779626028041, 1.0663269231051733e-35)
#
# Dummy CV RMSE: 0.07604023043270192
# Dummy test RMSE: 0.08591011446770012
# 177 drugs done
# **************************************************
#
# Trametinib (850, 146)
# Best CV score (RMSE): 0.2289263479148136
# Best parameters: {'estimator__alpha': 0.1, 'estimator__l1_ratio': 0.1}
#
# RMSE on training data: 0.2168831616833983
# Correlation with the training set: (0.6826063243100854, 8.089649379989269e-83)
#
# RMSE on test data: 0.2118915975195908
# Mean absolute error on test data: 0.1747125469626582
# Correlation with the test set: (0.6597561987940278, 3.0580999161626788e-33)
#
# Dummy CV RMSE: 0.2943175344997806
# Dummy test RMSE: 0.28020135017140285
# 178 drugs done
# **************************************************
#
# Dabrafenib (823, 150)
# Best CV score (RMSE): 0.12403363332620876
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.25}
#
# RMSE on training data: 0.11352041354133684
# Correlation with the training set: (0.7964168840075194, 1.7557027174464108e-127)
#
# RMSE on test data: 0.1457833219120562
# Mean absolute error on test data: 0.086832272831529
# Correlation with the test set: (0.7072463800620588, 9.08691821454789e-39)
#
# Dummy CV RMSE: 0.18470458862510783
# Dummy test RMSE: 0.20630954920273475
# 179 drugs done
# **************************************************
#
# Afatinib (862, 149)
# Best CV score (RMSE): 0.11526342345137676
# Best parameters: {'estimator__alpha': 0.01, 'estimator__l1_ratio': 0.25}
#
# RMSE on training data: 0.1070448779360251
# Correlation with the training set: (0.6807520743576265, 2.7092002008901238e-83)
#
# RMSE on test data: 0.14345537496105562
# Mean absolute error on test data: 0.08198384985188355
# Correlation with the test set: (0.6338214120879644, 1.6728386216633518e-30)
#
# Dummy CV RMSE: 0.14241186831264982
# Dummy test RMSE: 0.18171319894833393
# 180 drugs done
# **************************************************
#
# SN-38 (956, 144)
# Best CV score (RMSE): 0.17284618652970735
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.16483569665011197
# Correlation with the training set: (0.5598910980786763, 1.8384583932752998e-56)
#
# RMSE on test data: 0.19038437144851353
# Mean absolute error on test data: 0.15364844698835858
# Correlation with the test set: (0.38243812596360977, 1.98211913289769e-11)
#
# Dummy CV RMSE: 0.19648721909111883
# Dummy test RMSE: 0.2059482795580716
# 181 drugs done
# **************************************************
#
# Olaparib (884, 147)
# Best CV score (RMSE): 0.052960474648125554
# Best parameters: {'estimator__alpha': 1.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.05023571387480761
# Correlation with the training set: (0.40657956875964435, 5.303996833777446e-26)
#
# RMSE on test data: 0.06202079604265804
# Mean absolute error on test data: 0.03885553887675822
# Correlation with the test set: (0.4060411308118223, 5.569615899560067e-12)
#
# Dummy CV RMSE: 0.053134568035009544
# Dummy test RMSE: 0.06674051241538291
# 182 drugs done
# **************************************************
#
# Bicalutamide (880, 144)
# Best CV score (RMSE): 0.02989231588901471
# Best parameters: {'estimator__alpha': 10.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.02955793525400537
# Correlation with the training set: (0.21216459448002523, 1.0623366409555127e-07)
#
# RMSE on test data: 0.022850868184876555
# Mean absolute error on test data: 0.013851887491447
# Correlation with the test set: (0.17918415455849218, 0.0034861661001047164)
#
# Dummy CV RMSE: 0.026247146492701757
# Dummy test RMSE: 0.023211696033253387
# 183 drugs done
# **************************************************
#
# PFI-3 (800, 148)
# Best CV score (RMSE): 0.019102948967128535
# Best parameters: {'estimator__alpha': 10.0, 'estimator__l1_ratio': 0.0}
#
# RMSE on training data: 0.01878405821125096
# Correlation with the training set: (0.22921530862449196, 4.127677295454979e-08)
#
# RMSE on test data: 0.0195274108472203
# Mean absolute error on test data: 0.010440554545899464
# Correlation with the test set: (0.0902971671692438, 0.16318944725728168)
#
# Dummy CV RMSE: 0.017743143385494237
# Dummy test RMSE: 0.019604059844441808
# 184 drugs done
# **************************************************

# %% [markdown]
# Save this Experiment instance

# %%
# Create a filename out of the Experiment's "name" field
filename = exp.name.lower().replace(" ", "_") + ".pkl"
print(filename)
# Save the instance
with open("../Created data/Results/" + filename, "wb") as f:
    dill.dump(exp, f)
# Out:
# only_targets_with_merck_signatures-elastic_net_with_z-score_normalization.pkl

# %% [markdown]
# ### Random Forest Regressor with Z-score normalization for all features and randomized grid search for hyperparameter tuning - all data classes (expression, mutation, CNV, tissue) + Merck gene expression signatures

# %% [markdown]
# Initialize dictionary with DrugWithDrugBank objects and compute input data for them

# %%
# Create drug objects
drugs = DrugWithDrugBank.create_drugs(drug_annotations_df, map_drugs_to_drugbank_targets)
print(len(drugs))

# Set up data types we want to include in our input for each drug
data_types = ["CNV", "mutation", "expression", "tissue", "merck signatures"]
# Create input data
Experiment.create_input_for_each_drug(drugs, drug_response_df, data_combination=data_types, 
                                     gene_expression_df=gene_expression_df, 
                                     cnv_binary_df=cnv_binary_df,
                                     map_cl_id_and_feature_to_status=map_from_cl_id_and_genetic_feature_to_mutation_status,
                                     cell_lines_list_df=cell_lines_list_df,
                                     coding_variants_df=coding_variants_df,
                                     merck_signatures_df=signatures_df,
                                     feat_threshold=144,
                                     log=True)
# Out:
# 267
# 10 drugs done
# 20 drugs done
# 30 drugs done
# 40 drugs done
# 50 drugs done
# 60 drugs done
# 70 drugs done
# 80 drugs done
# 90 drugs done
# 100 drugs done
# 110 drugs done
# 120 drugs done
# 130 drugs done
# 140 drugs done
# 150 drugs done
# 160 drugs done
# 170 drugs done
# 180 drugs done
# 190 drugs done
# 200 drugs done
# 210 drugs done
# 220 drugs done
# 230 drugs done
# 240 drugs done
# 250 drugs done
# 260 drugs done
# Number of drugs with number of features bigger than 144: 184
# Mean number of features in 267 drugs: 131.24719101123594

# %%
#############################################################################################################
# Set up constants, feature normalization, predictive algorithm and initialize experiment instance
#############################################################################################################

log = True
counter = 0
sensitivity_metric = "AUC"
record_weights = False   # Does the model has coefficients we want to record?
n_folds = 5   # Number of folds in parameter tuning cross-validation
n_combinations = 20   # Number of parameter combinations to try (when using randomized search)

scaler = preprocessing.StandardScaler()   # Setup transformer for feature scaling

estimator = RandomForestRegressor()   # Setup algorithm to use

# Hyperparameter space to search on
# Number of trees in random forest
n_estimators = [10, 20, 50, 100, 200, 500]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [int(x) for x in np.linspace(2, 101, num = 10)]
# Minimum number of samples required at each leaf node
min_samples_leaf = [int(x) for x in np.linspace(2, 101, num = 10)]
# Method of selecting samples for training each tree
criterion = ["mse", "mae"]

# Create the param grid
param_grid = {'estimator__n_estimators': n_estimators,
               'estimator__max_features': max_features,
               'estimator__max_depth': max_depth,
               'estimator__min_samples_split': min_samples_split,
               'estimator__min_samples_leaf': min_samples_leaf,
               'estimator__criterion': criterion}

# Set up seeds for data split and randomized parameter tuning
split_seed = 37
tuning_seed = 53

# Function to be optimized during hyperparameter tuning
scoring = "neg_mean_squared_error"   # Function to be optimized by hyperparameters

# Initialize Experiment object for this assay
exp = Experiment(name="Only targets with merck signatures-Random Forest with Z-score normalization",
                algorithm="RandomForestRegressor",
                parameter_search_type="RandomizedSearch",
                data_normalization_type="StandardScaler on all features",
                kfolds=n_folds,
                split_seed=split_seed,
                tuning_seed=tuning_seed)

# Load previous interrupted Experiment
load = True
if load:
    filename = exp.name.lower().replace(" ", "_") + ".pkl"
    with open("../Created data/Results/" + filename, "rb") as f:
        exp = dill.load(f)

#############################################################################################################
# Enter the loop over drugs
#############################################################################################################

for ide in drugs:
    drug = drugs[ide]   # Current Drug object
    
    if (drug.name, ide) in exp.training_scores:
        continue   # If drug was already modeled in this Experiment, skip it
        
    data = drug.full_data  # Extract input data (should be previously computed)
    if data.shape[0] == 0:   # Check if data exists, if not, skip the drug
        continue
    if data.shape[1] < 144:    # That means that data has only features related to tissue
        continue           # so also skip this case
        
    # Reset drug data fields in order to save memory
    drug.full_data = None
    drug.merck_signatures = None
    drug.tissue_data = None
        
    # Add input data to corresponding Experiment objects's field (dictionary)
    exp.input_data[(drug.name, ide)] = data
    if log:
        print(drug.name, data.shape)
        
    # Add data shapes to corresponding field in Experiment (dictionary)
    exp.data_shapes[(drug.name, ide)] = data.shape
    
    y = data[sensitivity_metric]   # Extract response variable
    X = data.drop(["cell_line_id", sensitivity_metric], axis=1)     # Drop targets and cell line IDs
    assert X.shape[0] == y.shape[0]   # Sanity check
    assert X.shape[1] < data.shape[1]
    
    # Split data into training and test set
    test_size = 0.3    # Fraction of data spent on test set
    X_val, X_test, y_val, y_test = model_selection.train_test_split(X, y, test_size=test_size,
                                                                   random_state=split_seed)
    
    # Record standard deviations of data
    # Create collections.collections.namedtuple for storing
    StandardDeviations = collections.namedtuple("StandardDeviations", ["validation", "test", "overall"])
    stds = StandardDeviations(y_val.std(), y_test.std(), y.std())
    # Record in corresponding field (dictionary)
    exp.data_stds[(drug.name, ide)] = stds    
    
    # Set up and fit Dummy Regressor
    dummy = DummyRegressor()
    dummy.fit(X_val, y_val)
    # Get dummy predictions on the test set
    dummy_preds = dummy.predict(X_test)
    # Baseline dummy performance
    baseline_scores = model_selection.cross_val_score(dummy, X_val, y_val, scoring=scoring, cv=n_folds)
    baseline_mean = np.mean([(-x)**0.5 for x in baseline_scores])
    baseline_std = np.std([(-x)**0.5 for x in baseline_scores])
    
    # Set elements of the pipeline, i.e. scaler and estimator
    transformer = clone(scaler)
    predictor = clone(estimator)   # Make a copy to ensure that for every drug we get "fresh" predictor
    
    # Create pipeline
    main_pipeline = Pipeline([
        ("scaler", transformer),
        ("estimator", predictor)
    ])    
    
#     # Set up grid search with cross-validation
#     grid = model_selection.GridSearchCV(main_pipeline, param_grid=param_grid, 
#                                        scoring=scoring, cv=n_folds)
    
    # Or use RandomizedSearch
    grid = model_selection.RandomizedSearchCV(main_pipeline, param_distributions=param_grid,
                                             n_iter=n_combinations, scoring=scoring, cv=n_folds,
                                             random_state=tuning_seed)
    
    # Fit the grid
    grid.fit(X_val, y_val)
    best = grid.best_estimator_   # Best model
    pred = grid.predict(X_test)   # Predict on test data with refitted best model
    training_preds = grid.predict(X_val)    # Predict on train data with refitted best model
    
    if log:   # Report the results
        # Summarize grid search
        print("Best CV score (RMSE):", (-grid.best_score_)**0.5)
        print("Best parameters:", grid.best_params_)
        print("")
        
        # Print out performance of the best model on training set
        print("RMSE on training data:", metrics.mean_squared_error(y_val, training_preds)**0.5)
        print("Correlation with the training set:", pearsonr(y_val, training_preds))
        print("")
        
        # Print out the performance of the best model on test set
        print("RMSE on test data:", metrics.mean_squared_error(y_test, pred) ** 0.5)
        print("Mean absolute error on test data:", metrics.mean_absolute_error(y_test, pred))
        print("Correlation with the test set:", pearsonr(y_test, pred))
        print("")
        
        # Print out performance of dummy regressor
        print("Dummy CV RMSE:", baseline_mean)
        print("Dummy test RMSE:", metrics.mean_squared_error(y_test, dummy_preds) ** 0.5)
        
    # Record results in corresponding Experiment fields, mostly as named tuples
    # Classification performance
    ModelTestScores = collections.namedtuple("ModelTestScores", ["cv_best_score", "test_RMSE",
                                                    "test_explained_variance", "test_correlation"])
    model_test_scores = ModelTestScores(grid.best_score_, metrics.mean_squared_error(y_test, pred) ** 0.5,
                                       metrics.explained_variance_score(y_test, pred), pearsonr(y_test, pred))
    # Record in appropriate field (dictionary)
    exp.best_scores[(drug.name, ide)] = model_test_scores
    
    # Full results of cross-validation tuning
    exp.cv_results[(drug.name, ide)] = grid.cv_results_
    
    # Parameters of best found model
    exp.best_parameters[(drug.name, ide)] = grid.best_params_
    
    # Coefficients (if model has them)
    if record_weights:
        BestModelWeights = collections.namedtuple("BestModelWeights", ["intercept", "weights_array"])
        best_model_weights = BestModelWeights(best.named_steps["estimator"].intercept_,
                                         best.named_steps["estimator"].coef_)
        # Record in appropriate field (dictionary)
        exp.coefficients[(drug.name, ide)] = best_model_weights
    
    # Performance on the training set
    ModelTrainingScores = collections.namedtuple("ModelTrainingScores", ["training_RMSE", "training_correlation"])
    model_training_scores = ModelTrainingScores(metrics.mean_squared_error(y_val, training_preds) ** 0.5,
                                               pearsonr(y_val, training_preds))
    # Record in appropriate field (dictionary)
    exp.training_scores[(drug.name, ide)] = model_training_scores
    
    # Performance of dummy model
    DummyScores = collections.namedtuple("DummyScores", ["cv_RMSE", "test_RMSE", "test_explained_variance",
                                            "test_correlation"])
    dummy_performance = DummyScores(baseline_mean, metrics.mean_squared_error(y_test, dummy_preds) ** 0.5,
                                   metrics.explained_variance_score(y_test, dummy_preds),
                                   pearsonr(y_test, dummy_preds))
    # Record in appropriate field (dictionary)
    exp.dummy_scores[(drug.name, ide)] = dummy_performance
    
    # Increment counter and display summary information
    counter += 1
    if log:
        print(counter, "drugs done")
        print("*" * 50)
        print("")
# Out:
# GSK429286A (897, 146)
# Best CV score (RMSE): 0.07043033950341852
# Best parameters: {'estimator__n_estimators': 100, 'estimator__min_samples_split': 35, 'estimator__min_samples_leaf': 35, 'estimator__max_features': 'auto', 'estimator__max_depth': None, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.06552450004721036
# Correlation with the training set: (0.4939239774908348, 7.130605687966033e-40)
#
# RMSE on test data: 0.05415550795038702
# Mean absolute error on test data: 0.03289751524577331
# Correlation with the test set: (0.3248169124856245, 4.725995424344891e-08)
#
# Dummy CV RMSE: 0.07265307325849626
# Dummy test RMSE: 0.0572091068889053
# 1 drugs done
# **************************************************
#
# QL-XII-47 (920, 145)
# Best CV score (RMSE): 0.17825949331626706
# Best parameters: {'estimator__n_estimators': 500, 'estimator__min_samples_split': 68, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'auto', 'estimator__max_depth': 30, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.14390786340660353
# Correlation with the training set: (0.7151855492396355, 5.90496830038402e-102)
#
# RMSE on test data: 0.17967110446184895
# Mean absolute error on test data: 0.1495959971290621
# Correlation with the test set: (0.2823015935209726, 1.8796401548550966e-06)
#
# Dummy CV RMSE: 0.1894762639452023
# Dummy test RMSE: 0.18598576178682436
# 2 drugs done
# **************************************************
#
# Cabozantinib (861, 157)
# Best CV score (RMSE): 0.07944761205603942
# Best parameters: {'estimator__n_estimators': 500, 'estimator__min_samples_split': 68, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'auto', 'estimator__max_depth': 30, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.06067926839058933
# Correlation with the training set: (0.8427049575758391, 1.7296798363474346e-163)
#
# RMSE on test data: 0.08143577767600171
# Mean absolute error on test data: 0.05346582805923445
# Correlation with the test set: (0.3056930276477712, 5.263062733180675e-07)
#
# Dummy CV RMSE: 0.10876390422390694
# Dummy test RMSE: 0.08557861773830903
# 3 drugs done
# **************************************************
#
# WZ3105 (863, 154)
# Best CV score (RMSE): 0.14382969367487974
# Best parameters: {'estimator__n_estimators': 500, 'estimator__min_samples_split': 68, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'auto', 'estimator__max_depth': 30, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.11890726182673494
# Correlation with the training set: (0.7374010560840113, 1.1501816545466803e-104)
#
# RMSE on test data: 0.15365978001769232
# Mean absolute error on test data: 0.11628864016638832
# Correlation with the test set: (0.4881115271977368, 6.539091936184479e-17)
#
# Dummy CV RMSE: 0.17108559328583092
# Dummy test RMSE: 0.17569371607430592
# 4 drugs done
# **************************************************
#
# XMD14-99 (863, 148)
# Best CV score (RMSE): 0.032644161044052725
# Best parameters: {'estimator__n_estimators': 500, 'estimator__min_samples_split': 68, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'auto', 'estimator__max_depth': 30, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.025824571925252324
# Correlation with the training set: (0.7286485390255865, 4.9171059634894036e-101)
#
# RMSE on test data: 0.025457785557415135
# Mean absolute error on test data: 0.017121694889191484
# Correlation with the test set: (0.43334205250359, 2.7889905412970533e-13)
#
# Dummy CV RMSE: 0.03522454323689966
# Dummy test RMSE: 0.0278696816721942
# 5 drugs done
# **************************************************
#
# Quizartinib (862, 146)
# Best CV score (RMSE): 0.06177397473771782
# Best parameters: {'estimator__n_estimators': 500, 'estimator__min_samples_split': 68, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'auto', 'estimator__max_depth': 30, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.04009437615839813
# Correlation with the training set: (0.8760481983141966, 1.5917516716772082e-192)
#
# RMSE on test data: 0.03819413139780893
# Mean absolute error on test data: 0.02069916070442115
# Correlation with the test set: (0.8331073825721784, 4.763549622813537e-68)
#
# Dummy CV RMSE: 0.07193555791687725
# Dummy test RMSE: 0.06685671494251601
# 6 drugs done
# **************************************************
#
# CP724714 (863, 146)
# Best CV score (RMSE): 0.04679625645628614
# Best parameters: {'estimator__n_estimators': 500, 'estimator__min_samples_split': 68, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'auto', 'estimator__max_depth': 30, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.0356652257198024
# Correlation with the training set: (0.7566383860450658, 3.4978884713408814e-113)
#
# RMSE on test data: 0.05135619927875809
# Mean absolute error on test data: 0.022609833655299064
# Correlation with the test set: (0.26487606248258133, 1.5634161514138526e-05)
#
# Dummy CV RMSE: 0.050467417766972056
# Dummy test RMSE: 0.05271661695848376
# 7 drugs done
# **************************************************
#
# JW-7-24-1 (922, 144)
# Best CV score (RMSE): 0.14090615282766836
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 79, 'estimator__min_samples_leaf': 13, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mae'}
#
# RMSE on training data: 0.1321532884515057
# Correlation with the training set: (0.5909259175483393, 5.619265667406998e-62)
#
# RMSE on test data: 0.13056359045375066
# Mean absolute error on test data: 0.0968753015162455
# Correlation with the test set: (0.5856001036267474, 6.810088482962993e-27)
#
# Dummy CV RMSE: 0.1637335412192671
# Dummy test RMSE: 0.1579922232905281
# 8 drugs done
# **************************************************
#
# NPK76-II-72-1 (920, 144)
# Best CV score (RMSE): 0.11250107314961097
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 79, 'estimator__min_samples_leaf': 35, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 70, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.10565001960158661
# Correlation with the training set: (0.6889047177436134, 8.692467891919691e-92)
#
# RMSE on test data: 0.12057495308855232
# Mean absolute error on test data: 0.08887392778667119
# Correlation with the test set: (0.5662806227089274, 8.338836522448528e-25)
#
# Dummy CV RMSE: 0.1434614544915654
# Dummy test RMSE: 0.1469115442441061
# 9 drugs done
# **************************************************
#
# NG-25 (920, 144)
# Best CV score (RMSE): 0.1283493274321071
# Best parameters: {'estimator__n_estimators': 100, 'estimator__min_samples_split': 35, 'estimator__min_samples_leaf': 35, 'estimator__max_features': 'auto', 'estimator__max_depth': None, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.12014170919799994
# Correlation with the training set: (0.6105008380257949, 4.9917339276099284e-67)
#
# RMSE on test data: 0.1369934642205214
# Mean absolute error on test data: 0.09501311812685342
# Correlation with the test set: (0.5829331662961643, 1.6165617277400308e-26)
#
# Dummy CV RMSE: 0.150582400745568
# Dummy test RMSE: 0.1698858447001442
# 10 drugs done
# **************************************************
#
# FR-180204 (894, 145)
# Best CV score (RMSE): 0.037243478016897945
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.03316097848311043
# Correlation with the training set: (0.6345213150073825, 1.0086687035642106e-71)
#
# RMSE on test data: 0.02785249980304569
# Mean absolute error on test data: 0.02079450512379191
# Correlation with the test set: (0.27884369645806695, 3.408550190374611e-06)
#
# Dummy CV RMSE: 0.03645296002120528
# Dummy test RMSE: 0.029007109713656637
# 11 drugs done
# **************************************************
#
# Tubastatin A (917, 146)
# Best CV score (RMSE): 0.0656629150677457
# Best parameters: {'estimator__n_estimators': 100, 'estimator__min_samples_split': 35, 'estimator__min_samples_leaf': 35, 'estimator__max_features': 'auto', 'estimator__max_depth': None, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.060058275434875866
# Correlation with the training set: (0.6526820486811455, 4.5419728459394255e-79)
#
# RMSE on test data: 0.059435490393544704
# Mean absolute error on test data: 0.04297602643614466
# Correlation with the test set: (0.48186402556647856, 1.8802900693494716e-17)
#
# Dummy CV RMSE: 0.07805797192366741
# Dummy test RMSE: 0.06689630506493317
# 12 drugs done
# **************************************************
#
# Sepantronium bromide (888, 144)
# Best CV score (RMSE): 0.2516740070959647
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.21599954853087822
# Correlation with the training set: (0.6820707425829625, 3.478368554561202e-86)
#
# RMSE on test data: 0.25602368009854093
# Mean absolute error on test data: 0.19097529014654763
# Correlation with the test set: (0.25069401297294475, 3.4202545020481744e-05)
#
# Dummy CV RMSE: 0.2586245593634898
# Dummy test RMSE: 0.2644383733127208
# 13 drugs done
# **************************************************
#
# NSC-207895 (889, 145)
# Best CV score (RMSE): 0.09253844972044857
# Best parameters: {'estimator__n_estimators': 500, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 90, 'estimator__max_features': 'auto', 'estimator__max_depth': 30, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.0900785079181776
# Correlation with the training set: (0.34452653245900783, 8.951610489871548e-19)
#
# RMSE on test data: 0.09429511771831384
# Mean absolute error on test data: 0.06937760052475393
# Correlation with the test set: (0.285956008668996, 2.032170621625556e-06)
#
# Dummy CV RMSE: 0.09508946856081615
# Dummy test RMSE: 0.09826825567670788
# 14 drugs done
# **************************************************
#
# AR-42 (911, 144)
# Best CV score (RMSE): 0.1751882846807844
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 90, 'estimator__min_samples_leaf': 2, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mse'}
#
# RMSE on training data: 0.15631673722082817
# Correlation with the training set: (0.6639676572564883, 3.287511141475386e-82)
#
# RMSE on test data: 0.18529145187853527
# Mean absolute error on test data: 0.14722593523479344
# Correlation with the test set: (0.47721646963015046, 5.451337339294213e-17)
#
# Dummy CV RMSE: 0.20406937660864846
# Dummy test RMSE: 0.2116218537363952
# 15 drugs done
# **************************************************
#
# CUDC-101 (844, 149)
# Best CV score (RMSE): 0.1809046662387253
# Best parameters: {'estimator__n_estimators': 50, 'estimator__min_samples_split': 79, 'estimator__min_samples_leaf': 13, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 100, 'estimator__criterion': 'mae'}
#
# RMSE on training data: 0.16610455221922266
# Correlation with the training set: (0.628606910952617, 3.3319227470777793e-66)
#
# RMSE on test data: 0.2031560981496226
# Mean absolute error on test data: 0.16681685885826775
# Correlation with the test set: (0.3899538808768868, 1.1870723150510032e-10)
#
# Dummy CV RMSE: 0.21073737259750497
# Dummy test RMSE: 0.2194496671441799
# 16 drugs done
# **************************************************
#
# Belinostat (836, 156)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-c88a10504cc3> in <module>()
#     136
#     137     # Fit the grid
# --> 138     grid.fit(X_val, y_val)
#     139     best = grid.best_estimator_   # Best model
#     140     pred = grid.predict(X_test)   # Predict on test data with refitted best model
#
# ~/.local/lib/python3.6/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     638                                   error_score=self.error_score)
#     639           for parameters, (train, test) in product(candidate_params,
# --> 640                                                    cv.split(X, y, groups)))
#     641
#     642         # if one choose to see train score, "out" will contain train score info
#
# ~/.local/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     777             # was dispatched. In particular this covers the edge
#     778             # case of Parallel used with an exhausted iterator.
# --> 779             while self.dispatch_one_batch(iterator):
#     780                 self._iterating = True
#     781             else:
#
# ~/.local/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     623                 return False
#     624             else:
# --> 625                 self._dispatch(tasks)
#     626                 return True
#     627
#
# ~/.local/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     586         dispatch_timestamp = time.time()
#     587         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 588         job = self._backend.apply_async(batch, callback=cb)
#     589         self._jobs.append(job)
#     590
#
# ~/.local/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     109     def apply_async(self, func, callback=None):
#     110         """Schedule a func to be run"""
# --> 111         result = ImmediateResult(func)
#     112         if callback:
#     113             callback(result)
#
# ~/.local/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     330         # Don't delay the application, to avoid keeping the input
#     331         # arguments in memory
# --> 332         self.results = batch()
#     333
#     334     def get(self):
#
# ~/.local/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# ~/.local/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# ~/.local/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, error_score)
#     456             estimator.fit(X_train, **fit_params)
#     457         else:
# --> 458             estimator.fit(X_train, y_train, **fit_params)
#     459
#     460     except Exception as e:
#
# ~/.local/lib/python3.6/site-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     248         Xt, fit_params = self._fit(X, y, **fit_params)
#     249         if self._final_estimator is not None:
# --> 250             self._final_estimator.fit(Xt, y, **fit_params)
#     251         return self
#     252
#
# ~/.local/lib/python3.6/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     326                     t, self, X, y, sample_weight, i, len(trees),
#     327                     verbose=self.verbose, class_weight=self.class_weight)
# --> 328                 for i, t in enumerate(trees))
#     329
#     330             # Collect newly grown trees
#
# ~/.local/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     777             # was dispatched. In particular this covers the edge
#     778             # case of Parallel used with an exhausted iterator.
# --> 779             while self.dispatch_one_batch(iterator):
#     780                 self._iterating = True
#     781             else:
#
# ~/.local/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     623                 return False
#     624             else:
# --> 625                 self._dispatch(tasks)
#     626                 return True
#     627
#
# ~/.local/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     586         dispatch_timestamp = time.time()
#     587         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 588         job = self._backend.apply_async(batch, callback=cb)
#     589         self._jobs.append(job)
#     590
#
# ~/.local/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     109     def apply_async(self, func, callback=None):
#     110         """Schedule a func to be run"""
# --> 111         result = ImmediateResult(func)
#     112         if callback:
#     113             callback(result)
#
# ~/.local/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     330         # Don't delay the application, to avoid keeping the input
#     331         # arguments in memory
# --> 332         self.results = batch()
#     333
#     334     def get(self):
#
# ~/.local/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# ~/.local/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# ~/.local/lib/python3.6/site-packages/sklearn/ensemble/forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight)
#     119             curr_sample_weight *= compute_sample_weight('balanced', y, indices)
#     120
# --> 121         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     122     else:
#     123         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# ~/.local/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1122             sample_weight=sample_weight,
#    1123             check_input=check_input,
# -> 1124             X_idx_sorted=X_idx_sorted)
#    1125         return self
#    1126
#
# ~/.local/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     360                                            min_impurity_split)
#     361
# --> 362         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     363
#     364         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:

# %% [markdown]
# Save this Experiment instance

# %%
# Create a filename out of the Experiment's "name" field
filename = exp.name.lower().replace(" ", "_") + ".pkl"
print(filename)
# Save the instance
with open("../Created data/Results/" + filename, "wb") as f:
    dill.dump(exp, f)
# Out:
# only_targets_with_merck_signatures-random_forest_with_z-score_normalization.pkl
